# %%
#needed after restructuring of directory
import os
os.chdir('/Users/alexchandler/UFC_Prediction_2022')
os.getcwd()
# Out:
# '/Users/alexchandler/UFC_Prediction_2022'

# %%
#this is all copied from https://pytorch.org/tutorials/advanced/neural_style_tutorial.html
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import pandas as pd

from PIL import Image
import matplotlib.pyplot as plt

import torchvision.transforms as transforms
import torchvision.models as models

import copy

from torchvision.utils import save_image
import torch
import torchvision

from os.path import exists

import random

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

cnn = models.vgg19(pretrained=True).features.to(device).eval()

# %%
# desired size of the output image
imsize = 512 if torch.cuda.is_available() else 256  # use small size if no gpu

loader = transforms.Compose([
    transforms.Resize(imsize),  # scale imported image
    transforms.ToTensor()])  # transform it into a torch tensor

def image_loader(image):
    # fake batch dimension required to fit network's input dimensions
    image = loader(image).unsqueeze(0)
    return image.to(device, torch.float)

styleimage0=Image.open("src/models/buildingMLModel/images/escher1.jpeg") 

styleimage1=Image.open("src/models/buildingMLModel/images/onepunch.jpg")

styleimage2=Image.open("src/models/buildingMLModel/images/pixelart.jpeg")
styleimage3=Image.open("src/models/buildingMLModel/images/vegito.jpeg") 
styleimage4=Image.open("src/models/buildingMLModel/images/conorpainting.jpeg")  
styleimage5=Image.open("src/models/buildingMLModel/images/picasso.jpeg")  
styleimage6=Image.open("src/models/buildingMLModel/images/paintedoblivion.webp")
styleimage7=Image.open("src/models/buildingMLModel/images/starrynight.jpeg")
styleimage8=Image.open("src/models/buildingMLModel/images/bear.jpeg")
styleimage9=Image.open("src/models/buildingMLModel/images/god.jpeg")
styleimage10=Image.open("src/models/buildingMLModel/images/vangogh.jpeg")  

thresh={0:950,
       1: 250,
        2:1200,
        3: 800,
        4:250,
        5: 40,
        6: 60, 
        7: 100,
        8: 200,
        9: 150,
        10: 160,
       }


styleimage0=styleimage0.resize((256,256))
styleimage1=styleimage1.resize((256,256))
styleimage2=styleimage2.resize((256,256))
styleimage3=styleimage3.resize((256,256))
styleimage4=styleimage4.resize((256,256))
styleimage5=styleimage5.resize((256,256))
styleimage6=styleimage6.resize((256,256))
styleimage7=styleimage7.resize((256,256))
styleimage8=styleimage8.resize((256,256))
styleimage9=styleimage9.resize((256,256))
styleimage10=styleimage10.resize((256,256))



fighterimage=Image.open("src/models/buildingMLModel/images/2KhamzatChimaev.jpg")
fighterimage=fighterimage.resize((256,256))

style = [image_loader(styleimage0),image_loader(styleimage1),image_loader(styleimage2),
         image_loader(styleimage3), image_loader(styleimage4), image_loader(styleimage5), 
         image_loader(styleimage6), image_loader(styleimage7), image_loader(styleimage8),
        image_loader(styleimage9), image_loader(styleimage10)]

#defining an alternate line of styles
styleimage0alt=Image.open("src/models/buildingMLModel/images/uigoku.jpeg")  
styleimage1alt=Image.open("src/models/buildingMLModel/images/bulma.jpeg")
styleimage2alt=Image.open("src/models/buildingMLModel/images/vegeta.webp")
styleimage3alt=Image.open("src/models/buildingMLModel/images/jiren.jpeg")  
styleimage4alt=Image.open("src/models/buildingMLModel/images/top.webp")  
styleimage5alt=Image.open("src/models/buildingMLModel/images/frieza.jpeg")
styleimage6alt=Image.open("src/models/buildingMLModel/images/conor.jpeg")


threshalt={0: 500,
           1: 500,
           2: 1000,
           3: 525,
           4: 1000,
           5:400,
           6:150
       }

styleimage0alt=styleimage0alt.resize((256,256))
styleimage1alt=styleimage1alt.resize((256,256))
styleimage2alt=styleimage2alt.resize((256,256))
styleimage3alt=styleimage3alt.resize((256,256))
styleimage4alt=styleimage4alt.resize((256,256))
styleimage5alt=styleimage5alt.resize((256,256))
styleimage6alt=styleimage6alt.resize((256,256))


stylealt = [image_loader(styleimage0alt),image_loader(styleimage1alt),image_loader(styleimage2alt),
          image_loader(styleimage3alt), image_loader(styleimage4alt), 
         image_loader(styleimage5alt), image_loader(styleimage6alt)]

fighterimage=Image.open("src/models/buildingMLModel/images/2KhamzatChimaev.jpg")
fighterimage=fighterimage.resize((256,256))

content_img = image_loader(fighterimage)
assert all(style[i].size() == content_img.size() for i in range(len(style))), \
    "we need to import style and content images of the same size"

unloader = transforms.ToPILImage()  # reconvert into PIL image

plt.ion()

def imshow(tensor, title=None):
    image = tensor.cpu().clone()  # we clone the tensor to not do changes on it
    image = image.squeeze(0)      # remove the fake batch dimension
    image = unloader(image)
    plt.imshow(image)
    if title is not None:
        plt.title(title)
    plt.pause(0.001) # pause a bit so that plots are updated
    
class ContentLoss(nn.Module):

    def __init__(self, target,):
        super(ContentLoss, self).__init__()
        # we 'detach' the target content from the tree used
        # to dynamically compute the gradient: this is a stated value,
        # not a variable. Otherwise the forward method of the criterion
        # will throw an error.
        self.target = target.detach()

    def forward(self, input):
        self.loss = F.mse_loss(input, self.target)
        return input
    
def gram_matrix(input):
    a, b, c, d = input.size()  # a=batch size(=1)
    # b=number of feature maps
    # (c,d)=dimensions of a f. map (N=c*d)

    features = input.view(a * b, c * d)  # resise F_XL into \hat F_XL

    G = torch.mm(features, features.t())  # compute the gram product

    # we 'normalize' the values of the gram matrix
    # by dividing by the number of element in each feature maps.
    return G.div(a * b * c * d)

class StyleLoss(nn.Module):

    def __init__(self, target_feature):
        super(StyleLoss, self).__init__()
        self.target = gram_matrix(target_feature).detach()

    def forward(self, input):
        G = gram_matrix(input)
        self.loss = F.mse_loss(G, self.target)
        return input
    
cnn_normalization_mean = torch.tensor([0.485, 0.456, 0.406]).to(device)
cnn_normalization_std = torch.tensor([0.229, 0.224, 0.225]).to(device)

# create a module to normalize input image so we can easily put it in a
# nn.Sequential
class Normalization(nn.Module):
    def __init__(self, mean, std):
        super(Normalization, self).__init__()
        # .view the mean and std to make them [C x 1 x 1] so that they can
        # directly work with image Tensor of shape [B x C x H x W].
        # B is batch size. C is number of channels. H is height and W is width.
        self.mean = torch.tensor(mean).view(-1, 1, 1)
        self.std = torch.tensor(std).view(-1, 1, 1)

    def forward(self, img):
        # normalize img
        return (img - self.mean) / self.std
    
# desired depth layers to compute style/content losses :
content_layers_default = ['conv_4']
style_layers_default = ['conv_1', 'conv_2', 'conv_3', 'conv_4', 'conv_5']

def get_style_model_and_losses(cnn, normalization_mean, normalization_std,
                               style_img, content_img,
                               content_layers=content_layers_default,
                               style_layers=style_layers_default):
    # normalization module
    normalization = Normalization(normalization_mean, normalization_std).to(device)

    # just in order to have an iterable access to or list of content/syle
    # losses
    content_losses = []
    style_losses = []

    # assuming that cnn is a nn.Sequential, so we make a new nn.Sequential
    # to put in modules that are supposed to be activated sequentially
    model = nn.Sequential(normalization)

    i = 0  # increment every time we see a conv
    for layer in cnn.children():
        if isinstance(layer, nn.Conv2d):
            i += 1
            name = 'conv_{}'.format(i)
        elif isinstance(layer, nn.ReLU):
            name = 'relu_{}'.format(i)
            # The in-place version doesn't play very nicely with the ContentLoss
            # and StyleLoss we insert below. So we replace with out-of-place
            # ones here.
            layer = nn.ReLU(inplace=False)
        elif isinstance(layer, nn.MaxPool2d):
            name = 'pool_{}'.format(i)
        elif isinstance(layer, nn.BatchNorm2d):
            name = 'bn_{}'.format(i)
        else:
            raise RuntimeError('Unrecognized layer: {}'.format(layer.__class__.__name__))

        model.add_module(name, layer)

        if name in content_layers:
            # add content loss:
            target = model(content_img).detach()
            content_loss = ContentLoss(target)
            model.add_module("content_loss_{}".format(i), content_loss)
            content_losses.append(content_loss)

        if name in style_layers:
            # add style loss:
            target_feature = model(style_img).detach()
            style_loss = StyleLoss(target_feature)
            model.add_module("style_loss_{}".format(i), style_loss)
            style_losses.append(style_loss)

    # now we trim off the layers after the last content and style losses
    for i in range(len(model) - 1, -1, -1):
        if isinstance(model[i], ContentLoss) or isinstance(model[i], StyleLoss):
            break

    model = model[:(i + 1)]

    return model, style_losses, content_losses

input_img = content_img.clone()
# if you want to use white noise instead uncomment the below line:
# input_img = torch.randn(content_img.data.size(), device=device)

# add the original input image to the figure:
plt.figure()

for i in range(len(style)):
    print('style '+str(i))
    imshow(style[i], title='Style Image')

def get_input_optimizer(input_img):
    # this line to show that input is a parameter that requires a gradient
    optimizer = optim.LBFGS([input_img])
    return optimizer

def run_style_transfer(cnn, normalization_mean, normalization_std,
                       content_img, style_img, input_img, num_steps=300,
                       style_weight=1000000, content_weight=1):
    """Run the style transfer."""
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)
    # We want to optimize the input and not the model parameters so we
    # update all the requires_grad fields accordingly
    input_img.requires_grad_(True)
    model.requires_grad_(False)
    optimizer = get_input_optimizer(input_img)
    run = [0]
    while run[0] <= num_steps:
        def closure():
            # correct the values of updated input image
            with torch.no_grad():
                input_img.clamp_(0, 1)
            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0
            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss
            style_score *= style_weight
            content_score *= content_weight
            loss = style_score + content_score
            loss.backward()
            run[0] += 1
            if run[0] ==50:
                print('Style Loss : {:4f}'.format(style_score.item()))
            return style_score + content_score
        optimizer.step(closure)
    # a last correction...
    with torch.no_grad():
        input_img.clamp_(0, 1)
    return input_img

alt=False

def run_style_transfer_adaptive(cnn, normalization_mean, normalization_std,
                       content_img, styleindex, input_img, num_steps=300,
                       style_weight=1000000, content_weight=1):
    style_img=style[styleindex]
    if alt==True:
        style_img=stylealt[styleindex]
    firstLoss={0:0}
    """Run the style transfer."""
    model, style_losses, content_losses = get_style_model_and_losses(cnn,
        normalization_mean, normalization_std, style_img, content_img)
    # We want to optimize the input and not the model parameters so we
    # update all the requires_grad fields accordingly
    input_img.requires_grad_(True)
    model.requires_grad_(False)
    optimizer = get_input_optimizer(input_img)
    run = [0]
    while run[0] <= num_steps and firstLoss[0]==0:
        def closure():
            # correct the values of updated input image
            with torch.no_grad():
                input_img.clamp_(0, 1)
            optimizer.zero_grad()
            model(input_img)
            style_score = 0
            content_score = 0
            for sl in style_losses:
                style_score += sl.loss
            for cl in content_losses:
                content_score += cl.loss
            style_score *= style_weight
            content_score *= content_weight
            loss = style_score + content_score
            loss.backward()
            run[0] += 1
            if run[0] % 50 == 0:
                if (style_score.item()>thresh[styleindex] and alt==False) or (style_score.item()>threshalt[styleindex] and alt==True):
                    firstLoss[0]=style_score.item()
            return style_score + content_score
        optimizer.step(closure)
    # a last correction...
    with torch.no_grad():
        input_img.clamp_(0, 1)
    if firstLoss[0]==0:
        return input_img
    else:
        return 'empty'
# Out:
# style 0
# style 1
# style 2
# style 3
# style 4
# style 5
# style 6
# style 7
# style 8
# style 9
# style 10

# %%
ufcfighterscrap =pd.read_csv('src/models/buildingMLModel/data/processed/fighter_stats.csv',sep=',',low_memory=False)
names = list(ufcfighterscrap['name'])

# %%
#testing stylization
fighterimage=Image.open("src/models/buildingMLModel/images/1NateDiaz.jpg")
fighterimage=fighterimage.resize((256,256))
content_img = image_loader(fighterimage)
styleindex=random.randint(1,len(style))-1
output = 'empty'
while output =='empty':
    input_img = content_img.clone()
    styleindex=(styleindex+1)%len(style)
    print('trying style number '+str((styleindex+1)%len(style)))
    output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                       content_img, styleindex, input_img, num_steps=300,
                       style_weight=1000000, content_weight=1)

# %%
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#0-7 done
#can run about 90 overnight
for name in names[8:100]:
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty' and k<=5:
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                print('trying style number '+str((styleindex+1)%len(style)))
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
        except:
            continue

# %%
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#0-7 done
#can run about 90 overnight
for name in names[100:200]:
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty' and k<=5:
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                print('trying style number '+str((styleindex+1)%len(style)))
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
        except:
            continue

# %%
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#0-200 done... testing next 30 to see if there are any running poorly
#can run about 90 overnight
for name in names[200:230]:
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print('couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                print('trying style number '+str(styleindex)+' for '+name)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print('saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            continue
# Out:
# trying style number 2 for ChrisWeidman
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/241124489.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/241124489.py:111: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# saving: src/models/buildingMLModel/images2/1ChrisWeidman.jpg in style 2
# trying style number 0 for ChrisWeidman
# saving: src/models/buildingMLModel/images2/2ChrisWeidman.jpg in style 0
# trying style number 4 for ChrisWeidman
# trying style number 5 for ChrisWeidman
# saving: src/models/buildingMLModel/images2/3ChrisWeidman.jpg in style 5
# trying style number 5 for ChrisWeidman
# saving: src/models/buildingMLModel/images2/4ChrisWeidman.jpg in style 5
# trying style number 3 for OmariAkhmedov
# trying style number 4 for OmariAkhmedov
# saving: src/models/buildingMLModel/images2/1OmariAkhmedov.jpg in style 4
# trying style number 1 for OmariAkhmedov
# trying style number 2 for OmariAkhmedov
# trying style number 3 for OmariAkhmedov
# trying style number 4 for OmariAkhmedov
# trying style number 5 for OmariAkhmedov
# saving: src/models/buildingMLModel/images2/2OmariAkhmedov.jpg in style 5
# trying style number 6 for OmariAkhmedov
# saving: src/models/buildingMLModel/images2/3OmariAkhmedov.jpg in style 6
# trying style number 6 for OmariAkhmedov
# saving: src/models/buildingMLModel/images2/4OmariAkhmedov.jpg in style 6
# trying style number 5 for DarrenStewart
# saving: src/models/buildingMLModel/images2/1DarrenStewart.jpg in style 5
# trying style number 5 for DarrenStewart
# saving: src/models/buildingMLModel/images2/2DarrenStewart.jpg in style 5
# trying style number 0 for DarrenStewart
# trying style number 1 for DarrenStewart
# saving: src/models/buildingMLModel/images2/3DarrenStewart.jpg in style 1
# trying style number 5 for DarrenStewart
# saving: src/models/buildingMLModel/images2/4DarrenStewart.jpg in style 5
# trying style number 5 for MakiPitolo
# saving: src/models/buildingMLModel/images2/1MakiPitolo.jpg in style 5
# trying style number 1 for MakiPitolo
# saving: src/models/buildingMLModel/images2/2MakiPitolo.jpg in style 1
# trying style number 4 for MakiPitolo
# trying style number 5 for MakiPitolo
# saving: src/models/buildingMLModel/images2/3MakiPitolo.jpg in style 5
# trying style number 1 for MakiPitolo
# saving: src/models/buildingMLModel/images2/4MakiPitolo.jpg in style 1
# trying style number 0 for YanaKunitskaya
# saving: src/models/buildingMLModel/images2/1YanaKunitskaya.jpg in style 0
# trying style number 3 for YanaKunitskaya
# saving: src/models/buildingMLModel/images2/2YanaKunitskaya.jpg in style 3
# trying style number 5 for YanaKunitskaya
# saving: src/models/buildingMLModel/images2/3YanaKunitskaya.jpg in style 5
# trying style number 2 for YanaKunitskaya
# saving: src/models/buildingMLModel/images2/4YanaKunitskaya.jpg in style 2
# trying style number 1 for JulijaStoliarenko
# saving: src/models/buildingMLModel/images2/1JulijaStoliarenko.jpg in style 1
# trying style number 0 for JulijaStoliarenko
# trying style number 1 for JulijaStoliarenko
# trying style number 2 for JulijaStoliarenko
# trying style number 3 for JulijaStoliarenko
# saving: src/models/buildingMLModel/images2/2JulijaStoliarenko.jpg in style 3
# trying style number 0 for JulijaStoliarenko
# saving: src/models/buildingMLModel/images2/3JulijaStoliarenko.jpg in style 0
# trying style number 1 for JulijaStoliarenko
# trying style number 2 for JulijaStoliarenko
# trying style number 3 for JulijaStoliarenko
# saving: src/models/buildingMLModel/images2/4JulijaStoliarenko.jpg in style 3
# trying style number 6 for BeneilDariush
# saving: src/models/buildingMLModel/images2/1BeneilDariush.jpg in style 6
# trying style number 3 for BeneilDariush
# saving: src/models/buildingMLModel/images2/2BeneilDariush.jpg in style 3
# trying style number 3 for BeneilDariush
# trying style number 4 for BeneilDariush
# saving: src/models/buildingMLModel/images2/3BeneilDariush.jpg in style 4
# trying style number 0 for BeneilDariush
# saving: src/models/buildingMLModel/images2/4BeneilDariush.jpg in style 0
# trying style number 4 for ScottHoltzman
# saving: src/models/buildingMLModel/images2/1ScottHoltzman.jpg in style 4
# trying style number 4 for ScottHoltzman
# trying style number 5 for ScottHoltzman
# saving: src/models/buildingMLModel/images2/2ScottHoltzman.jpg in style 5
# trying style number 4 for ScottHoltzman
# saving: src/models/buildingMLModel/images2/3ScottHoltzman.jpg in style 4
# trying style number 3 for ScottHoltzman
# trying style number 4 for ScottHoltzman
# saving: src/models/buildingMLModel/images2/4ScottHoltzman.jpg in style 4
# trying style number 1 for TimMeans
# saving: src/models/buildingMLModel/images2/1TimMeans.jpg in style 1
# trying style number 2 for TimMeans
# saving: src/models/buildingMLModel/images2/2TimMeans.jpg in style 2
# trying style number 5 for TimMeans
# saving: src/models/buildingMLModel/images2/3TimMeans.jpg in style 5
# trying style number 5 for TimMeans
# saving: src/models/buildingMLModel/images2/4TimMeans.jpg in style 5
# trying style number 2 for LaureanoStaropoli
# saving: src/models/buildingMLModel/images2/1LaureanoStaropoli.jpg in style 2
# trying style number 3 for LaureanoStaropoli
# saving: src/models/buildingMLModel/images2/2LaureanoStaropoli.jpg in style 3
# trying style number 0 for LaureanoStaropoli
# trying style number 1 for LaureanoStaropoli
# trying style number 2 for LaureanoStaropoli
# trying style number 3 for LaureanoStaropoli
# trying style number 4 for LaureanoStaropoli
# trying style number 5 for LaureanoStaropoli
# saving: src/models/buildingMLModel/images2/3LaureanoStaropoli.jpg in style 5
# trying style number 3 for LaureanoStaropoli
# saving: src/models/buildingMLModel/images2/4LaureanoStaropoli.jpg in style 3
# trying style number 5 for KevinHolland
# saving: src/models/buildingMLModel/images2/1KevinHolland.jpg in style 5
# trying style number 4 for KevinHolland
# trying style number 5 for KevinHolland
# trying style number 6 for KevinHolland
# trying style number 0 for KevinHolland
# trying style number 1 for KevinHolland
# saving: src/models/buildingMLModel/images2/2KevinHolland.jpg in style 1
# trying style number 2 for KevinHolland
# saving: src/models/buildingMLModel/images2/3KevinHolland.jpg in style 2
# trying style number 0 for KevinHolland
# trying style number 1 for KevinHolland
# saving: src/models/buildingMLModel/images2/4KevinHolland.jpg in style 1
# trying style number 6 for JoaquinBuckley
# saving: src/models/buildingMLModel/images2/1JoaquinBuckley.jpg in style 6
# trying style number 4 for JoaquinBuckley
# trying style number 5 for JoaquinBuckley
# saving: src/models/buildingMLModel/images2/2JoaquinBuckley.jpg in style 5
# trying style number 3 for JoaquinBuckley
# saving: src/models/buildingMLModel/images2/3JoaquinBuckley.jpg in style 3
# trying style number 4 for JoaquinBuckley
# trying style number 5 for JoaquinBuckley
# saving: src/models/buildingMLModel/images2/4JoaquinBuckley.jpg in style 5
# trying style number 6 for NasratHaqparast
# saving: src/models/buildingMLModel/images2/1NasratHaqparast.jpg in style 6
# trying style number 3 for NasratHaqparast
# saving: src/models/buildingMLModel/images2/2NasratHaqparast.jpg in style 3
# trying style number 5 for NasratHaqparast
# saving: src/models/buildingMLModel/images2/3NasratHaqparast.jpg in style 5
# trying style number 3 for NasratHaqparast
# saving: src/models/buildingMLModel/images2/4NasratHaqparast.jpg in style 3
# trying style number 4 for AlexanderMunoz
# saving: src/models/buildingMLModel/images2/1AlexanderMunoz.jpg in style 4
# trying style number 1 for AlexanderMunoz
# trying style number 2 for AlexanderMunoz
# trying style number 3 for AlexanderMunoz
# saving: src/models/buildingMLModel/images2/2AlexanderMunoz.jpg in style 3
# trying style number 5 for AlexanderMunoz
# trying style number 6 for AlexanderMunoz
# trying style number 0 for AlexanderMunoz
# trying style number 1 for AlexanderMunoz
# trying style number 2 for AlexanderMunoz
# trying style number 3 for AlexanderMunoz
# trying style number 4 for AlexanderMunoz
# trying style number 5 for AlexanderMunoz
# couldnt find a good style for 3AlexanderMunoz
# trying style number 2 for AlexanderMunoz
# saving: src/models/buildingMLModel/images2/4AlexanderMunoz.jpg in style 2
# trying style number 3 for AndrewSanchez
# saving: src/models/buildingMLModel/images2/1AndrewSanchez.jpg in style 3
# trying style number 3 for AndrewSanchez
# saving: src/models/buildingMLModel/images2/2AndrewSanchez.jpg in style 3
# trying style number 2 for AndrewSanchez
# saving: src/models/buildingMLModel/images2/3AndrewSanchez.jpg in style 2
# trying style number 6 for AndrewSanchez
# saving: src/models/buildingMLModel/images2/4AndrewSanchez.jpg in style 6
# trying style number 6 for WellingtonTurman
# saving: src/models/buildingMLModel/images2/1WellingtonTurman.jpg in style 6
# trying style number 1 for WellingtonTurman
# trying style number 2 for WellingtonTurman
# trying style number 3 for WellingtonTurman
# trying style number 4 for WellingtonTurman
# trying style number 5 for WellingtonTurman
# saving: src/models/buildingMLModel/images2/2WellingtonTurman.jpg in style 5
# trying style number 3 for WellingtonTurman
# trying style number 4 for WellingtonTurman
# trying style number 5 for WellingtonTurman
# saving: src/models/buildingMLModel/images2/3WellingtonTurman.jpg in style 5
# trying style number 5 for WellingtonTurman
# saving: src/models/buildingMLModel/images2/4WellingtonTurman.jpg in style 5
# trying style number 3 for GavinTucker
# saving: src/models/buildingMLModel/images2/1GavinTucker.jpg in style 3
# trying style number 5 for GavinTucker
# saving: src/models/buildingMLModel/images2/2GavinTucker.jpg in style 5
# trying style number 2 for GavinTucker
# trying style number 3 for GavinTucker
# saving: src/models/buildingMLModel/images2/3GavinTucker.jpg in style 3
# trying style number 4 for GavinTucker
# trying style number 5 for GavinTucker
# saving: src/models/buildingMLModel/images2/4GavinTucker.jpg in style 5
# trying style number 3 for JustinJaynes
# saving: src/models/buildingMLModel/images2/1JustinJaynes.jpg in style 3
# trying style number 0 for JustinJaynes
# saving: src/models/buildingMLModel/images2/2JustinJaynes.jpg in style 0
# trying style number 1 for JustinJaynes
# saving: src/models/buildingMLModel/images2/3JustinJaynes.jpg in style 1
# trying style number 5 for JustinJaynes
# saving: src/models/buildingMLModel/images2/4JustinJaynes.jpg in style 5
# trying style number 4 for YoussefZalal
# saving: src/models/buildingMLModel/images2/1YoussefZalal.jpg in style 4
# trying style number 6 for YoussefZalal
# saving: src/models/buildingMLModel/images2/2YoussefZalal.jpg in style 6
# trying style number 6 for YoussefZalal
# saving: src/models/buildingMLModel/images2/3YoussefZalal.jpg in style 6
# trying style number 6 for YoussefZalal
# saving: src/models/buildingMLModel/images2/4YoussefZalal.jpg in style 6
# trying style number 6 for PeterBarrett
# saving: src/models/buildingMLModel/images2/1PeterBarrett.jpg in style 6
# trying style number 3 for PeterBarrett
# trying style number 4 for PeterBarrett
# trying style number 5 for PeterBarrett
# saving: src/models/buildingMLModel/images2/2PeterBarrett.jpg in style 5
# trying style number 0 for PeterBarrett
# trying style number 1 for PeterBarrett
# trying style number 2 for PeterBarrett
# trying style number 3 for PeterBarrett
# saving: src/models/buildingMLModel/images2/3PeterBarrett.jpg in style 3
# trying style number 4 for PeterBarrett
# trying style number 5 for PeterBarrett
# saving: src/models/buildingMLModel/images2/4PeterBarrett.jpg in style 5
# trying style number 2 for IrwinRivera
# saving: src/models/buildingMLModel/images2/1IrwinRivera.jpg in style 2
# trying style number 1 for IrwinRivera
# trying style number 2 for IrwinRivera
# trying style number 3 for IrwinRivera
# trying style number 4 for IrwinRivera
# trying style number 5 for IrwinRivera
# saving: src/models/buildingMLModel/images2/2IrwinRivera.jpg in style 5
# trying style number 5 for IrwinRivera
# saving: src/models/buildingMLModel/images2/3IrwinRivera.jpg in style 5
# trying style number 4 for IrwinRivera
# saving: src/models/buildingMLModel/images2/4IrwinRivera.jpg in style 4
# trying style number 2 for AliAlQaisi
# trying style number 3 for AliAlQaisi
# saving: src/models/buildingMLModel/images2/1AliAlQaisi.jpg in style 3
# trying style number 0 for AliAlQaisi
# saving: src/models/buildingMLModel/images2/2AliAlQaisi.jpg in style 0
# trying style number 1 for AliAlQaisi
# trying style number 2 for AliAlQaisi
# trying style number 3 for AliAlQaisi
# trying style number 4 for AliAlQaisi
# trying style number 5 for AliAlQaisi
# saving: src/models/buildingMLModel/images2/3AliAlQaisi.jpg in style 5
# trying style number 5 for AliAlQaisi
# saving: src/models/buildingMLModel/images2/4AliAlQaisi.jpg in style 5
# trying style number 3 for DerekBrunson
# saving: src/models/buildingMLModel/images2/1DerekBrunson.jpg in style 3
# trying style number 1 for DerekBrunson
# saving: src/models/buildingMLModel/images2/2DerekBrunson.jpg in style 1
# trying style number 1 for DerekBrunson
# saving: src/models/buildingMLModel/images2/3DerekBrunson.jpg in style 1
# trying style number 1 for DerekBrunson
# trying style number 2 for DerekBrunson
# trying style number 3 for DerekBrunson
# trying style number 4 for DerekBrunson
# trying style number 5 for DerekBrunson
# saving: src/models/buildingMLModel/images2/4DerekBrunson.jpg in style 5
# trying style number 3 for EdmenShahbazyan
# saving: src/models/buildingMLModel/images2/1EdmenShahbazyan.jpg in style 3
# trying style number 0 for EdmenShahbazyan
# trying style number 1 for EdmenShahbazyan
# saving: src/models/buildingMLModel/images2/2EdmenShahbazyan.jpg in style 1
# trying style number 0 for EdmenShahbazyan
# trying style number 1 for EdmenShahbazyan
# saving: src/models/buildingMLModel/images2/3EdmenShahbazyan.jpg in style 1
# trying style number 0 for EdmenShahbazyan
# trying style number 1 for EdmenShahbazyan
# saving: src/models/buildingMLModel/images2/4EdmenShahbazyan.jpg in style 1
# trying style number 3 for JenniferMaia
# saving: src/models/buildingMLModel/images2/1JenniferMaia.jpg in style 3
# trying style number 5 for JenniferMaia
# saving: src/models/buildingMLModel/images2/2JenniferMaia.jpg in style 5
# trying style number 2 for JenniferMaia
# saving: src/models/buildingMLModel/images2/3JenniferMaia.jpg in style 2
# trying style number 1 for JenniferMaia
# saving: src/models/buildingMLModel/images2/4JenniferMaia.jpg in style 1
# trying style number 0 for JoanneCalderwood
# saving: src/models/buildingMLModel/images2/1JoanneCalderwood.jpg in style 0
# trying style number 6 for JoanneCalderwood
# saving: src/models/buildingMLModel/images2/2JoanneCalderwood.jpg in style 6
# trying style number 2 for JoanneCalderwood
# trying style number 3 for JoanneCalderwood
# saving: src/models/buildingMLModel/images2/3JoanneCalderwood.jpg in style 3
# trying style number 5 for JoanneCalderwood
# saving: src/models/buildingMLModel/images2/4JoanneCalderwood.jpg in style 5
# trying style number 3 for VicenteLuque
# saving: src/models/buildingMLModel/images2/1VicenteLuque.jpg in style 3
# trying style number 0 for VicenteLuque
# trying style number 1 for VicenteLuque
# saving: src/models/buildingMLModel/images2/2VicenteLuque.jpg in style 1
# trying style number 1 for VicenteLuque
# saving: src/models/buildingMLModel/images2/3VicenteLuque.jpg in style 1
# trying style number 1 for VicenteLuque
# saving: src/models/buildingMLModel/images2/4VicenteLuque.jpg in style 1
# trying style number 0 for RandyBrown
# saving: src/models/buildingMLModel/images2/1RandyBrown.jpg in style 0
# trying style number 1 for RandyBrown
# saving: src/models/buildingMLModel/images2/2RandyBrown.jpg in style 1
# trying style number 5 for RandyBrown
# saving: src/models/buildingMLModel/images2/3RandyBrown.jpg in style 5
# trying style number 4 for RandyBrown
# saving: src/models/buildingMLModel/images2/4RandyBrown.jpg in style 4
# trying style number 4 for BobbyGreen
# trying style number 5 for BobbyGreen
# saving: src/models/buildingMLModel/images2/1BobbyGreen.jpg in style 5
# trying style number 4 for BobbyGreen
# trying style number 5 for BobbyGreen
# saving: src/models/buildingMLModel/images2/2BobbyGreen.jpg in style 5
# trying style number 4 for BobbyGreen
# saving: src/models/buildingMLModel/images2/3BobbyGreen.jpg in style 4
# trying style number 1 for BobbyGreen
# saving: src/models/buildingMLModel/images2/4BobbyGreen.jpg in style 1
# trying style number 1 for LandoVannata
# saving: src/models/buildingMLModel/images2/1LandoVannata.jpg in style 1
# trying style number 4 for LandoVannata
# saving: src/models/buildingMLModel/images2/2LandoVannata.jpg in style 4
# trying style number 5 for LandoVannata
# saving: src/models/buildingMLModel/images2/3LandoVannata.jpg in style 5
# trying style number 6 for LandoVannata
# saving: src/models/buildingMLModel/images2/4LandoVannata.jpg in style 6

# %%
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#0-200 done... testing next 30 to see if there are any running poorly
#can run about 90 overnight
for name in names[230:250]:
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print(str(j)+' couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print(str(j)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            continue
# Out:
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:114: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 1 saving: src/models/buildingMLModel/images2/1JonathanMartinez.jpg in style 5
# 2 saving: src/models/buildingMLModel/images2/2JonathanMartinez.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3JonathanMartinez.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4JonathanMartinez.jpg in style 7
# 1 saving: src/models/buildingMLModel/images2/1FrankieSaenz.jpg in style 4
# 2 saving: src/models/buildingMLModel/images2/2FrankieSaenz.jpg in style 7
# 3 saving: src/models/buildingMLModel/images2/3FrankieSaenz.jpg in style 3
# 4 saving: src/models/buildingMLModel/images2/4FrankieSaenz.jpg in style 3
# 1 saving: src/models/buildingMLModel/images2/1NateManess.jpg in style 1
# 2 saving: src/models/buildingMLModel/images2/2NateManess.jpg in style 0
# 3 saving: src/models/buildingMLModel/images2/3NateManess.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4NateManess.jpg in style 7
# 1 saving: src/models/buildingMLModel/images2/1JohnnyMunoz.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2JohnnyMunoz.jpg in style 1
# 3 saving: src/models/buildingMLModel/images2/3JohnnyMunoz.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4JohnnyMunoz.jpg in style 7
# 1 saving: src/models/buildingMLModel/images2/1JamallEmmers.jpg in style 3
# 2 saving: src/models/buildingMLModel/images2/2JamallEmmers.jpg in style 2
# 3 saving: src/models/buildingMLModel/images2/3JamallEmmers.jpg in style 2
# 4 saving: src/models/buildingMLModel/images2/4JamallEmmers.jpg in style 3
# 1 saving: src/models/buildingMLModel/images2/1VinceCachero.jpg in style 5
# 2 saving: src/models/buildingMLModel/images2/2VinceCachero.jpg in style 2
# 3 saving: src/models/buildingMLModel/images2/3VinceCachero.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4VinceCachero.jpg in style 1
# 1 saving: src/models/buildingMLModel/images2/1ChrisGutierrez.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2ChrisGutierrez.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3ChrisGutierrez.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4ChrisGutierrez.jpg in style 2
# 1 saving: src/models/buildingMLModel/images2/1CodyDurden.jpg in style 5
# 2 saving: src/models/buildingMLModel/images2/2CodyDurden.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3CodyDurden.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4CodyDurden.jpg in style 1
# 1 saving: src/models/buildingMLModel/images2/1RobertWhittaker.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2RobertWhittaker.jpg in style 2
# 3 saving: src/models/buildingMLModel/images2/3RobertWhittaker.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4RobertWhittaker.jpg in style 0
# 1 saving: src/models/buildingMLModel/images2/1DarrenTill.jpg in style 1
# 2 saving: src/models/buildingMLModel/images2/2DarrenTill.jpg in style 3
# 3 saving: src/models/buildingMLModel/images2/3DarrenTill.jpg in style 7
# 4 saving: src/models/buildingMLModel/images2/4DarrenTill.jpg in style 7
# 1 saving: src/models/buildingMLModel/images2/1MauricioRua.jpg in style 1
# 2 saving: src/models/buildingMLModel/images2/2MauricioRua.jpg in style 3
# 3 saving: src/models/buildingMLModel/images2/3MauricioRua.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4MauricioRua.jpg in style 5
# 1 saving: src/models/buildingMLModel/images2/1RogerioNogueira.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2RogerioNogueira.jpg in style 7
# 3 saving: src/models/buildingMLModel/images2/3RogerioNogueira.jpg in style 3
# 4 saving: src/models/buildingMLModel/images2/4RogerioNogueira.jpg in style 5
# 1 saving: src/models/buildingMLModel/images2/1FabricioWerdum.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2FabricioWerdum.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3FabricioWerdum.jpg in style 2
# 4 saving: src/models/buildingMLModel/images2/4FabricioWerdum.jpg in style 1
# 1 saving: src/models/buildingMLModel/images2/1AlexanderGustafsson.jpg in style 5
# 2 saving: src/models/buildingMLModel/images2/2AlexanderGustafsson.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3AlexanderGustafsson.jpg in style 6
# 4 saving: src/models/buildingMLModel/images2/4AlexanderGustafsson.jpg in style 5
# 1 saving: src/models/buildingMLModel/images2/1CarlaEsparza.jpg in style 4
# 2 saving: src/models/buildingMLModel/images2/2CarlaEsparza.jpg in style 2
# 3 saving: src/models/buildingMLModel/images2/3CarlaEsparza.jpg in style 4
# 4 saving: src/models/buildingMLModel/images2/4CarlaEsparza.jpg in style 1
# 1 saving: src/models/buildingMLModel/images2/1MarinaRodriguez.jpg in style 6
# 2 saving: src/models/buildingMLModel/images2/2MarinaRodriguez.jpg in style 7
# 3 saving: src/models/buildingMLModel/images2/3MarinaRodriguez.jpg in style 6
# 4 saving: src/models/buildingMLModel/images2/4MarinaRodriguez.jpg in style 7
# 1 saving: src/models/buildingMLModel/images2/1PaulCraig.jpg in style 2
# 2 saving: src/models/buildingMLModel/images2/2PaulCraig.jpg in style 7
# 3 saving: src/models/buildingMLModel/images2/3PaulCraig.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4PaulCraig.jpg in style 0
# 1 saving: src/models/buildingMLModel/images2/1GadzhimuradAntigulov.jpg in style 1
# 2 saving: src/models/buildingMLModel/images2/2GadzhimuradAntigulov.jpg in style 3
# 3 saving: src/models/buildingMLModel/images2/3GadzhimuradAntigulov.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4GadzhimuradAntigulov.jpg in style 6
# 1 saving: src/models/buildingMLModel/images2/1AlexOliveira.jpg in style 7
# 2 saving: src/models/buildingMLModel/images2/2AlexOliveira.jpg in style 5
# 3 saving: src/models/buildingMLModel/images2/3AlexOliveira.jpg in style 5
# 4 saving: src/models/buildingMLModel/images2/4AlexOliveira.jpg in style 5
# 1 saving: src/models/buildingMLModel/images2/1PeterSobotta.jpg in style 5
# 2 saving: src/models/buildingMLModel/images2/2PeterSobotta.jpg in style 7
# 3 saving: src/models/buildingMLModel/images2/3PeterSobotta.jpg in style 1
# 4 saving: src/models/buildingMLModel/images2/4PeterSobotta.jpg in style 1

# %%
plt.figure()
imshow(output, title='Output Image')

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()

# %%
img1 = output
# img1 = img1.numpy() # TypeError: tensor or list of tensors expected, got <class 'numpy.ndarray'>
save_image(img1, 'img1.png')

# %%
fighterimage=Image.open("src/models/buildingMLModel/images/3AlexanderMunoz.jpg");fighterimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=162x101 at 0x1574A0CA0>

# %%
#to test the most recently added style image
fighterimage=fighterimage.resize((256,256))
content_img = image_loader(fighterimage)
input_img = content_img.clone()
output = run_style_transfer(cnn, cnn_normalization_mean, cnn_normalization_std,
                            content_img, style[-1], input_img)

plt.figure()
imshow(output, title='Output Image')

# sphinx_gallery_thumbnail_number = 4
plt.ioff()
plt.show()
# Out:
# Building the style transfer model..
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:114: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# Optimizing..
# run [50]:
# Style Loss : 48.677467 Content Loss: 24.331326
# run [100]:
# Style Loss : 12.180967 Content Loss: 22.458076
# run [150]:
# Style Loss : 5.507638 Content Loss: 20.124273
# run [200]:
# Style Loss : 3.353812 Content Loss: 18.208982
# run [250]:
# Style Loss : 2.498357 Content Loss: 16.713793
# run [300]:
# Style Loss : 1.956803 Content Loss: 15.549734

# %%
img1 = output
# img1 = img1.numpy() # TypeError: tensor or list of tensors expected, got <class 'numpy.ndarray'>
save_image(img1, "src/models/buildingMLModel/images2/3AlexanderMunoz.jpg")

# %%
[1,2,3,4,5,6,7,8,9,0][9:3:-1]
# Out:
# [0, 9, 8, 7, 6, 5]

# %%
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#0-200 done... testing next 30 to see if there are any running poorly
#can run about 90 overnight
i=len(names)
for name in names[len(names):2054:-1]:
    i-=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print(str(j)+' couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            continue
# Out:
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_21743/3183849233.py:114: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 2240 saving: src/models/buildingMLModel/images2/1TeilaTuli.jpg in style 7
# 2240 saving: src/models/buildingMLModel/images2/2TeilaTuli.jpg in style 1
# 2240 saving: src/models/buildingMLModel/images2/3TeilaTuli.jpg in style 2
# 2240 saving: src/models/buildingMLModel/images2/4TeilaTuli.jpg in style 1
# 2239 saving: src/models/buildingMLModel/images2/1ArtJimmerson.jpg in style 4
# 2239 saving: src/models/buildingMLModel/images2/2ArtJimmerson.jpg in style 7
# 2239 saving: src/models/buildingMLModel/images2/3ArtJimmerson.jpg in style 3
# 2239 saving: src/models/buildingMLModel/images2/4ArtJimmerson.jpg in style 5
# 2238 saving: src/models/buildingMLModel/images2/1KevinRosier.jpg in style 7
# 2238 saving: src/models/buildingMLModel/images2/2KevinRosier.jpg in style 5
# 2238 saving: src/models/buildingMLModel/images2/3KevinRosier.jpg in style 0
# 2238 saving: src/models/buildingMLModel/images2/4KevinRosier.jpg in style 6
# 2237 saving: src/models/buildingMLModel/images2/1TrentJenkins.jpg in style 7
# 2237 saving: src/models/buildingMLModel/images2/2TrentJenkins.jpg in style 1
# 2237 saving: src/models/buildingMLModel/images2/3TrentJenkins.jpg in style 6
# 2237 saving: src/models/buildingMLModel/images2/4TrentJenkins.jpg in style 1
# 2236 saving: src/models/buildingMLModel/images2/1GerardGordeau.jpg in style 7
# 2236 saving: src/models/buildingMLModel/images2/2GerardGordeau.jpg in style 2
# 2236 saving: src/models/buildingMLModel/images2/3GerardGordeau.jpg in style 3
# 2236 saving: src/models/buildingMLModel/images2/4GerardGordeau.jpg in style 6
# 2235 saving: src/models/buildingMLModel/images2/1SeanDaugherty.jpg in style 5
# 2235 saving: src/models/buildingMLModel/images2/2SeanDaugherty.jpg in style 7
# 2235 saving: src/models/buildingMLModel/images2/3SeanDaugherty.jpg in style 5
# 2235 saving: src/models/buildingMLModel/images2/4SeanDaugherty.jpg in style 1
# 2234 saving: src/models/buildingMLModel/images2/1RayWizard.jpg in style 1
# 2234 saving: src/models/buildingMLModel/images2/2RayWizard.jpg in style 1
# 2234 saving: src/models/buildingMLModel/images2/3RayWizard.jpg in style 7
# 2234 saving: src/models/buildingMLModel/images2/4RayWizard.jpg in style 0
# 2233 saving: src/models/buildingMLModel/images2/1DavidLevicki.jpg in style 5
# 2233 saving: src/models/buildingMLModel/images2/2DavidLevicki.jpg in style 1
# 2233 saving: src/models/buildingMLModel/images2/3DavidLevicki.jpg in style 1
# 2233 saving: src/models/buildingMLModel/images2/4DavidLevicki.jpg in style 7
# 2232 saving: src/models/buildingMLModel/images2/1ThaddeusLuster.jpg in style 3
# 2232 saving: src/models/buildingMLModel/images2/2ThaddeusLuster.jpg in style 6
# 2232 saving: src/models/buildingMLModel/images2/3ThaddeusLuster.jpg in style 7
# 2232 saving: src/models/buildingMLModel/images2/4ThaddeusLuster.jpg in style 5
# 2231 saving: src/models/buildingMLModel/images2/1FrankHamaker.jpg in style 7
# 2231 saving: src/models/buildingMLModel/images2/2FrankHamaker.jpg in style 7
# 2231 saving: src/models/buildingMLModel/images2/3FrankHamaker.jpg in style 5
# 2231 saving: src/models/buildingMLModel/images2/4FrankHamaker.jpg in style 4
# 2230 saving: src/models/buildingMLModel/images2/1RobertLucarelli.jpg in style 1
# 2230 saving: src/models/buildingMLModel/images2/2RobertLucarelli.jpg in style 1
# 2230 saving: src/models/buildingMLModel/images2/3RobertLucarelli.jpg in style 3
# 2230 saving: src/models/buildingMLModel/images2/4RobertLucarelli.jpg in style 7
# 2229 saving: src/models/buildingMLModel/images2/1AlbertaCerraLeon.jpg in style 5
# 2229 saving: src/models/buildingMLModel/images2/2AlbertaCerraLeon.jpg in style 7
# 2229 saving: src/models/buildingMLModel/images2/3AlbertaCerraLeon.jpg in style 7
# 2229 saving: src/models/buildingMLModel/images2/4AlbertaCerraLeon.jpg in style 5
# 2228 saving: src/models/buildingMLModel/images2/1ScottBaker.jpg in style 7
# 2228 saving: src/models/buildingMLModel/images2/2ScottBaker.jpg in style 5
# 2228 saving: src/models/buildingMLModel/images2/3ScottBaker.jpg in style 3
# 2228 saving: src/models/buildingMLModel/images2/4ScottBaker.jpg in style 2
# 2227 saving: src/models/buildingMLModel/images2/1MinokiIchihara.jpg in style 3
# 2227 saving: src/models/buildingMLModel/images2/2MinokiIchihara.jpg in style 1
# 2227 saving: src/models/buildingMLModel/images2/3MinokiIchihara.jpg in style 0
# 2227 saving: src/models/buildingMLModel/images2/4MinokiIchihara.jpg in style 7
# 2226 saving: src/models/buildingMLModel/images2/1ScottMorris.jpg in style 6
# 2226 saving: src/models/buildingMLModel/images2/2ScottMorris.jpg in style 1
# 2226 saving: src/models/buildingMLModel/images2/3ScottMorris.jpg in style 6
# 2226 saving: src/models/buildingMLModel/images2/4ScottMorris.jpg in style 1
# 2225 saving: src/models/buildingMLModel/images2/1FredEttish.jpg in style 3
# 2225 saving: src/models/buildingMLModel/images2/2FredEttish.jpg in style 2
# 2225 saving: src/models/buildingMLModel/images2/3FredEttish.jpg in style 6
# 2225 saving: src/models/buildingMLModel/images2/4FredEttish.jpg in style 3
# 2224 saving: src/models/buildingMLModel/images2/1OrlandoWiet.jpg in style 5
# 2224 saving: src/models/buildingMLModel/images2/2OrlandoWiet.jpg in style 3
# 2224 saving: src/models/buildingMLModel/images2/3OrlandoWiet.jpg in style 5
# 2224 saving: src/models/buildingMLModel/images2/4OrlandoWiet.jpg in style 6
# 2223 saving: src/models/buildingMLModel/images2/1JohnnyRhodes.jpg in style 1
# 2223 saving: src/models/buildingMLModel/images2/2JohnnyRhodes.jpg in style 7
# 2223 saving: src/models/buildingMLModel/images2/3JohnnyRhodes.jpg in style 3
# 2223 saving: src/models/buildingMLModel/images2/4JohnnyRhodes.jpg in style 3
# 2222 saving: src/models/buildingMLModel/images2/1EmmanuelYarborough.jpg in style 7
# 2222 saving: src/models/buildingMLModel/images2/2EmmanuelYarborough.jpg in style 7
# 2222 saving: src/models/buildingMLModel/images2/3EmmanuelYarborough.jpg in style 2
# 2222 saving: src/models/buildingMLModel/images2/4EmmanuelYarborough.jpg in style 1
# 2221 saving: src/models/buildingMLModel/images2/1RolandPayne.jpg in style 3
# 2221 saving: src/models/buildingMLModel/images2/2RolandPayne.jpg in style 3
# 2221 saving: src/models/buildingMLModel/images2/3RolandPayne.jpg in style 1
# 2221 saving: src/models/buildingMLModel/images2/4RolandPayne.jpg in style 5
# 2220 saving: src/models/buildingMLModel/images2/1FelixLeeMitchell.jpg in style 4
# 2220 saving: src/models/buildingMLModel/images2/2FelixLeeMitchell.jpg in style 5
# 2220 saving: src/models/buildingMLModel/images2/3FelixLeeMitchell.jpg in style 1
# 2220 saving: src/models/buildingMLModel/images2/4FelixLeeMitchell.jpg in style 6
# 2219 saving: src/models/buildingMLModel/images2/1JasonFairn.jpg in style 3
# 2219 saving: src/models/buildingMLModel/images2/2JasonFairn.jpg in style 7
# 2219 saving: src/models/buildingMLModel/images2/3JasonFairn.jpg in style 6
# 2219 saving: src/models/buildingMLModel/images2/4JasonFairn.jpg in style 1
# 2218 saving: src/models/buildingMLModel/images2/1RonvanClief.jpg in style 7
# 2218 saving: src/models/buildingMLModel/images2/2RonvanClief.jpg in style 3
# 2218 saving: src/models/buildingMLModel/images2/3RonvanClief.jpg in style 6
# 2218 saving: src/models/buildingMLModel/images2/4RonvanClief.jpg in style 1
# 2217 saving: src/models/buildingMLModel/images2/1JoeSon.jpg in style 5
# 2217 saving: src/models/buildingMLModel/images2/2JoeSon.jpg in style 1
# 2217 saving: src/models/buildingMLModel/images2/3JoeSon.jpg in style 6
# 2217 saving: src/models/buildingMLModel/images2/4JoeSon.jpg in style 3
# 2216 saving: src/models/buildingMLModel/images2/1MeltonBowen.jpg in style 3
# 2216 saving: src/models/buildingMLModel/images2/2MeltonBowen.jpg in style 5
# 2216 saving: src/models/buildingMLModel/images2/3MeltonBowen.jpg in style 3
# 2216 saving: src/models/buildingMLModel/images2/4MeltonBowen.jpg in style 1
# 2215 saving: src/models/buildingMLModel/images2/1MarcusBossett.jpg in style 3
# 2215 saving: src/models/buildingMLModel/images2/2MarcusBossett.jpg in style 4
# 2215 saving: src/models/buildingMLModel/images2/3MarcusBossett.jpg in style 7
# 2215 saving: src/models/buildingMLModel/images2/4MarcusBossett.jpg in style 5
# 2214 saving: src/models/buildingMLModel/images2/1AsbelCancio.jpg in style 1
# 2214 saving: src/models/buildingMLModel/images2/2AsbelCancio.jpg in style 5
# 2214 saving: src/models/buildingMLModel/images2/3AsbelCancio.jpg in style 5
# 2214 saving: src/models/buildingMLModel/images2/4AsbelCancio.jpg in style 6
# 2213 saving: src/models/buildingMLModel/images2/1JohnDowdy.jpg in style 7
# 2213 saving: src/models/buildingMLModel/images2/2JohnDowdy.jpg in style 1
# 2213 saving: src/models/buildingMLModel/images2/3JohnDowdy.jpg in style 1
# 2213 saving: src/models/buildingMLModel/images2/4JohnDowdy.jpg in style 5
# 2212 saving: src/models/buildingMLModel/images2/1AndyAnderson.jpg in style 3
# 2212 saving: src/models/buildingMLModel/images2/2AndyAnderson.jpg in style 5
# 2212 saving: src/models/buildingMLModel/images2/3AndyAnderson.jpg in style 1
# 2212 saving: src/models/buildingMLModel/images2/4AndyAnderson.jpg in style 3
# 2211 saving: src/models/buildingMLModel/images2/1JonHess.jpg in style 5
# 2211 saving: src/models/buildingMLModel/images2/2JonHess.jpg in style 3
# 2211 saving: src/models/buildingMLModel/images2/3JonHess.jpg in style 1
# 2211 saving: src/models/buildingMLModel/images2/4JonHess.jpg in style 3
# 2210 saving: src/models/buildingMLModel/images2/1ErnieVerdicia.jpg in style 5
# 2210 saving: src/models/buildingMLModel/images2/2ErnieVerdicia.jpg in style 3
# 2210 saving: src/models/buildingMLModel/images2/3ErnieVerdicia.jpg in style 3
# 2210 saving: src/models/buildingMLModel/images2/4ErnieVerdicia.jpg in style 3
# 2209 saving: src/models/buildingMLModel/images2/1ToddMedina.jpg in style 1
# 2209 saving: src/models/buildingMLModel/images2/2ToddMedina.jpg in style 7
# 2209 saving: src/models/buildingMLModel/images2/3ToddMedina.jpg in style 5
# 2209 saving: src/models/buildingMLModel/images2/4ToddMedina.jpg in style 3
# 2208 saving: src/models/buildingMLModel/images2/1JohnMatua.jpg in style 1
# 2207 saving: src/models/buildingMLModel/images2/1RudyardMoncayo.jpg in style 3
# 2207 saving: src/models/buildingMLModel/images2/2RudyardMoncayo.jpg in style 1
# 2207 saving: src/models/buildingMLModel/images2/3RudyardMoncayo.jpg in style 0
# 2207 saving: src/models/buildingMLModel/images2/4RudyardMoncayo.jpg in style 1
# 2206 saving: src/models/buildingMLModel/images2/1PatrickSmith.jpg in style 5
# 2206 saving: src/models/buildingMLModel/images2/2PatrickSmith.jpg in style 3
# 2206 saving: src/models/buildingMLModel/images2/3PatrickSmith.jpg in style 7
# 2206 saving: src/models/buildingMLModel/images2/4PatrickSmith.jpg in style 7
# 2205 saving: src/models/buildingMLModel/images2/1AnthonyMacias.jpg in style 5
# 2205 saving: src/models/buildingMLModel/images2/2AnthonyMacias.jpg in style 5
# 2205 saving: src/models/buildingMLModel/images2/3AnthonyMacias.jpg in style 3
# 2205 saving: src/models/buildingMLModel/images2/4AnthonyMacias.jpg in style 4
# 2204 saving: src/models/buildingMLModel/images2/1DavidHood.jpg in style 3
# 2204 saving: src/models/buildingMLModel/images2/2DavidHood.jpg in style 1
# 2204 saving: src/models/buildingMLModel/images2/3DavidHood.jpg in style 5
# 2204 saving: src/models/buildingMLModel/images2/4DavidHood.jpg in style 6
# 2203 saving: src/models/buildingMLModel/images2/1ScottBessac.jpg in style 1
# 2203 saving: src/models/buildingMLModel/images2/2ScottBessac.jpg in style 4
# 2203 saving: src/models/buildingMLModel/images2/3ScottBessac.jpg in style 5
# 2203 saving: src/models/buildingMLModel/images2/4ScottBessac.jpg in style 5
# 2202 saving: src/models/buildingMLModel/images2/1GerryHarris.jpg in style 1
# 2202 saving: src/models/buildingMLModel/images2/2GerryHarris.jpg in style 6
# 2202 saving: src/models/buildingMLModel/images2/3GerryHarris.jpg in style 6
# 2202 saving: src/models/buildingMLModel/images2/4GerryHarris.jpg in style 5
# 2201 saving: src/models/buildingMLModel/images2/1HaroldHoward.jpg in style 6
# 2201 saving: src/models/buildingMLModel/images2/2HaroldHoward.jpg in style 1
# 2201 saving: src/models/buildingMLModel/images2/3HaroldHoward.jpg in style 2
# 2201 saving: src/models/buildingMLModel/images2/4HaroldHoward.jpg in style 1
# 2200 saving: src/models/buildingMLModel/images2/1RyanParker.jpg in style 3
# 2200 saving: src/models/buildingMLModel/images2/2RyanParker.jpg in style 3
# 2200 saving: src/models/buildingMLModel/images2/3RyanParker.jpg in style 7
# 2200 saving: src/models/buildingMLModel/images2/4RyanParker.jpg in style 0
# 2199 saving: src/models/buildingMLModel/images2/1LarryCureton.jpg in style 6
# 2199 saving: src/models/buildingMLModel/images2/2LarryCureton.jpg in style 5
# 2199 saving: src/models/buildingMLModel/images2/3LarryCureton.jpg in style 5
# 2199 saving: src/models/buildingMLModel/images2/4LarryCureton.jpg in style 3
# 2198 saving: src/models/buildingMLModel/images2/1RemcoPardoel.jpg in style 6
# 2198 saving: src/models/buildingMLModel/images2/2RemcoPardoel.jpg in style 6
# 2198 saving: src/models/buildingMLModel/images2/3RemcoPardoel.jpg in style 5
# 2198 saving: src/models/buildingMLModel/images2/4RemcoPardoel.jpg in style 7
# 2197 saving: src/models/buildingMLModel/images2/1SteveJennum.jpg in style 3
# 2197 saving: src/models/buildingMLModel/images2/2SteveJennum.jpg in style 3
# 2197 saving: src/models/buildingMLModel/images2/3SteveJennum.jpg in style 3
# 2197 saving: src/models/buildingMLModel/images2/4SteveJennum.jpg in style 7
# 2196 saving: src/models/buildingMLModel/images2/1KeithHackney.jpg in style 4
# 2196 saving: src/models/buildingMLModel/images2/2KeithHackney.jpg in style 3
# 2196 saving: src/models/buildingMLModel/images2/3KeithHackney.jpg in style 5
# 2196 saving: src/models/buildingMLModel/images2/4KeithHackney.jpg in style 5
# 2195 saving: src/models/buildingMLModel/images2/1OlegTaktarov.jpg in style 6
# 2195 saving: src/models/buildingMLModel/images2/2OlegTaktarov.jpg in style 5
# 2195 saving: src/models/buildingMLModel/images2/3OlegTaktarov.jpg in style 1
# 2195 saving: src/models/buildingMLModel/images2/4OlegTaktarov.jpg in style 5
# 2194 saving: src/models/buildingMLModel/images2/1ThomasRamirez.jpg in style 5
# 2194 saving: src/models/buildingMLModel/images2/2ThomasRamirez.jpg in style 5
# 2194 saving: src/models/buildingMLModel/images2/3ThomasRamirez.jpg in style 5
# 2194 saving: src/models/buildingMLModel/images2/4ThomasRamirez.jpg in style 3
# 2193 saving: src/models/buildingMLModel/images2/1PaulHerrera.jpg in style 6
# 2193 saving: src/models/buildingMLModel/images2/2PaulHerrera.jpg in style 0
# 2193 saving: src/models/buildingMLModel/images2/3PaulHerrera.jpg in style 6
# 2193 saving: src/models/buildingMLModel/images2/4PaulHerrera.jpg in style 4
# 2192 saving: src/models/buildingMLModel/images2/1TaiBowden.jpg in style 7
# 2192 saving: src/models/buildingMLModel/images2/2TaiBowden.jpg in style 2
# 2192 saving: src/models/buildingMLModel/images2/3TaiBowden.jpg in style 3
# 2192 saving: src/models/buildingMLModel/images2/4TaiBowden.jpg in style 6
# 2191 saving: src/models/buildingMLModel/images2/1ZaneFrazier.jpg in style 3
# 2191 saving: src/models/buildingMLModel/images2/2ZaneFrazier.jpg in style 7
# 2191 saving: src/models/buildingMLModel/images2/3ZaneFrazier.jpg in style 5
# 2191 saving: src/models/buildingMLModel/images2/4ZaneFrazier.jpg in style 2
# 2190 saving: src/models/buildingMLModel/images2/1MattAndersen.jpg in style 1
# 2190 saving: src/models/buildingMLModel/images2/2MattAndersen.jpg in style 1
# 2190 saving: src/models/buildingMLModel/images2/3MattAndersen.jpg in style 5
# 2190 saving: src/models/buildingMLModel/images2/4MattAndersen.jpg in style 1
# 2189 saving: src/models/buildingMLModel/images2/1RafaelCarino.jpg in style 5
# 2189 saving: src/models/buildingMLModel/images2/2RafaelCarino.jpg in style 6
# 2189 saving: src/models/buildingMLModel/images2/3RafaelCarino.jpg in style 1
# 2189 saving: src/models/buildingMLModel/images2/4RafaelCarino.jpg in style 1
# 2188 saving: src/models/buildingMLModel/images2/1MarkSchultz.jpg in style 1
# 2188 saving: src/models/buildingMLModel/images2/2MarkSchultz.jpg in style 1
# 2188 saving: src/models/buildingMLModel/images2/3MarkSchultz.jpg in style 7
# 2188 saving: src/models/buildingMLModel/images2/4MarkSchultz.jpg in style 0
# 2187 saving: src/models/buildingMLModel/images2/1KojiKitao.jpg in style 3
# 2187 saving: src/models/buildingMLModel/images2/2KojiKitao.jpg in style 3
# 2187 saving: src/models/buildingMLModel/images2/3KojiKitao.jpg in style 5
# 2187 saving: src/models/buildingMLModel/images2/4KojiKitao.jpg in style 7
# 2186 saving: src/models/buildingMLModel/images2/1DieuselBerto.jpg in style 2
# 2186 saving: src/models/buildingMLModel/images2/2DieuselBerto.jpg in style 5
# 2186 saving: src/models/buildingMLModel/images2/3DieuselBerto.jpg in style 3
# 2186 saving: src/models/buildingMLModel/images2/4DieuselBerto.jpg in style 4
# 2185 saving: src/models/buildingMLModel/images2/1GezaKalman.jpg in style 1
# 2185 saving: src/models/buildingMLModel/images2/2GezaKalman.jpg in style 1
# 2185 saving: src/models/buildingMLModel/images2/3GezaKalman.jpg in style 2
# 2185 saving: src/models/buildingMLModel/images2/4GezaKalman.jpg in style 3
# 2184 saving: src/models/buildingMLModel/images2/1ScottFiedler.jpg in style 3
# 2184 saving: src/models/buildingMLModel/images2/2ScottFiedler.jpg in style 1
# 2184 saving: src/models/buildingMLModel/images2/3ScottFiedler.jpg in style 5
# 2184 saving: src/models/buildingMLModel/images2/4ScottFiedler.jpg in style 6
# 2183 saving: src/models/buildingMLModel/images2/1JohnCampetella.jpg in style 3
# 2183 saving: src/models/buildingMLModel/images2/2JohnCampetella.jpg in style 3
# 2183 saving: src/models/buildingMLModel/images2/3JohnCampetella.jpg in style 6
# 2183 saving: src/models/buildingMLModel/images2/4JohnCampetella.jpg in style 5
# 2182 saving: src/models/buildingMLModel/images2/1JulianSanchez.jpg in style 1
# 2182 saving: src/models/buildingMLModel/images2/2JulianSanchez.jpg in style 7
# 2182 saving: src/models/buildingMLModel/images2/3JulianSanchez.jpg in style 7
# 2182 saving: src/models/buildingMLModel/images2/4JulianSanchez.jpg in style 3
# 2181 saving: src/models/buildingMLModel/images2/1RezaNasri.jpg in style 1
# 2181 saving: src/models/buildingMLModel/images2/2RezaNasri.jpg in style 7
# 2181 saving: src/models/buildingMLModel/images2/3RezaNasri.jpg in style 3
# 2181 saving: src/models/buildingMLModel/images2/4RezaNasri.jpg in style 3
# 2180 saving: src/models/buildingMLModel/images2/1SamAdkins.jpg in style 3
# 2180 saving: src/models/buildingMLModel/images2/2SamAdkins.jpg in style 7
# 2180 saving: src/models/buildingMLModel/images2/3SamAdkins.jpg in style 1
# 2180 saving: src/models/buildingMLModel/images2/4SamAdkins.jpg in style 6
# 2179 saving: src/models/buildingMLModel/images2/1FabioGurgel.jpg in style 3
# 2179 saving: src/models/buildingMLModel/images2/2FabioGurgel.jpg in style 3
# 2179 saving: src/models/buildingMLModel/images2/3FabioGurgel.jpg in style 1
# 2179 saving: src/models/buildingMLModel/images2/4FabioGurgel.jpg in style 2
# 2178 saving: src/models/buildingMLModel/images2/1CalWorsham.jpg in style 4
# 2178 saving: src/models/buildingMLModel/images2/2CalWorsham.jpg in style 3
# 2178 saving: src/models/buildingMLModel/images2/3CalWorsham.jpg in style 1
# 2178 saving: src/models/buildingMLModel/images2/4CalWorsham.jpg in style 2
# 2177 saving: src/models/buildingMLModel/images2/1PaulVarelans.jpg in style 5
# 2177 saving: src/models/buildingMLModel/images2/2PaulVarelans.jpg in style 6
# 2177 saving: src/models/buildingMLModel/images2/3PaulVarelans.jpg in style 6
# 2177 saving: src/models/buildingMLModel/images2/4PaulVarelans.jpg in style 5
# 2176 saving: src/models/buildingMLModel/images2/1MarkHall.jpg in style 6
# 2176 saving: src/models/buildingMLModel/images2/2MarkHall.jpg in style 5
# 2176 saving: src/models/buildingMLModel/images2/3MarkHall.jpg in style 1
# 2176 saving: src/models/buildingMLModel/images2/4MarkHall.jpg in style 1
# 2175 saving: src/models/buildingMLModel/images2/1SteveNelmark.jpg in style 3
# 2175 saving: src/models/buildingMLModel/images2/2SteveNelmark.jpg in style 5
# 2175 saving: src/models/buildingMLModel/images2/3SteveNelmark.jpg in style 7
# 2175 saving: src/models/buildingMLModel/images2/4SteveNelmark.jpg in style 6
# 2174 saving: src/models/buildingMLModel/images2/1DonFrye.jpg in style 4
# 2174 saving: src/models/buildingMLModel/images2/2DonFrye.jpg in style 1
# 2174 saving: src/models/buildingMLModel/images2/3DonFrye.jpg in style 1
# 2174 saving: src/models/buildingMLModel/images2/4DonFrye.jpg in style 4
# 2173 saving: src/models/buildingMLModel/images2/1RainyMartinez.jpg in style 5
# 2173 saving: src/models/buildingMLModel/images2/2RainyMartinez.jpg in style 1
# 2173 saving: src/models/buildingMLModel/images2/3RainyMartinez.jpg in style 5
# 2173 saving: src/models/buildingMLModel/images2/4RainyMartinez.jpg in style 1
# 2172 saving: src/models/buildingMLModel/images2/1WallidIsmail.jpg in style 6
# 2172 saving: src/models/buildingMLModel/images2/2WallidIsmail.jpg in style 1
# 2172 saving: src/models/buildingMLModel/images2/3WallidIsmail.jpg in style 1
# 2172 saving: src/models/buildingMLModel/images2/4WallidIsmail.jpg in style 6
# 2171 saving: src/models/buildingMLModel/images2/1YoshikiTakahashi.jpg in style 4
# 2171 saving: src/models/buildingMLModel/images2/2YoshikiTakahashi.jpg in style 4
# 2171 saving: src/models/buildingMLModel/images2/3YoshikiTakahashi.jpg in style 1
# 2171 saving: src/models/buildingMLModel/images2/4YoshikiTakahashi.jpg in style 6
# 2170 saving: src/models/buildingMLModel/images2/1JimMullen.jpg in style 7
# 2170 saving: src/models/buildingMLModel/images2/2JimMullen.jpg in style 5
# 2170 saving: src/models/buildingMLModel/images2/3JimMullen.jpg in style 6
# 2170 saving: src/models/buildingMLModel/images2/4JimMullen.jpg in style 4
# 2169 saving: src/models/buildingMLModel/images2/1NickSanzo.jpg in style 2
# 2169 saving: src/models/buildingMLModel/images2/2NickSanzo.jpg in style 3
# 2169 saving: src/models/buildingMLModel/images2/3NickSanzo.jpg in style 5
# 2169 saving: src/models/buildingMLModel/images2/4NickSanzo.jpg in style 5
# 2168 saving: src/models/buildingMLModel/images2/1ScottFerrozzo.jpg in style 3
# 2168 saving: src/models/buildingMLModel/images2/2ScottFerrozzo.jpg in style 1
# 2168 saving: src/models/buildingMLModel/images2/3ScottFerrozzo.jpg in style 0
# 2168 saving: src/models/buildingMLModel/images2/4ScottFerrozzo.jpg in style 1
# 2167 saving: src/models/buildingMLModel/images2/1WesAlbritton.jpg in style 5
# 2167 saving: src/models/buildingMLModel/images2/2WesAlbritton.jpg in style 6
# 2167 saving: src/models/buildingMLModel/images2/3WesAlbritton.jpg in style 5
# 2167 saving: src/models/buildingMLModel/images2/4WesAlbritton.jpg in style 7
# 2166 saving: src/models/buildingMLModel/images2/1SaeedHosseini.jpg in style 5
# 2166 saving: src/models/buildingMLModel/images2/2SaeedHosseini.jpg in style 2
# 2166 saving: src/models/buildingMLModel/images2/3SaeedHosseini.jpg in style 5
# 2166 saving: src/models/buildingMLModel/images2/4SaeedHosseini.jpg in style 4
# 2165 saving: src/models/buildingMLModel/images2/1JackNilson.jpg in style 7
# 2165 saving: src/models/buildingMLModel/images2/2JackNilson.jpg in style 1
# 2165 saving: src/models/buildingMLModel/images2/3JackNilson.jpg in style 7
# 2165 saving: src/models/buildingMLModel/images2/4JackNilson.jpg in style 4
# 2164 saving: src/models/buildingMLModel/images2/1ChristopheLeninger.jpg in style 6
# 2164 saving: src/models/buildingMLModel/images2/2ChristopheLeninger.jpg in style 2
# 2164 saving: src/models/buildingMLModel/images2/3ChristopheLeninger.jpg in style 3
# 2164 saving: src/models/buildingMLModel/images2/4ChristopheLeninger.jpg in style 2
# 2163 saving: src/models/buildingMLModel/images2/1EnsonInoue.jpg in style 1
# 2163 saving: src/models/buildingMLModel/images2/2EnsonInoue.jpg in style 7
# 2163 saving: src/models/buildingMLModel/images2/3EnsonInoue.jpg in style 2
# 2163 saving: src/models/buildingMLModel/images2/4EnsonInoue.jpg in style 2
# 2162 saving: src/models/buildingMLModel/images2/1DmitriStepanov.jpg in style 6
# 2162 saving: src/models/buildingMLModel/images2/2DmitriStepanov.jpg in style 1
# 2162 saving: src/models/buildingMLModel/images2/3DmitriStepanov.jpg in style 6
# 2162 saving: src/models/buildingMLModel/images2/4DmitriStepanov.jpg in style 4
# 2161 saving: src/models/buildingMLModel/images2/1TonyHalme.jpg in style 1
# 2161 saving: src/models/buildingMLModel/images2/2TonyHalme.jpg in style 1
# 2161 saving: src/models/buildingMLModel/images2/3TonyHalme.jpg in style 6
# 2161 saving: src/models/buildingMLModel/images2/4TonyHalme.jpg in style 4
# 2160 saving: src/models/buildingMLModel/images2/1StevenGraham.jpg in style 1
# 2160 saving: src/models/buildingMLModel/images2/2StevenGraham.jpg in style 1
# 2160 saving: src/models/buildingMLModel/images2/3StevenGraham.jpg in style 2
# 2160 saving: src/models/buildingMLModel/images2/4StevenGraham.jpg in style 6
# 2159 saving: src/models/buildingMLModel/images2/1DonnieChappell.jpg in style 5
# 2159 saving: src/models/buildingMLModel/images2/2DonnieChappell.jpg in style 2
# 2159 saving: src/models/buildingMLModel/images2/3DonnieChappell.jpg in style 2
# 2159 saving: src/models/buildingMLModel/images2/4DonnieChappell.jpg in style 4
# 2158 saving: src/models/buildingMLModel/images2/1SamFulton.jpg in style 3
# 2158 saving: src/models/buildingMLModel/images2/2SamFulton.jpg in style 6
# 2158 saving: src/models/buildingMLModel/images2/3SamFulton.jpg in style 1
# 2158 saving: src/models/buildingMLModel/images2/4SamFulton.jpg in style 3
# 2157 saving: src/models/buildingMLModel/images2/1YuriVaulin.jpg in style 5
# 2157 saving: src/models/buildingMLModel/images2/2YuriVaulin.jpg in style 5
# 2157 saving: src/models/buildingMLModel/images2/3YuriVaulin.jpg in style 5
# 2157 saving: src/models/buildingMLModel/images2/4YuriVaulin.jpg in style 7
# 2156 saving: src/models/buildingMLModel/images2/1JoeMoreira.jpg in style 5
# 2156 saving: src/models/buildingMLModel/images2/2JoeMoreira.jpg in style 5
# 2156 saving: src/models/buildingMLModel/images2/3JoeMoreira.jpg in style 4
# 2156 saving: src/models/buildingMLModel/images2/4JoeMoreira.jpg in style 7
# 2155 saving: src/models/buildingMLModel/images2/1ToddButler.jpg in style 7
# 2155 saving: src/models/buildingMLModel/images2/2ToddButler.jpg in style 5
# 2155 saving: src/models/buildingMLModel/images2/3ToddButler.jpg in style 5
# 2155 saving: src/models/buildingMLModel/images2/4ToddButler.jpg in style 3
# 2154 saving: src/models/buildingMLModel/images2/1MotiHorenstein.jpg in style 3
# 2154 saving: src/models/buildingMLModel/images2/2MotiHorenstein.jpg in style 6
# 2154 saving: src/models/buildingMLModel/images2/3MotiHorenstein.jpg in style 7
# 2154 saving: src/models/buildingMLModel/images2/4MotiHorenstein.jpg in style 7
# 2153 saving: src/models/buildingMLModel/images2/1BrianJohnston.jpg in style 5
# 2153 saving: src/models/buildingMLModel/images2/2BrianJohnston.jpg in style 3
# 2153 saving: src/models/buildingMLModel/images2/3BrianJohnston.jpg in style 1
# 2153 saving: src/models/buildingMLModel/images2/4BrianJohnston.jpg in style 6
# 2152 saving: src/models/buildingMLModel/images2/1DanBobish.jpg in style 3
# 2152 saving: src/models/buildingMLModel/images2/2DanBobish.jpg in style 5
# 2152 saving: src/models/buildingMLModel/images2/3DanBobish.jpg in style 7
# 2152 saving: src/models/buildingMLModel/images2/4DanBobish.jpg in style 1
# 2151 saving: src/models/buildingMLModel/images2/1HarryMoskowitz.jpg in style 1
# 2151 saving: src/models/buildingMLModel/images2/2HarryMoskowitz.jpg in style 5
# 2151 saving: src/models/buildingMLModel/images2/3HarryMoskowitz.jpg in style 4
# 2151 saving: src/models/buildingMLModel/images2/4HarryMoskowitz.jpg in style 5
# 2150 saving: src/models/buildingMLModel/images2/1AlexHunter.jpg in style 2
# 2150 saving: src/models/buildingMLModel/images2/2AlexHunter.jpg in style 2
# 2150 saving: src/models/buildingMLModel/images2/3AlexHunter.jpg in style 1
# 2150 saving: src/models/buildingMLModel/images2/4AlexHunter.jpg in style 0
# 2149 saving: src/models/buildingMLModel/images2/1HoustonDorr.jpg in style 1
# 2149 saving: src/models/buildingMLModel/images2/2HoustonDorr.jpg in style 4
# 2149 saving: src/models/buildingMLModel/images2/3HoustonDorr.jpg in style 5
# 2149 saving: src/models/buildingMLModel/images2/4HoustonDorr.jpg in style 7
# 2148 saving: src/models/buildingMLModel/images2/1GregStott.jpg in style 7
# 2148 saving: src/models/buildingMLModel/images2/2GregStott.jpg in style 1
# 2148 saving: src/models/buildingMLModel/images2/3GregStott.jpg in style 7
# 2148 saving: src/models/buildingMLModel/images2/4GregStott.jpg in style 1
# 2147 saving: src/models/buildingMLModel/images2/1CarlosBarreto.jpg in style 6
# 2147 saving: src/models/buildingMLModel/images2/2CarlosBarreto.jpg in style 3
# 2147 saving: src/models/buildingMLModel/images2/3CarlosBarreto.jpg in style 3
# 2147 saving: src/models/buildingMLModel/images2/4CarlosBarreto.jpg in style 7
# 2146 saving: src/models/buildingMLModel/images2/1DaveBeneteau.jpg in style 3
# 2146 saving: src/models/buildingMLModel/images2/2DaveBeneteau.jpg in style 6
# 2146 saving: src/models/buildingMLModel/images2/3DaveBeneteau.jpg in style 1
# 2146 saving: src/models/buildingMLModel/images2/4DaveBeneteau.jpg in style 0
# 2145 saving: src/models/buildingMLModel/images2/1DwayneCason.jpg in style 6
# 2145 saving: src/models/buildingMLModel/images2/2DwayneCason.jpg in style 3
# 2145 saving: src/models/buildingMLModel/images2/3DwayneCason.jpg in style 5
# 2145 saving: src/models/buildingMLModel/images2/4DwayneCason.jpg in style 1
# 2144 saving: src/models/buildingMLModel/images2/1MarkKerr.jpg in style 2
# 2144 saving: src/models/buildingMLModel/images2/2MarkKerr.jpg in style 7
# 2144 saving: src/models/buildingMLModel/images2/3MarkKerr.jpg in style 2
# 2144 saving: src/models/buildingMLModel/images2/4MarkKerr.jpg in style 2
# 2143 saving: src/models/buildingMLModel/images2/1JoeCharles.jpg in style 5
# 2143 saving: src/models/buildingMLModel/images2/2JoeCharles.jpg in style 4
# 2143 saving: src/models/buildingMLModel/images2/3JoeCharles.jpg in style 7
# 2143 saving: src/models/buildingMLModel/images2/4JoeCharles.jpg in style 5
# 2142 saving: src/models/buildingMLModel/images2/1MarcusSilveira.jpg in style 7
# 2142 saving: src/models/buildingMLModel/images2/2MarcusSilveira.jpg in style 6
# 2142 saving: src/models/buildingMLModel/images2/3MarcusSilveira.jpg in style 6
# 2142 saving: src/models/buildingMLModel/images2/4MarcusSilveira.jpg in style 3
# 2141 saving: src/models/buildingMLModel/images2/1KazushiSakuraba.jpg in style 3
# 2141 saving: src/models/buildingMLModel/images2/2KazushiSakuraba.jpg in style 3
# 2141 saving: src/models/buildingMLModel/images2/3KazushiSakuraba.jpg in style 0
# 2141 saving: src/models/buildingMLModel/images2/4KazushiSakuraba.jpg in style 7
# 2140 saving: src/models/buildingMLModel/images2/1EugenioTadeu.jpg in style 4
# 2140 saving: src/models/buildingMLModel/images2/2EugenioTadeu.jpg in style 2
# 2140 saving: src/models/buildingMLModel/images2/3EugenioTadeu.jpg in style 6
# 2140 saving: src/models/buildingMLModel/images2/4EugenioTadeu.jpg in style 3
# 2139 saving: src/models/buildingMLModel/images2/1KevinJackson.jpg in style 1
# 2139 saving: src/models/buildingMLModel/images2/2KevinJackson.jpg in style 0
# 2139 saving: src/models/buildingMLModel/images2/3KevinJackson.jpg in style 0
# 2139 saving: src/models/buildingMLModel/images2/4KevinJackson.jpg in style 0
# 2138 saving: src/models/buildingMLModel/images2/1IgorZinoviev.jpg in style 7
# 2138 saving: src/models/buildingMLModel/images2/2IgorZinoviev.jpg in style 5
# 2138 saving: src/models/buildingMLModel/images2/3IgorZinoviev.jpg in style 2
# 2138 saving: src/models/buildingMLModel/images2/4IgorZinoviev.jpg in style 1
# 2137 saving: src/models/buildingMLModel/images2/1NoeHernandez.jpg in style 3
# 2137 saving: src/models/buildingMLModel/images2/2NoeHernandez.jpg in style 5
# 2137 saving: src/models/buildingMLModel/images2/3NoeHernandez.jpg in style 1
# 2137 saving: src/models/buildingMLModel/images2/4NoeHernandez.jpg in style 1
# 2136 saving: src/models/buildingMLModel/images2/1AllanGoes.jpg in style 1
# 2136 saving: src/models/buildingMLModel/images2/2AllanGoes.jpg in style 5
# 2136 saving: src/models/buildingMLModel/images2/3AllanGoes.jpg in style 4
# 2136 saving: src/models/buildingMLModel/images2/4AllanGoes.jpg in style 1
# 2135 saving: src/models/buildingMLModel/images2/1BobGilstrap.jpg in style 3
# 2135 saving: src/models/buildingMLModel/images2/2BobGilstrap.jpg in style 3
# 2135 saving: src/models/buildingMLModel/images2/3BobGilstrap.jpg in style 2
# 2135 saving: src/models/buildingMLModel/images2/4BobGilstrap.jpg in style 7
# 2134 saving: src/models/buildingMLModel/images2/1JoePardo.jpg in style 3
# 2134 saving: src/models/buildingMLModel/images2/2JoePardo.jpg in style 6
# 2134 saving: src/models/buildingMLModel/images2/3JoePardo.jpg in style 3
# 2134 saving: src/models/buildingMLModel/images2/4JoePardo.jpg in style 5
# 2133 saving: src/models/buildingMLModel/images2/1HugoDuarte.jpg in style 5
# 2133 saving: src/models/buildingMLModel/images2/2HugoDuarte.jpg in style 7
# 2133 saving: src/models/buildingMLModel/images2/3HugoDuarte.jpg in style 3
# 2133 saving: src/models/buildingMLModel/images2/4HugoDuarte.jpg in style 0
# 2132 saving: src/models/buildingMLModel/images2/1AdrianoSantos.jpg in style 1
# 2132 saving: src/models/buildingMLModel/images2/2AdrianoSantos.jpg in style 5
# 2132 saving: src/models/buildingMLModel/images2/3AdrianoSantos.jpg in style 6
# 2132 saving: src/models/buildingMLModel/images2/4AdrianoSantos.jpg in style 1
# 2131 saving: src/models/buildingMLModel/images2/1TulioPalhares.jpg in style 6
# 2131 saving: src/models/buildingMLModel/images2/2TulioPalhares.jpg in style 5
# 2131 saving: src/models/buildingMLModel/images2/3TulioPalhares.jpg in style 6
# 2131 saving: src/models/buildingMLModel/images2/4TulioPalhares.jpg in style 5
# 2130 saving: src/models/buildingMLModel/images2/1EbenezerFontesBraga.jpg in style 2
# 2130 saving: src/models/buildingMLModel/images2/2EbenezerFontesBraga.jpg in style 3
# 2130 saving: src/models/buildingMLModel/images2/3EbenezerFontesBraga.jpg in style 1
# 2130 saving: src/models/buildingMLModel/images2/4EbenezerFontesBraga.jpg in style 3
# 2129 saving: src/models/buildingMLModel/images2/1JohnLober.jpg in style 6
# 2129 saving: src/models/buildingMLModel/images2/2JohnLober.jpg in style 2
# 2129 saving: src/models/buildingMLModel/images2/3JohnLober.jpg in style 1
# 2129 saving: src/models/buildingMLModel/images2/4JohnLober.jpg in style 3
# 2128 saving: src/models/buildingMLModel/images2/1FrankCaracci.jpg in style 2
# 2128 saving: src/models/buildingMLModel/images2/2FrankCaracci.jpg in style 0
# 2128 saving: src/models/buildingMLModel/images2/3FrankCaracci.jpg in style 6
# 2128 saving: src/models/buildingMLModel/images2/4FrankCaracci.jpg in style 7
# 2127 saving: src/models/buildingMLModel/images2/1DarrelGholar.jpg in style 2
# 2127 saving: src/models/buildingMLModel/images2/2DarrelGholar.jpg in style 5
# 2127 saving: src/models/buildingMLModel/images2/3DarrelGholar.jpg in style 5
# 2127 saving: src/models/buildingMLModel/images2/4DarrelGholar.jpg in style 0
# 2126 saving: src/models/buildingMLModel/images2/1TownsendSaunders.jpg in style 1
# 2126 saving: src/models/buildingMLModel/images2/2TownsendSaunders.jpg in style 2
# 2126 saving: src/models/buildingMLModel/images2/3TownsendSaunders.jpg in style 6
# 2126 saving: src/models/buildingMLModel/images2/4TownsendSaunders.jpg in style 0
# 2125 saving: src/models/buildingMLModel/images2/1MikeyBurnett.jpg in style 3
# 2125 saving: src/models/buildingMLModel/images2/2MikeyBurnett.jpg in style 7
# 2125 saving: src/models/buildingMLModel/images2/3MikeyBurnett.jpg in style 5
# 2125 saving: src/models/buildingMLModel/images2/4MikeyBurnett.jpg in style 2
# 2124 saving: src/models/buildingMLModel/images2/1JerryBohlander.jpg in style 3
# 2124 saving: src/models/buildingMLModel/images2/2JerryBohlander.jpg in style 3
# 2124 saving: src/models/buildingMLModel/images2/3JerryBohlander.jpg in style 5
# 2124 saving: src/models/buildingMLModel/images2/4JerryBohlander.jpg in style 0
# 2123 saving: src/models/buildingMLModel/images2/1JorgePatino.jpg in style 5
# 2123 saving: src/models/buildingMLModel/images2/2JorgePatino.jpg in style 5
# 2123 saving: src/models/buildingMLModel/images2/3JorgePatino.jpg in style 0
# 2123 saving: src/models/buildingMLModel/images2/4JorgePatino.jpg in style 5
# 2122 saving: src/models/buildingMLModel/images2/1JoeyRoberts.jpg in style 1
# 2122 saving: src/models/buildingMLModel/images2/2JoeyRoberts.jpg in style 5
# 2122 saving: src/models/buildingMLModel/images2/3JoeyRoberts.jpg in style 3
# 2122 saving: src/models/buildingMLModel/images2/4JoeyRoberts.jpg in style 1
# 2121 saving: src/models/buildingMLModel/images2/1SioneLatu.jpg in style 1
# 2121 saving: src/models/buildingMLModel/images2/2SioneLatu.jpg in style 5
# 2121 saving: src/models/buildingMLModel/images2/3SioneLatu.jpg in style 6
# 2121 saving: src/models/buildingMLModel/images2/4SioneLatu.jpg in style 5
# 2120 saving: src/models/buildingMLModel/images2/1GaryGoodridge.jpg in style 2
# 2120 saving: src/models/buildingMLModel/images2/2GaryGoodridge.jpg in style 7
# 2120 saving: src/models/buildingMLModel/images2/3GaryGoodridge.jpg in style 5
# 2120 saving: src/models/buildingMLModel/images2/4GaryGoodridge.jpg in style 6
# 2119 saving: src/models/buildingMLModel/images2/1GuyMezger.jpg in style 5
# 2119 saving: src/models/buildingMLModel/images2/2GuyMezger.jpg in style 7
# 2119 saving: src/models/buildingMLModel/images2/3GuyMezger.jpg in style 0
# 2119 saving: src/models/buildingMLModel/images2/4GuyMezger.jpg in style 1
# 2118 saving: src/models/buildingMLModel/images2/1ChrisCondo.jpg in style 1
# 2118 saving: src/models/buildingMLModel/images2/2ChrisCondo.jpg in style 1
# 2118 saving: src/models/buildingMLModel/images2/3ChrisCondo.jpg in style 5
# 2118 saving: src/models/buildingMLModel/images2/4ChrisCondo.jpg in style 1
# 2117 saving: src/models/buildingMLModel/images2/1DavidRoberts.jpg in style 1
# 2117 saving: src/models/buildingMLModel/images2/2DavidRoberts.jpg in style 2
# 2117 saving: src/models/buildingMLModel/images2/3DavidRoberts.jpg in style 1
# 2117 saving: src/models/buildingMLModel/images2/4DavidRoberts.jpg in style 6
# 2116 saving: src/models/buildingMLModel/images2/1MarceloMello.jpg in style 4
# 2116 saving: src/models/buildingMLModel/images2/2MarceloMello.jpg in style 0
# 2116 saving: src/models/buildingMLModel/images2/3MarceloMello.jpg in style 3
# 2116 saving: src/models/buildingMLModel/images2/4MarceloMello.jpg in style 1
# 2115 saving: src/models/buildingMLModel/images2/1TonyPetarra.jpg in style 1
# 2115 saving: src/models/buildingMLModel/images2/2TonyPetarra.jpg in style 6
# 2115 saving: src/models/buildingMLModel/images2/3TonyPetarra.jpg in style 5
# 2115 saving: src/models/buildingMLModel/images2/4TonyPetarra.jpg in style 0
# 2114 saving: src/models/buildingMLModel/images2/1BasRutten.jpg in style 7
# 2114 saving: src/models/buildingMLModel/images2/2BasRutten.jpg in style 1
# 2114 saving: src/models/buildingMLModel/images2/3BasRutten.jpg in style 1
# 2114 saving: src/models/buildingMLModel/images2/4BasRutten.jpg in style 4
# 2113 saving: src/models/buildingMLModel/images2/1TravisFulton.jpg in style 0
# 2113 saving: src/models/buildingMLModel/images2/2TravisFulton.jpg in style 5
# 2113 saving: src/models/buildingMLModel/images2/3TravisFulton.jpg in style 0
# 2113 saving: src/models/buildingMLModel/images2/4TravisFulton.jpg in style 4
# 2112 saving: src/models/buildingMLModel/images2/1AndreRoberts.jpg in style 7
# 2112 saving: src/models/buildingMLModel/images2/2AndreRoberts.jpg in style 7
# 2112 saving: src/models/buildingMLModel/images2/3AndreRoberts.jpg in style 5
# 2112 saving: src/models/buildingMLModel/images2/4AndreRoberts.jpg in style 6
# 2111 saving: src/models/buildingMLModel/images2/1RoyceAlger.jpg in style 5
# 2111 saving: src/models/buildingMLModel/images2/2RoyceAlger.jpg in style 7
# 2111 saving: src/models/buildingMLModel/images2/3RoyceAlger.jpg in style 4
# 2111 saving: src/models/buildingMLModel/images2/4RoyceAlger.jpg in style 1
# 2110 saving: src/models/buildingMLModel/images2/1FlavioLuizMoura.jpg in style 7
# 2110 saving: src/models/buildingMLModel/images2/2FlavioLuizMoura.jpg in style 4
# 2110 saving: src/models/buildingMLModel/images2/3FlavioLuizMoura.jpg in style 1
# 2110 saving: src/models/buildingMLModel/images2/4FlavioLuizMoura.jpg in style 6
# 2109 saving: src/models/buildingMLModel/images2/1AndrePederneiras.jpg in style 3
# 2109 saving: src/models/buildingMLModel/images2/2AndrePederneiras.jpg in style 1
# 2109 saving: src/models/buildingMLModel/images2/3AndrePederneiras.jpg in style 1
# 2109 saving: src/models/buildingMLModel/images2/4AndrePederneiras.jpg in style 7
# 2108 saving: src/models/buildingMLModel/images2/1MarcoRuas.jpg in style 6
# 2108 saving: src/models/buildingMLModel/images2/2MarcoRuas.jpg in style 0
# 2108 saving: src/models/buildingMLModel/images2/3MarcoRuas.jpg in style 3
# 2108 saving: src/models/buildingMLModel/images2/4MarcoRuas.jpg in style 5
# 2107 saving: src/models/buildingMLModel/images2/1AlfonsoAlcarez.jpg in style 0
# 2107 saving: src/models/buildingMLModel/images2/2AlfonsoAlcarez.jpg in style 6
# 2107 saving: src/models/buildingMLModel/images2/3AlfonsoAlcarez.jpg in style 5
# 2107 saving: src/models/buildingMLModel/images2/4AlfonsoAlcarez.jpg in style 0
# 2106 saving: src/models/buildingMLModel/images2/1LowellAnderson.jpg in style 5
# 2106 saving: src/models/buildingMLModel/images2/2LowellAnderson.jpg in style 5
# 2106 saving: src/models/buildingMLModel/images2/3LowellAnderson.jpg in style 0
# 2106 saving: src/models/buildingMLModel/images2/4LowellAnderson.jpg in style 1
# 2105 saving: src/models/buildingMLModel/images2/1ValeriIgnatov.jpg in style 1
# 2105 saving: src/models/buildingMLModel/images2/2ValeriIgnatov.jpg in style 5
# 2105 saving: src/models/buildingMLModel/images2/3ValeriIgnatov.jpg in style 5
# 2105 saving: src/models/buildingMLModel/images2/4ValeriIgnatov.jpg in style 3
# 2104 saving: src/models/buildingMLModel/images2/1PaulJones.jpg in style 1
# 2104 saving: src/models/buildingMLModel/images2/2PaulJones.jpg in style 2
# 2104 saving: src/models/buildingMLModel/images2/3PaulJones.jpg in style 3
# 2104 saving: src/models/buildingMLModel/images2/4PaulJones.jpg in style 6
# 2103 saving: src/models/buildingMLModel/images2/1BradKohler.jpg in style 5
# 2103 saving: src/models/buildingMLModel/images2/2BradKohler.jpg in style 7
# 2103 saving: src/models/buildingMLModel/images2/3BradKohler.jpg in style 1
# 2103 saving: src/models/buildingMLModel/images2/4BradKohler.jpg in style 3
# 2102 saving: src/models/buildingMLModel/images2/1JasonGodsey.jpg in style 6
# 2102 saving: src/models/buildingMLModel/images2/2JasonGodsey.jpg in style 3
# 2102 saving: src/models/buildingMLModel/images2/3JasonGodsey.jpg in style 5
# 2102 saving: src/models/buildingMLModel/images2/4JasonGodsey.jpg in style 7
# 2101 saving: src/models/buildingMLModel/images2/1FrankShamrock.jpg in style 5
# 2101 saving: src/models/buildingMLModel/images2/2FrankShamrock.jpg in style 1
# 2101 saving: src/models/buildingMLModel/images2/3FrankShamrock.jpg in style 2
# 2101 saving: src/models/buildingMLModel/images2/4FrankShamrock.jpg in style 4
# 2100 saving: src/models/buildingMLModel/images2/1MasutatsuYano.jpg in style 0
# 2100 saving: src/models/buildingMLModel/images2/2MasutatsuYano.jpg in style 1
# 2100 saving: src/models/buildingMLModel/images2/3MasutatsuYano.jpg in style 3
# 2100 saving: src/models/buildingMLModel/images2/4MasutatsuYano.jpg in style 5
# 2099 saving: src/models/buildingMLModel/images2/1KeiichiroYamamiya.jpg in style 2
# 2099 saving: src/models/buildingMLModel/images2/2KeiichiroYamamiya.jpg in style 1
# 2099 saving: src/models/buildingMLModel/images2/3KeiichiroYamamiya.jpg in style 3
# 2099 saving: src/models/buildingMLModel/images2/4KeiichiroYamamiya.jpg in style 5
# 2098 saving: src/models/buildingMLModel/images2/1JasonDeLucia.jpg in style 5
# 2098 saving: src/models/buildingMLModel/images2/2JasonDeLucia.jpg in style 6
# 2098 saving: src/models/buildingMLModel/images2/3JasonDeLucia.jpg in style 0
# 2098 saving: src/models/buildingMLModel/images2/4JasonDeLucia.jpg in style 3
# 2097 saving: src/models/buildingMLModel/images2/1KatsuhisaFujii.jpg in style 1
# 2097 saving: src/models/buildingMLModel/images2/2KatsuhisaFujii.jpg in style 6
# 2097 saving: src/models/buildingMLModel/images2/3KatsuhisaFujii.jpg in style 4
# 2097 saving: src/models/buildingMLModel/images2/4KatsuhisaFujii.jpg in style 6
# 2096 saving: src/models/buildingMLModel/images2/1ScottAdams.jpg in style 1
# 2096 saving: src/models/buildingMLModel/images2/2ScottAdams.jpg in style 5
# 2096 saving: src/models/buildingMLModel/images2/3ScottAdams.jpg in style 2
# 2096 saving: src/models/buildingMLModel/images2/4ScottAdams.jpg in style 1
# 2095 saving: src/models/buildingMLModel/images2/1DavidVelasquez.jpg in style 3
# 2095 saving: src/models/buildingMLModel/images2/2DavidVelasquez.jpg in style 6
# 2095 saving: src/models/buildingMLModel/images2/3DavidVelasquez.jpg in style 5
# 2095 saving: src/models/buildingMLModel/images2/4DavidVelasquez.jpg in style 1
# 2094 saving: src/models/buildingMLModel/images2/1BobCook.jpg in style 1
# 2094 saving: src/models/buildingMLModel/images2/2BobCook.jpg in style 5
# 2094 saving: src/models/buildingMLModel/images2/3BobCook.jpg in style 1
# 2094 saving: src/models/buildingMLModel/images2/4BobCook.jpg in style 3
# 2093 saving: src/models/buildingMLModel/images2/1JermaineAndre.jpg in style 2
# 2093 saving: src/models/buildingMLModel/images2/2JermaineAndre.jpg in style 0
# 2093 saving: src/models/buildingMLModel/images2/3JermaineAndre.jpg in style 4
# 2093 saving: src/models/buildingMLModel/images2/4JermaineAndre.jpg in style 3
# 2092 saving: src/models/buildingMLModel/images2/1SteveJudson.jpg in style 4
# 2092 saving: src/models/buildingMLModel/images2/2SteveJudson.jpg in style 2
# 2092 saving: src/models/buildingMLModel/images2/3SteveJudson.jpg in style 2
# 2092 saving: src/models/buildingMLModel/images2/4SteveJudson.jpg in style 3
# 2091 saving: src/models/buildingMLModel/images2/1JoeSlick.jpg in style 6
# 2091 saving: src/models/buildingMLModel/images2/2JoeSlick.jpg in style 5
# 2091 saving: src/models/buildingMLModel/images2/3JoeSlick.jpg in style 5
# 2091 saving: src/models/buildingMLModel/images2/4JoeSlick.jpg in style 5
# 2090 saving: src/models/buildingMLModel/images2/1IkuhisaMinowa.jpg in style 1
# 2090 saving: src/models/buildingMLModel/images2/2IkuhisaMinowa.jpg in style 2
# 2090 saving: src/models/buildingMLModel/images2/3IkuhisaMinowa.jpg in style 5
# 2090 saving: src/models/buildingMLModel/images2/4IkuhisaMinowa.jpg in style 2
# 2089 saving: src/models/buildingMLModel/images2/1SatoshiHonma.jpg in style 3
# 2089 saving: src/models/buildingMLModel/images2/2SatoshiHonma.jpg in style 4
# 2089 saving: src/models/buildingMLModel/images2/3SatoshiHonma.jpg in style 1
# 2089 saving: src/models/buildingMLModel/images2/4SatoshiHonma.jpg in style 1
# 2088 saving: src/models/buildingMLModel/images2/1RonWaterman.jpg in style 1
# 2088 saving: src/models/buildingMLModel/images2/2RonWaterman.jpg in style 1
# 2088 saving: src/models/buildingMLModel/images2/3RonWaterman.jpg in style 1
# 2088 saving: src/models/buildingMLModel/images2/4RonWaterman.jpg in style 2
# 2087 saving: src/models/buildingMLModel/images2/1SanaeKikuta.jpg in style 5
# 2087 saving: src/models/buildingMLModel/images2/2SanaeKikuta.jpg in style 5
# 2087 saving: src/models/buildingMLModel/images2/3SanaeKikuta.jpg in style 3
# 2087 saving: src/models/buildingMLModel/images2/4SanaeKikuta.jpg in style 3
# 2086 saving: src/models/buildingMLModel/images2/1AdrianSerrano.jpg in style 1
# 2086 saving: src/models/buildingMLModel/images2/2AdrianSerrano.jpg in style 1
# 2086 saving: src/models/buildingMLModel/images2/3AdrianSerrano.jpg in style 3
# 2086 saving: src/models/buildingMLModel/images2/4AdrianSerrano.jpg in style 7
# 2085 saving: src/models/buildingMLModel/images2/1NateSchroeder.jpg in style 7
# 2085 saving: src/models/buildingMLModel/images2/2NateSchroeder.jpg in style 5
# 2085 saving: src/models/buildingMLModel/images2/3NateSchroeder.jpg in style 6
# 2085 saving: src/models/buildingMLModel/images2/4NateSchroeder.jpg in style 4
# 2084 saving: src/models/buildingMLModel/images2/1JoaoRoque.jpg in style 5
# 2084 saving: src/models/buildingMLModel/images2/2JoaoRoque.jpg in style 3
# 2084 saving: src/models/buildingMLModel/images2/3JoaoRoque.jpg in style 3
# 2084 saving: src/models/buildingMLModel/images2/4JoaoRoque.jpg in style 7
# 2083 saving: src/models/buildingMLModel/images2/1MarceloAguiar.jpg in style 3
# 2083 saving: src/models/buildingMLModel/images2/2MarceloAguiar.jpg in style 5
# 2083 saving: src/models/buildingMLModel/images2/3MarceloAguiar.jpg in style 1
# 2083 saving: src/models/buildingMLModel/images2/4MarceloAguiar.jpg in style 0
# 2082 saving: src/models/buildingMLModel/images2/1AlexAndrade.jpg in style 4
# 2082 saving: src/models/buildingMLModel/images2/2AlexAndrade.jpg in style 1
# 2082 saving: src/models/buildingMLModel/images2/3AlexAndrade.jpg in style 3
# 2082 saving: src/models/buildingMLModel/images2/4AlexAndrade.jpg in style 4
# 2081 saving: src/models/buildingMLModel/images2/1AmauryBitetti.jpg in style 4
# 2081 saving: src/models/buildingMLModel/images2/2AmauryBitetti.jpg in style 6
# 2081 saving: src/models/buildingMLModel/images2/3AmauryBitetti.jpg in style 5
# 2081 saving: src/models/buildingMLModel/images2/4AmauryBitetti.jpg in style 1
# 2080 saving: src/models/buildingMLModel/images2/1DavidDodd.jpg in style 2
# 2080 saving: src/models/buildingMLModel/images2/2DavidDodd.jpg in style 5
# 2080 saving: src/models/buildingMLModel/images2/3DavidDodd.jpg in style 3
# 2080 saving: src/models/buildingMLModel/images2/4DavidDodd.jpg in style 7
# 2079 saving: src/models/buildingMLModel/images2/1TyroneRoberts.jpg in style 7
# 2079 saving: src/models/buildingMLModel/images2/2TyroneRoberts.jpg in style 2
# 2079 saving: src/models/buildingMLModel/images2/3TyroneRoberts.jpg in style 2
# 2079 saving: src/models/buildingMLModel/images2/4TyroneRoberts.jpg in style 7
# 2078 saving: src/models/buildingMLModel/images2/1CJFernandes.jpg in style 0
# 2078 saving: src/models/buildingMLModel/images2/2CJFernandes.jpg in style 0
# 2078 saving: src/models/buildingMLModel/images2/3CJFernandes.jpg in style 5
# 2078 saving: src/models/buildingMLModel/images2/4CJFernandes.jpg in style 3
# 2077 saving: src/models/buildingMLModel/images2/1BradGumm.jpg in style 7
# 2077 saving: src/models/buildingMLModel/images2/2BradGumm.jpg in style 3
# 2077 saving: src/models/buildingMLModel/images2/3BradGumm.jpg in style 5
# 2077 saving: src/models/buildingMLModel/images2/4BradGumm.jpg in style 6
# 2076 saving: src/models/buildingMLModel/images2/1TimLajcik.jpg in style 1
# 2076 saving: src/models/buildingMLModel/images2/2TimLajcik.jpg in style 7
# 2076 saving: src/models/buildingMLModel/images2/3TimLajcik.jpg in style 6
# 2076 saving: src/models/buildingMLModel/images2/4TimLajcik.jpg in style 3
# 2075 saving: src/models/buildingMLModel/images2/1TeddWilliams.jpg in style 2
# 2075 saving: src/models/buildingMLModel/images2/2TeddWilliams.jpg in style 2
# 2075 saving: src/models/buildingMLModel/images2/3TeddWilliams.jpg in style 1
# 2075 saving: src/models/buildingMLModel/images2/4TeddWilliams.jpg in style 6
# 2074 saving: src/models/buildingMLModel/images2/1LaverneClark.jpg in style 7
# 2074 saving: src/models/buildingMLModel/images2/2LaverneClark.jpg in style 1
# 2074 saving: src/models/buildingMLModel/images2/3LaverneClark.jpg in style 0
# 2074 saving: src/models/buildingMLModel/images2/4LaverneClark.jpg in style 3
# 2073 saving: src/models/buildingMLModel/images2/1DanSevern.jpg in style 6
# 2073 saving: src/models/buildingMLModel/images2/2DanSevern.jpg in style 5
# 2073 saving: src/models/buildingMLModel/images2/3DanSevern.jpg in style 7
# 2073 saving: src/models/buildingMLModel/images2/4DanSevern.jpg in style 2
# 2072 saving: src/models/buildingMLModel/images2/1BenEarwood.jpg in style 5
# 2072 saving: src/models/buildingMLModel/images2/2BenEarwood.jpg in style 5
# 2072 saving: src/models/buildingMLModel/images2/3BenEarwood.jpg in style 3
# 2072 saving: src/models/buildingMLModel/images2/4BenEarwood.jpg in style 3
# 2071 saving: src/models/buildingMLModel/images2/1AlexStiebling.jpg in style 1
# 2071 saving: src/models/buildingMLModel/images2/2AlexStiebling.jpg in style 7
# 2071 saving: src/models/buildingMLModel/images2/3AlexStiebling.jpg in style 6
# 2071 saving: src/models/buildingMLModel/images2/4AlexStiebling.jpg in style 3
# 2070 saving: src/models/buildingMLModel/images2/1MarkHughes.jpg in style 1
# 2070 saving: src/models/buildingMLModel/images2/2MarkHughes.jpg in style 5
# 2070 saving: src/models/buildingMLModel/images2/3MarkHughes.jpg in style 0
# 2070 saving: src/models/buildingMLModel/images2/4MarkHughes.jpg in style 4
# 2069 saving: src/models/buildingMLModel/images2/1JohnLewis.jpg in style 6
# 2069 saving: src/models/buildingMLModel/images2/2JohnLewis.jpg in style 5
# 2069 saving: src/models/buildingMLModel/images2/3JohnLewis.jpg in style 6
# 2069 saving: src/models/buildingMLModel/images2/4JohnLewis.jpg in style 3
# 2068 saving: src/models/buildingMLModel/images2/1AaronBrink.jpg in style 0
# 2068 saving: src/models/buildingMLModel/images2/2AaronBrink.jpg in style 3
# 2068 saving: src/models/buildingMLModel/images2/3AaronBrink.jpg in style 2
# 2068 saving: src/models/buildingMLModel/images2/4AaronBrink.jpg in style 5
# 2067 saving: src/models/buildingMLModel/images2/1MauriceSmith.jpg in style 5
# 2067 saving: src/models/buildingMLModel/images2/2MauriceSmith.jpg in style 4
# 2067 saving: src/models/buildingMLModel/images2/3MauriceSmith.jpg in style 3
# 2067 saving: src/models/buildingMLModel/images2/4MauriceSmith.jpg in style 5
# 2066 saving: src/models/buildingMLModel/images2/1LanceGibson.jpg in style 4
# 2066 saving: src/models/buildingMLModel/images2/2LanceGibson.jpg in style 5
# 2066 saving: src/models/buildingMLModel/images2/3LanceGibson.jpg in style 5
# 2066 saving: src/models/buildingMLModel/images2/4LanceGibson.jpg in style 1
# 2065 saving: src/models/buildingMLModel/images2/1DaijuTakase.jpg in style 1
# 2065 saving: src/models/buildingMLModel/images2/2DaijuTakase.jpg in style 1
# 2065 saving: src/models/buildingMLModel/images2/3DaijuTakase.jpg in style 2
# 2065 saving: src/models/buildingMLModel/images2/4DaijuTakase.jpg in style 7
# 2064 saving: src/models/buildingMLModel/images2/1YojiAnjo.jpg in style 6
# 2064 saving: src/models/buildingMLModel/images2/2YojiAnjo.jpg in style 3
# 2064 saving: src/models/buildingMLModel/images2/3YojiAnjo.jpg in style 1
# 2064 saving: src/models/buildingMLModel/images2/4YojiAnjo.jpg in style 1
# 2063 saving: src/models/buildingMLModel/images2/1KenichiYamamoto.jpg in style 4
# 2063 saving: src/models/buildingMLModel/images2/2KenichiYamamoto.jpg in style 1
# 2063 saving: src/models/buildingMLModel/images2/3KenichiYamamoto.jpg in style 4
# 2063 saving: src/models/buildingMLModel/images2/4KenichiYamamoto.jpg in style 5
# 2062 saving: src/models/buildingMLModel/images2/1MarkRobinson.jpg in style 5
# 2062 saving: src/models/buildingMLModel/images2/2MarkRobinson.jpg in style 3
# 2062 saving: src/models/buildingMLModel/images2/3MarkRobinson.jpg in style 5
# 2062 saving: src/models/buildingMLModel/images2/4MarkRobinson.jpg in style 5
# 2061 saving: src/models/buildingMLModel/images2/1PhilJohns.jpg in style 4
# 2061 saving: src/models/buildingMLModel/images2/2PhilJohns.jpg in style 1
# 2061 saving: src/models/buildingMLModel/images2/3PhilJohns.jpg in style 5
# 2061 saving: src/models/buildingMLModel/images2/4PhilJohns.jpg in style 7
# 2060 saving: src/models/buildingMLModel/images2/1JoeyGilbert.jpg in style 6
# 2060 saving: src/models/buildingMLModel/images2/2JoeyGilbert.jpg in style 5
# 2060 saving: src/models/buildingMLModel/images2/3JoeyGilbert.jpg in style 1
# 2060 saving: src/models/buildingMLModel/images2/4JoeyGilbert.jpg in style 1
# 2059 saving: src/models/buildingMLModel/images2/1PaulRodriguez.jpg in style 5
# 2059 saving: src/models/buildingMLModel/images2/2PaulRodriguez.jpg in style 6
# 2059 saving: src/models/buildingMLModel/images2/3PaulRodriguez.jpg in style 3
# 2059 saving: src/models/buildingMLModel/images2/4PaulRodriguez.jpg in style 3
# 2058 saving: src/models/buildingMLModel/images2/1YukiKondo.jpg in style 6
# 2058 saving: src/models/buildingMLModel/images2/2YukiKondo.jpg in style 4
# 2058 saving: src/models/buildingMLModel/images2/3YukiKondo.jpg in style 0
# 2058 saving: src/models/buildingMLModel/images2/4YukiKondo.jpg in style 2
# 2057 saving: src/models/buildingMLModel/images2/1SemmySchilt.jpg in style 7
# 2057 saving: src/models/buildingMLModel/images2/2SemmySchilt.jpg in style 7
# 2057 saving: src/models/buildingMLModel/images2/3SemmySchilt.jpg in style 0
# 2057 saving: src/models/buildingMLModel/images2/4SemmySchilt.jpg in style 0
# 2056 saving: src/models/buildingMLModel/images2/1FabianoIha.jpg in style 1
# 2056 saving: src/models/buildingMLModel/images2/2FabianoIha.jpg in style 5
# 2056 saving: src/models/buildingMLModel/images2/3FabianoIha.jpg in style 2
# 2056 saving: src/models/buildingMLModel/images2/4FabianoIha.jpg in style 1
# 2055 saving: src/models/buildingMLModel/images2/1RobertoTraven.jpg in style 7
# 2055 saving: src/models/buildingMLModel/images2/2RobertoTraven.jpg in style 3
# 2055 saving: src/models/buildingMLModel/images2/3RobertoTraven.jpg in style 5
# 2055 saving: src/models/buildingMLModel/images2/4RobertoTraven.jpg in style 1
# 2054 saving: src/models/buildingMLModel/images2/1HomerMoore.jpg in style 4
# 2054 saving: src/models/buildingMLModel/images2/4HomerMoore.jpg in style 3
# 2053 saving: src/models/buildingMLModel/images2/1BobbyHoffman.jpg in style 4
# 2053 saving: src/models/buildingMLModel/images2/2BobbyHoffman.jpg in style 1
# 2053 saving: src/models/buildingMLModel/images2/3BobbyHoffman.jpg in style 1
# 2053 saving: src/models/buildingMLModel/images2/4BobbyHoffman.jpg in style 0
# 2052 saving: src/models/buildingMLModel/images2/1ChrisBrennan.jpg in style 5

# %%
#lowered the threshold from 170 to 150 lets see if we get any failures
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#[0:250] and [len(names):2054:-1] done... 
#can run about 90 overnight
i=len(names)
for name in names[2054:1800:-1]:
    i-=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print(str(j)+' couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            continue
# Out:
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_34184/1865165917.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_34184/1865165917.py:114: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 2240 saving: src/models/buildingMLModel/images2/1HomerMoore.jpg in style 1
# 2240 saving: src/models/buildingMLModel/images2/2HomerMoore.jpg in style 1
# 2240 saving: src/models/buildingMLModel/images2/3HomerMoore.jpg in style 6
# 2240 saving: src/models/buildingMLModel/images2/4HomerMoore.jpg in style 7
# 2239 saving: src/models/buildingMLModel/images2/1BobbyHoffman.jpg in style 2
# 2239 saving: src/models/buildingMLModel/images2/2BobbyHoffman.jpg in style 6
# 2239 saving: src/models/buildingMLModel/images2/3BobbyHoffman.jpg in style 1
# 2239 saving: src/models/buildingMLModel/images2/4BobbyHoffman.jpg in style 4
# 2238 saving: src/models/buildingMLModel/images2/1ChrisBrennan.jpg in style 2
# 2238 saving: src/models/buildingMLModel/images2/2ChrisBrennan.jpg in style 1
# 2238 saving: src/models/buildingMLModel/images2/3ChrisBrennan.jpg in style 5
# 2238 saving: src/models/buildingMLModel/images2/4ChrisBrennan.jpg in style 3
# 2237 saving: src/models/buildingMLModel/images2/1KevinRandleman.jpg in style 1
# 2237 saving: src/models/buildingMLModel/images2/2KevinRandleman.jpg in style 6
# 2237 saving: src/models/buildingMLModel/images2/3KevinRandleman.jpg in style 1
# 2237 saving: src/models/buildingMLModel/images2/4KevinRandleman.jpg in style 1
# 2236 saving: src/models/buildingMLModel/images2/1JutaroNakao.jpg in style 1

# %%
#oops... started i at len(names) instead of 2054... lets try that again
#lowered the threshold from 170 to 150 lets see if we get any failures
#this builds a folder images2 with 4 stylized images for each ufc fighter in history
#[0:250] and [len(names):2054:-1] done... 
#can run about 90 overnight
i=2051
for name in names[2050:1800:-1]:
    i-=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print(str(j)+' couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            continue
# Out:
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_34449/1865165917.py:113: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_34449/1865165917.py:114: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 2050 saving: src/models/buildingMLModel/images2/1JutaroNakao.jpg in style 3
# 2050 saving: src/models/buildingMLModel/images2/2JutaroNakao.jpg in style 1
# 2050 saving: src/models/buildingMLModel/images2/3JutaroNakao.jpg in style 4
# 2050 saving: src/models/buildingMLModel/images2/4JutaroNakao.jpg in style 5
# 2049 saving: src/models/buildingMLModel/images2/1KellyDullanty.jpg in style 7
# 2049 saving: src/models/buildingMLModel/images2/2KellyDullanty.jpg in style 5
# 2049 saving: src/models/buildingMLModel/images2/3KellyDullanty.jpg in style 1
# 2049 saving: src/models/buildingMLModel/images2/4KellyDullanty.jpg in style 2
# 2048 saving: src/models/buildingMLModel/images2/1PeteWilliams.jpg in style 1
# 2048 saving: src/models/buildingMLModel/images2/2PeteWilliams.jpg in style 3
# 2048 saving: src/models/buildingMLModel/images2/3PeteWilliams.jpg in style 4
# 2048 saving: src/models/buildingMLModel/images2/4PeteWilliams.jpg in style 5
# 2047 saving: src/models/buildingMLModel/images2/1PatMiletich.jpg in style 1
# 2047 saving: src/models/buildingMLModel/images2/2PatMiletich.jpg in style 1
# 2047 saving: src/models/buildingMLModel/images2/3PatMiletich.jpg in style 0
# 2047 saving: src/models/buildingMLModel/images2/4PatMiletich.jpg in style 1
# 2046 saving: src/models/buildingMLModel/images2/1HayatoSakurai.jpg in style 1
# 2046 saving: src/models/buildingMLModel/images2/2HayatoSakurai.jpg in style 1
# 2046 saving: src/models/buildingMLModel/images2/3HayatoSakurai.jpg in style 2
# 2046 saving: src/models/buildingMLModel/images2/4HayatoSakurai.jpg in style 1
# 2045 saving: src/models/buildingMLModel/images2/1AndreiSemenov.jpg in style 3
# 2045 saving: src/models/buildingMLModel/images2/2AndreiSemenov.jpg in style 5
# 2045 saving: src/models/buildingMLModel/images2/3AndreiSemenov.jpg in style 5
# 2045 saving: src/models/buildingMLModel/images2/4AndreiSemenov.jpg in style 3
# 2044 saving: src/models/buildingMLModel/images2/1AmarSuloev.jpg in style 4
# 2044 saving: src/models/buildingMLModel/images2/2AmarSuloev.jpg in style 4
# 2044 saving: src/models/buildingMLModel/images2/3AmarSuloev.jpg in style 7
# 2044 saving: src/models/buildingMLModel/images2/4AmarSuloev.jpg in style 5
# 2043 saving: src/models/buildingMLModel/images2/1PaulCreighton.jpg in style 4
# 2043 saving: src/models/buildingMLModel/images2/2PaulCreighton.jpg in style 1
# 2043 saving: src/models/buildingMLModel/images2/3PaulCreighton.jpg in style 1
# 2043 saving: src/models/buildingMLModel/images2/4PaulCreighton.jpg in style 1
# 2042 saving: src/models/buildingMLModel/images2/1TsuyoshiKohsaka.jpg in style 1
# 2042 saving: src/models/buildingMLModel/images2/2TsuyoshiKohsaka.jpg in style 1
# 2042 saving: src/models/buildingMLModel/images2/3TsuyoshiKohsaka.jpg in style 3
# 2042 saving: src/models/buildingMLModel/images2/4TsuyoshiKohsaka.jpg in style 4
# 2041 saving: src/models/buildingMLModel/images2/1MuriloBustamante.jpg in style 6
# 2041 saving: src/models/buildingMLModel/images2/2MuriloBustamante.jpg in style 3
# 2041 saving: src/models/buildingMLModel/images2/3MuriloBustamante.jpg in style 2
# 2041 saving: src/models/buildingMLModel/images2/4MuriloBustamante.jpg in style 1
# 2040 saving: src/models/buildingMLModel/images2/1JoaoPierini.jpg in style 3
# 2040 saving: src/models/buildingMLModel/images2/2JoaoPierini.jpg in style 6
# 2040 saving: src/models/buildingMLModel/images2/3JoaoPierini.jpg in style 1
# 2040 saving: src/models/buildingMLModel/images2/4JoaoPierini.jpg in style 4
# 2039 saving: src/models/buildingMLModel/images2/1RodrigoRuas.jpg in style 7
# 2039 saving: src/models/buildingMLModel/images2/2RodrigoRuas.jpg in style 5
# 2039 saving: src/models/buildingMLModel/images2/3RodrigoRuas.jpg in style 6
# 2039 saving: src/models/buildingMLModel/images2/4RodrigoRuas.jpg in style 1
# 2038 saving: src/models/buildingMLModel/images2/1SteveBerger.jpg in style 5
# 2038 saving: src/models/buildingMLModel/images2/2SteveBerger.jpg in style 5
# 2038 saving: src/models/buildingMLModel/images2/3SteveBerger.jpg in style 7
# 2038 saving: src/models/buildingMLModel/images2/4SteveBerger.jpg in style 1
# 2037 saving: src/models/buildingMLModel/images2/1ZachLight.jpg in style 1
# 2037 saving: src/models/buildingMLModel/images2/2ZachLight.jpg in style 1
# 2037 saving: src/models/buildingMLModel/images2/3ZachLight.jpg in style 2
# 2037 saving: src/models/buildingMLModel/images2/4ZachLight.jpg in style 1
# 2036 saving: src/models/buildingMLModel/images2/1NickSerra.jpg in style 5
# 2036 saving: src/models/buildingMLModel/images2/2NickSerra.jpg in style 2
# 2036 saving: src/models/buildingMLModel/images2/3NickSerra.jpg in style 3
# 2036 saving: src/models/buildingMLModel/images2/4NickSerra.jpg in style 5
# 2035 saving: src/models/buildingMLModel/images2/1ChrisHaseman.jpg in style 4
# 2035 saving: src/models/buildingMLModel/images2/2ChrisHaseman.jpg in style 3
# 2035 saving: src/models/buildingMLModel/images2/3ChrisHaseman.jpg in style 1
# 2035 saving: src/models/buildingMLModel/images2/4ChrisHaseman.jpg in style 5
# 2034 saving: src/models/buildingMLModel/images2/1JamesZikic.jpg in style 6
# 2034 saving: src/models/buildingMLModel/images2/2JamesZikic.jpg in style 1
# 2034 saving: src/models/buildingMLModel/images2/3JamesZikic.jpg in style 5
# 2034 saving: src/models/buildingMLModel/images2/4JamesZikic.jpg in style 3
# 2033 saving: src/models/buildingMLModel/images2/1LeighRemedios.jpg in style 4
# 2033 saving: src/models/buildingMLModel/images2/2LeighRemedios.jpg in style 2
# 2033 saving: src/models/buildingMLModel/images2/3LeighRemedios.jpg in style 1
# 2033 saving: src/models/buildingMLModel/images2/4LeighRemedios.jpg in style 1
# 2032 saving: src/models/buildingMLModel/images2/1EugeneJackson.jpg in style 1
# 2032 saving: src/models/buildingMLModel/images2/2EugeneJackson.jpg in style 1
# 2032 saving: src/models/buildingMLModel/images2/3EugeneJackson.jpg in style 1
# 2032 saving: src/models/buildingMLModel/images2/4EugeneJackson.jpg in style 4
# 2031 saving: src/models/buildingMLModel/images2/1BenjiRadach.jpg in style 5
# 2031 saving: src/models/buildingMLModel/images2/2BenjiRadach.jpg in style 5
# 2031 saving: src/models/buildingMLModel/images2/3BenjiRadach.jpg in style 1
# 2031 saving: src/models/buildingMLModel/images2/4BenjiRadach.jpg in style 2
# 2030 saving: src/models/buildingMLModel/images2/1PhillipMiller.jpg in style 5
# 2030 saving: src/models/buildingMLModel/images2/2PhillipMiller.jpg in style 6
# 2030 saving: src/models/buildingMLModel/images2/3PhillipMiller.jpg in style 5
# 2030 saving: src/models/buildingMLModel/images2/4PhillipMiller.jpg in style 2
# 2029 saving: src/models/buildingMLModel/images2/1GilCastillo.jpg in style 5
# 2029 saving: src/models/buildingMLModel/images2/2GilCastillo.jpg in style 1
# 2029 saving: src/models/buildingMLModel/images2/3GilCastillo.jpg in style 5
# 2029 saving: src/models/buildingMLModel/images2/4GilCastillo.jpg in style 5
# 2028 saving: src/models/buildingMLModel/images2/1AlexandreDantas.jpg in style 1
# 2028 saving: src/models/buildingMLModel/images2/2AlexandreDantas.jpg in style 2
# 2028 saving: src/models/buildingMLModel/images2/3AlexandreDantas.jpg in style 1
# 2028 saving: src/models/buildingMLModel/images2/4AlexandreDantas.jpg in style 7
# 2027 saving: src/models/buildingMLModel/images2/1MarkWeir.jpg in style 5
# 2027 saving: src/models/buildingMLModel/images2/2MarkWeir.jpg in style 1
# 2027 saving: src/models/buildingMLModel/images2/3MarkWeir.jpg in style 6
# 2027 saving: src/models/buildingMLModel/images2/4MarkWeir.jpg in style 7
# 2026 saving: src/models/buildingMLModel/images2/1RichardCrunkilton.jpg in style 3
# 2026 saving: src/models/buildingMLModel/images2/2RichardCrunkilton.jpg in style 1
# 2026 saving: src/models/buildingMLModel/images2/3RichardCrunkilton.jpg in style 5
# 2026 saving: src/models/buildingMLModel/images2/4RichardCrunkilton.jpg in style 1
# 2025 saving: src/models/buildingMLModel/images2/1SeanAlvarez.jpg in style 3
# 2025 saving: src/models/buildingMLModel/images2/2SeanAlvarez.jpg in style 1
# 2025 saving: src/models/buildingMLModel/images2/3SeanAlvarez.jpg in style 5
# 2025 saving: src/models/buildingMLModel/images2/4SeanAlvarez.jpg in style 1
# 2024 saving: src/models/buildingMLModel/images2/1RomieAram.jpg in style 0
# 2024 saving: src/models/buildingMLModel/images2/2RomieAram.jpg in style 6
# 2024 saving: src/models/buildingMLModel/images2/3RomieAram.jpg in style 1
# 2024 saving: src/models/buildingMLModel/images2/4RomieAram.jpg in style 0
# 2023 saving: src/models/buildingMLModel/images2/1EddieRuiz.jpg in style 3
# 2023 saving: src/models/buildingMLModel/images2/2EddieRuiz.jpg in style 3
# 2023 saving: src/models/buildingMLModel/images2/3EddieRuiz.jpg in style 5
# 2023 saving: src/models/buildingMLModel/images2/4EddieRuiz.jpg in style 6
# 2022 saving: src/models/buildingMLModel/images2/1IanFreeman.jpg in style 5
# 2022 saving: src/models/buildingMLModel/images2/2IanFreeman.jpg in style 0
# 2022 saving: src/models/buildingMLModel/images2/3IanFreeman.jpg in style 6
# 2022 saving: src/models/buildingMLModel/images2/4IanFreeman.jpg in style 2
# 2021 saving: src/models/buildingMLModel/images2/1GeraldStrebendt.jpg in style 1
# 2021 saving: src/models/buildingMLModel/images2/2GeraldStrebendt.jpg in style 1
# 2021 saving: src/models/buildingMLModel/images2/3GeraldStrebendt.jpg in style 1
# 2021 saving: src/models/buildingMLModel/images2/4GeraldStrebendt.jpg in style 4
# 2020 saving: src/models/buildingMLModel/images2/1DaveStrasser.jpg in style 4
# 2020 saving: src/models/buildingMLModel/images2/2DaveStrasser.jpg in style 1
# 2020 saving: src/models/buildingMLModel/images2/3DaveStrasser.jpg in style 4
# 2020 saving: src/models/buildingMLModel/images2/4DaveStrasser.jpg in style 4
# 2019 saving: src/models/buildingMLModel/images2/1GanMcGee.jpg in style 5
# 2019 saving: src/models/buildingMLModel/images2/2GanMcGee.jpg in style 5
# 2019 saving: src/models/buildingMLModel/images2/3GanMcGee.jpg in style 0
# 2019 saving: src/models/buildingMLModel/images2/4GanMcGee.jpg in style 1
# 2018 saving: src/models/buildingMLModel/images2/1NickAgallar.jpg in style 6
# 2018 saving: src/models/buildingMLModel/images2/2NickAgallar.jpg in style 1
# 2018 saving: src/models/buildingMLModel/images2/3NickAgallar.jpg in style 7
# 2018 saving: src/models/buildingMLModel/images2/4NickAgallar.jpg in style 5
# 2017 saving: src/models/buildingMLModel/images2/1ChrisLiguori.jpg in style 1
# 2017 saving: src/models/buildingMLModel/images2/2ChrisLiguori.jpg in style 5
# 2017 saving: src/models/buildingMLModel/images2/3ChrisLiguori.jpg in style 1
# 2017 saving: src/models/buildingMLModel/images2/4ChrisLiguori.jpg in style 4
# 2016 saving: src/models/buildingMLModel/images2/1KeithRockel.jpg in style 5
# 2016 saving: src/models/buildingMLModel/images2/2KeithRockel.jpg in style 6
# 2016 saving: src/models/buildingMLModel/images2/3KeithRockel.jpg in style 6
# 2016 saving: src/models/buildingMLModel/images2/4KeithRockel.jpg in style 5
# 2015 saving: src/models/buildingMLModel/images2/1RiccoRodriguez.jpg in style 6
# 2015 saving: src/models/buildingMLModel/images2/2RiccoRodriguez.jpg in style 2
# 2015 saving: src/models/buildingMLModel/images2/3RiccoRodriguez.jpg in style 5
# 2015 saving: src/models/buildingMLModel/images2/4RiccoRodriguez.jpg in style 3
# 2014 saving: src/models/buildingMLModel/images2/1PedroRizzo.jpg in style 4
# 2014 saving: src/models/buildingMLModel/images2/2PedroRizzo.jpg in style 7
# 2014 saving: src/models/buildingMLModel/images2/3PedroRizzo.jpg in style 5
# 2014 saving: src/models/buildingMLModel/images2/4PedroRizzo.jpg in style 1
# 2013 saving: src/models/buildingMLModel/images2/1DavidAbbott.jpg in style 5
# 2013 saving: src/models/buildingMLModel/images2/2DavidAbbott.jpg in style 2
# 2013 saving: src/models/buildingMLModel/images2/3DavidAbbott.jpg in style 1
# 2013 saving: src/models/buildingMLModel/images2/4DavidAbbott.jpg in style 5
# 2012 saving: src/models/buildingMLModel/images2/1FalanikoVitale.jpg in style 6
# 2012 saving: src/models/buildingMLModel/images2/2FalanikoVitale.jpg in style 3
# 2012 saving: src/models/buildingMLModel/images2/3FalanikoVitale.jpg in style 5
# 2012 saving: src/models/buildingMLModel/images2/4FalanikoVitale.jpg in style 5
# 2011 saving: src/models/buildingMLModel/images2/1LeeMurray.jpg in style 2
# 2011 saving: src/models/buildingMLModel/images2/2LeeMurray.jpg in style 0
# 2011 saving: src/models/buildingMLModel/images2/3LeeMurray.jpg in style 4
# 2011 saving: src/models/buildingMLModel/images2/4LeeMurray.jpg in style 7
# 2010 saving: src/models/buildingMLModel/images2/1CarlosNewton.jpg in style 2
# 2010 saving: src/models/buildingMLModel/images2/2CarlosNewton.jpg in style 5
# 2010 saving: src/models/buildingMLModel/images2/3CarlosNewton.jpg in style 4
# 2010 saving: src/models/buildingMLModel/images2/4CarlosNewton.jpg in style 1
# 2009 saving: src/models/buildingMLModel/images2/1GenkiSudo.jpg in style 3
# 2009 saving: src/models/buildingMLModel/images2/2GenkiSudo.jpg in style 3
# 2009 saving: src/models/buildingMLModel/images2/3GenkiSudo.jpg in style 4
# 2009 saving: src/models/buildingMLModel/images2/4GenkiSudo.jpg in style 5
# 2008 saving: src/models/buildingMLModel/images2/1WadeShipp.jpg in style 1
# 2008 saving: src/models/buildingMLModel/images2/2WadeShipp.jpg in style 1
# 2008 saving: src/models/buildingMLModel/images2/3WadeShipp.jpg in style 1
# 2008 saving: src/models/buildingMLModel/images2/4WadeShipp.jpg in style 2
# 2007 saving: src/models/buildingMLModel/images2/1JonathanWiezorek.jpg in style 1
# 2007 saving: src/models/buildingMLModel/images2/2JonathanWiezorek.jpg in style 7
# 2007 saving: src/models/buildingMLModel/images2/3JonathanWiezorek.jpg in style 2
# 2007 saving: src/models/buildingMLModel/images2/4JonathanWiezorek.jpg in style 5
# 2006 saving: src/models/buildingMLModel/images2/1WesSims.jpg in style 4
# 2006 saving: src/models/buildingMLModel/images2/2WesSims.jpg in style 6
# 2006 saving: src/models/buildingMLModel/images2/3WesSims.jpg in style 1
# 2006 saving: src/models/buildingMLModel/images2/4WesSims.jpg in style 6
# 2005 saving: src/models/buildingMLModel/images2/1WesleyCorreira.jpg in style 6
# 2005 saving: src/models/buildingMLModel/images2/2WesleyCorreira.jpg in style 7
# 2005 saving: src/models/buildingMLModel/images2/3WesleyCorreira.jpg in style 5
# 2005 saving: src/models/buildingMLModel/images2/4WesleyCorreira.jpg in style 4
# 2004 saving: src/models/buildingMLModel/images2/1TikiGhosn.jpg in style 5
# 2004 saving: src/models/buildingMLModel/images2/2TikiGhosn.jpg in style 1
# 2004 saving: src/models/buildingMLModel/images2/3TikiGhosn.jpg in style 1
# 2004 saving: src/models/buildingMLModel/images2/4TikiGhosn.jpg in style 5
# 2003 saving: src/models/buildingMLModel/images2/1CurtisStout.jpg in style 1
# 2003 saving: src/models/buildingMLModel/images2/2CurtisStout.jpg in style 2
# 2003 saving: src/models/buildingMLModel/images2/3CurtisStout.jpg in style 7
# 2003 saving: src/models/buildingMLModel/images2/4CurtisStout.jpg in style 5
# 2002 saving: src/models/buildingMLModel/images2/1KimoLeopoldo.jpg in style 0
# 2002 saving: src/models/buildingMLModel/images2/2KimoLeopoldo.jpg in style 5
# 2002 saving: src/models/buildingMLModel/images2/3KimoLeopoldo.jpg in style 6
# 2002 saving: src/models/buildingMLModel/images2/4KimoLeopoldo.jpg in style 0
# 2001 saving: src/models/buildingMLModel/images2/1RonaldJhun.jpg in style 7
# 2001 saving: src/models/buildingMLModel/images2/2RonaldJhun.jpg in style 7
# 2001 saving: src/models/buildingMLModel/images2/3RonaldJhun.jpg in style 1
# 2001 saving: src/models/buildingMLModel/images2/4RonaldJhun.jpg in style 1
# 2000 saving: src/models/buildingMLModel/images2/1VernonWhite.jpg in style 1
# 2000 saving: src/models/buildingMLModel/images2/2VernonWhite.jpg in style 5
# 2000 saving: src/models/buildingMLModel/images2/3VernonWhite.jpg in style 6
# 2000 saving: src/models/buildingMLModel/images2/4VernonWhite.jpg in style 1
# 1999 saving: src/models/buildingMLModel/images2/1TonyFryklund.jpg in style 6
# 1999 saving: src/models/buildingMLModel/images2/2TonyFryklund.jpg in style 2
# 1999 saving: src/models/buildingMLModel/images2/3TonyFryklund.jpg in style 5
# 1999 saving: src/models/buildingMLModel/images2/4TonyFryklund.jpg in style 0
# 1998 saving: src/models/buildingMLModel/images2/1RenatoVerissimo.jpg in style 7
# 1998 saving: src/models/buildingMLModel/images2/2RenatoVerissimo.jpg in style 5
# 1998 saving: src/models/buildingMLModel/images2/3RenatoVerissimo.jpg in style 5
# 1998 saving: src/models/buildingMLModel/images2/4RenatoVerissimo.jpg in style 5
# 1997 saving: src/models/buildingMLModel/images2/1MikeKyle.jpg in style 6
# 1997 saving: src/models/buildingMLModel/images2/2MikeKyle.jpg in style 5
# 1997 saving: src/models/buildingMLModel/images2/3MikeKyle.jpg in style 4
# 1997 saving: src/models/buildingMLModel/images2/4MikeKyle.jpg in style 7
# 1996 saving: src/models/buildingMLModel/images2/1JoshRafferty.jpg in style 5
# 1996 saving: src/models/buildingMLModel/images2/2JoshRafferty.jpg in style 1
# 1996 saving: src/models/buildingMLModel/images2/3JoshRafferty.jpg in style 5
# 1996 saving: src/models/buildingMLModel/images2/4JoshRafferty.jpg in style 1
# 1995 saving: src/models/buildingMLModel/images2/1AlexSchoenauer.jpg in style 7
# 1995 saving: src/models/buildingMLModel/images2/2AlexSchoenauer.jpg in style 3
# 1995 saving: src/models/buildingMLModel/images2/3AlexSchoenauer.jpg in style 1
# 1995 saving: src/models/buildingMLModel/images2/4AlexSchoenauer.jpg in style 3
# 1994 saving: src/models/buildingMLModel/images2/1LoduneSincaid.jpg in style 3
# 1994 saving: src/models/buildingMLModel/images2/2LoduneSincaid.jpg in style 6
# 1994 saving: src/models/buildingMLModel/images2/3LoduneSincaid.jpg in style 1
# 1994 saving: src/models/buildingMLModel/images2/4LoduneSincaid.jpg in style 1
# 1993 saving: src/models/buildingMLModel/images2/1ChrisSanford.jpg in style 5
# 1993 saving: src/models/buildingMLModel/images2/2ChrisSanford.jpg in style 1
# 1993 saving: src/models/buildingMLModel/images2/3ChrisSanford.jpg in style 1
# 1993 saving: src/models/buildingMLModel/images2/4ChrisSanford.jpg in style 5
# 1992 saving: src/models/buildingMLModel/images2/1JasonThacker.jpg in style 2
# 1992 saving: src/models/buildingMLModel/images2/2JasonThacker.jpg in style 3
# 1992 saving: src/models/buildingMLModel/images2/3JasonThacker.jpg in style 2
# 1992 saving: src/models/buildingMLModel/images2/4JasonThacker.jpg in style 2
# 1991 saving: src/models/buildingMLModel/images2/1BobbySouthworth.jpg in style 2
# 1991 saving: src/models/buildingMLModel/images2/2BobbySouthworth.jpg in style 3
# 1991 saving: src/models/buildingMLModel/images2/3BobbySouthworth.jpg in style 1
# 1991 saving: src/models/buildingMLModel/images2/4BobbySouthworth.jpg in style 3
# 1990 saving: src/models/buildingMLModel/images2/1JohnMarsh.jpg in style 7
# 1990 saving: src/models/buildingMLModel/images2/2JohnMarsh.jpg in style 5
# 1990 saving: src/models/buildingMLModel/images2/3JohnMarsh.jpg in style 2
# 1990 saving: src/models/buildingMLModel/images2/4JohnMarsh.jpg in style 4
# 1989 saving: src/models/buildingMLModel/images2/1TravisWiuff.jpg in style 5
# 1989 saving: src/models/buildingMLModel/images2/2TravisWiuff.jpg in style 6
# 1989 saving: src/models/buildingMLModel/images2/3TravisWiuff.jpg in style 0
# 1989 saving: src/models/buildingMLModel/images2/4TravisWiuff.jpg in style 5
# 1988 saving: src/models/buildingMLModel/images2/1KojiOishi.jpg in style 1
# 1988 saving: src/models/buildingMLModel/images2/2KojiOishi.jpg in style 6
# 1988 saving: src/models/buildingMLModel/images2/3KojiOishi.jpg in style 4
# 1988 saving: src/models/buildingMLModel/images2/4KojiOishi.jpg in style 2
# 1987 saving: src/models/buildingMLModel/images2/1BillMahood.jpg in style 5
# 1987 saving: src/models/buildingMLModel/images2/2BillMahood.jpg in style 5
# 1987 saving: src/models/buildingMLModel/images2/3BillMahood.jpg in style 5
# 1987 saving: src/models/buildingMLModel/images2/4BillMahood.jpg in style 3
# 1986 saving: src/models/buildingMLModel/images2/1MattLindland.jpg in style 2
# 1986 saving: src/models/buildingMLModel/images2/2MattLindland.jpg in style 1
# 1986 saving: src/models/buildingMLModel/images2/3MattLindland.jpg in style 5
# 1986 saving: src/models/buildingMLModel/images2/4MattLindland.jpg in style 5
# 1985 saving: src/models/buildingMLModel/images2/1BrianGassaway.jpg in style 1
# 1985 saving: src/models/buildingMLModel/images2/2BrianGassaway.jpg in style 5
# 1985 saving: src/models/buildingMLModel/images2/3BrianGassaway.jpg in style 3
# 1985 saving: src/models/buildingMLModel/images2/4BrianGassaway.jpg in style 5
# 1984 saving: src/models/buildingMLModel/images2/1TraTelligman.jpg in style 3
# 1984 saving: src/models/buildingMLModel/images2/2TraTelligman.jpg in style 6
# 1984 saving: src/models/buildingMLModel/images2/3TraTelligman.jpg in style 2
# 1984 saving: src/models/buildingMLModel/images2/4TraTelligman.jpg in style 6
# 1983 saving: src/models/buildingMLModel/images2/1RonFaircloth.jpg in style 7
# 1983 saving: src/models/buildingMLModel/images2/2RonFaircloth.jpg in style 5
# 1983 saving: src/models/buildingMLModel/images2/3RonFaircloth.jpg in style 3
# 1983 saving: src/models/buildingMLModel/images2/4RonFaircloth.jpg in style 5
# 1982 saving: src/models/buildingMLModel/images2/1KeigoKunihara.jpg in style 1
# 1982 saving: src/models/buildingMLModel/images2/2KeigoKunihara.jpg in style 3
# 1982 saving: src/models/buildingMLModel/images2/3KeigoKunihara.jpg in style 1
# 1982 saving: src/models/buildingMLModel/images2/4KeigoKunihara.jpg in style 2
# 1981 saving: src/models/buildingMLModel/images2/1SeanGannon.jpg in style 6
# 1981 saving: src/models/buildingMLModel/images2/2SeanGannon.jpg in style 1
# 1981 saving: src/models/buildingMLModel/images2/3SeanGannon.jpg in style 7
# 1981 saving: src/models/buildingMLModel/images2/4SeanGannon.jpg in style 1
# 1980 saving: src/models/buildingMLModel/images2/1KerrySchall.jpg in style 3
# 1980 saving: src/models/buildingMLModel/images2/2KerrySchall.jpg in style 5
# 1980 saving: src/models/buildingMLModel/images2/3KerrySchall.jpg in style 1
# 1980 saving: src/models/buildingMLModel/images2/4KerrySchall.jpg in style 6
# 1979 saving: src/models/buildingMLModel/images2/1KitCope.jpg in style 5
# 1979 saving: src/models/buildingMLModel/images2/2KitCope.jpg in style 6
# 1979 saving: src/models/buildingMLModel/images2/3KitCope.jpg in style 5
# 1979 saving: src/models/buildingMLModel/images2/4KitCope.jpg in style 5
# 1978 saving: src/models/buildingMLModel/images2/1JeffNewton.jpg in style 5
# 1978 saving: src/models/buildingMLModel/images2/2JeffNewton.jpg in style 7
# 1978 saving: src/models/buildingMLModel/images2/3JeffNewton.jpg in style 1
# 1978 saving: src/models/buildingMLModel/images2/4JeffNewton.jpg in style 5
# 1977 saving: src/models/buildingMLModel/images2/1KevinJordan.jpg in style 4
# 1977 saving: src/models/buildingMLModel/images2/2KevinJordan.jpg in style 1
# 1977 saving: src/models/buildingMLModel/images2/3KevinJordan.jpg in style 6
# 1977 saving: src/models/buildingMLModel/images2/4KevinJordan.jpg in style 6
# 1976 saving: src/models/buildingMLModel/images2/1AlexKaralexis.jpg in style 1
# 1976 saving: src/models/buildingMLModel/images2/2AlexKaralexis.jpg in style 1
# 1976 saving: src/models/buildingMLModel/images2/3AlexKaralexis.jpg in style 1
# 1976 saving: src/models/buildingMLModel/images2/4AlexKaralexis.jpg in style 4
# 1975 saving: src/models/buildingMLModel/images2/1MikeWhitehead.jpg in style 5
# 1975 saving: src/models/buildingMLModel/images2/2MikeWhitehead.jpg in style 1
# 1975 saving: src/models/buildingMLModel/images2/3MikeWhitehead.jpg in style 3
# 1975 saving: src/models/buildingMLModel/images2/4MikeWhitehead.jpg in style 7
# 1974 saving: src/models/buildingMLModel/images2/1MikevanArsdale.jpg in style 3
# 1974 saving: src/models/buildingMLModel/images2/2MikevanArsdale.jpg in style 7
# 1974 saving: src/models/buildingMLModel/images2/3MikevanArsdale.jpg in style 0
# 1974 saving: src/models/buildingMLModel/images2/4MikevanArsdale.jpg in style 5
# 1973 saving: src/models/buildingMLModel/images2/1JustinEilers.jpg in style 5
# 1973 saving: src/models/buildingMLModel/images2/2JustinEilers.jpg in style 2
# 1973 saving: src/models/buildingMLModel/images2/3JustinEilers.jpg in style 1
# 1973 saving: src/models/buildingMLModel/images2/4JustinEilers.jpg in style 1
# 1972 saving: src/models/buildingMLModel/images2/1IchoLarenas.jpg in style 3
# 1972 saving: src/models/buildingMLModel/images2/2IchoLarenas.jpg in style 2
# 1972 saving: src/models/buildingMLModel/images2/3IchoLarenas.jpg in style 7
# 1972 saving: src/models/buildingMLModel/images2/4IchoLarenas.jpg in style 2
# 1971 saving: src/models/buildingMLModel/images2/1TomMurphy.jpg in style 5
# 1971 saving: src/models/buildingMLModel/images2/2TomMurphy.jpg in style 1
# 1971 saving: src/models/buildingMLModel/images2/3TomMurphy.jpg in style 7
# 1971 saving: src/models/buildingMLModel/images2/4TomMurphy.jpg in style 7
# 1970 saving: src/models/buildingMLModel/images2/1SteveVigneault.jpg in style 6
# 1970 saving: src/models/buildingMLModel/images2/2SteveVigneault.jpg in style 1
# 1970 saving: src/models/buildingMLModel/images2/3SteveVigneault.jpg in style 5
# 1970 saving: src/models/buildingMLModel/images2/4SteveVigneault.jpg in style 1
# 1969 saving: src/models/buildingMLModel/images2/1TrevorPrangley.jpg in style 6
# 1969 saving: src/models/buildingMLModel/images2/2TrevorPrangley.jpg in style 6
# 1969 saving: src/models/buildingMLModel/images2/3TrevorPrangley.jpg in style 1
# 1969 saving: src/models/buildingMLModel/images2/4TrevorPrangley.jpg in style 6
# 1968 saving: src/models/buildingMLModel/images2/1AnsarChalangov.jpg in style 1
# 1968 saving: src/models/buildingMLModel/images2/2AnsarChalangov.jpg in style 2
# 1968 saving: src/models/buildingMLModel/images2/3AnsarChalangov.jpg in style 7
# 1968 saving: src/models/buildingMLModel/images2/4AnsarChalangov.jpg in style 7
# 1967 saving: src/models/buildingMLModel/images2/1DerrickNoble.jpg in style 5
# 1967 saving: src/models/buildingMLModel/images2/2DerrickNoble.jpg in style 6
# 1967 saving: src/models/buildingMLModel/images2/3DerrickNoble.jpg in style 4
# 1967 saving: src/models/buildingMLModel/images2/4DerrickNoble.jpg in style 0
# 1966 saving: src/models/buildingMLModel/images2/1DavidTerrell.jpg in style 4
# 1966 saving: src/models/buildingMLModel/images2/2DavidTerrell.jpg in style 1
# 1966 saving: src/models/buildingMLModel/images2/3DavidTerrell.jpg in style 3
# 1966 saving: src/models/buildingMLModel/images2/4DavidTerrell.jpg in style 5
# 1965 saving: src/models/buildingMLModel/images2/1NickThompson.jpg in style 3
# 1965 saving: src/models/buildingMLModel/images2/2NickThompson.jpg in style 7
# 1965 saving: src/models/buildingMLModel/images2/3NickThompson.jpg in style 1
# 1965 saving: src/models/buildingMLModel/images2/4NickThompson.jpg in style 3
# 1964 saving: src/models/buildingMLModel/images2/1RickDavis.jpg in style 1
# 1964 saving: src/models/buildingMLModel/images2/2RickDavis.jpg in style 1
# 1964 saving: src/models/buildingMLModel/images2/3RickDavis.jpg in style 1
# 1964 saving: src/models/buildingMLModel/images2/4RickDavis.jpg in style 6
# 1963 saving: src/models/buildingMLModel/images2/1FabianoScherner.jpg in style 5
# 1963 saving: src/models/buildingMLModel/images2/2FabianoScherner.jpg in style 5
# 1963 saving: src/models/buildingMLModel/images2/3FabianoScherner.jpg in style 1
# 1963 saving: src/models/buildingMLModel/images2/4FabianoScherner.jpg in style 6
# 1962 saving: src/models/buildingMLModel/images2/1RoyceGracie.jpg in style 4
# 1962 saving: src/models/buildingMLModel/images2/2RoyceGracie.jpg in style 4
# 1962 saving: src/models/buildingMLModel/images2/3RoyceGracie.jpg in style 4
# 1962 saving: src/models/buildingMLModel/images2/4RoyceGracie.jpg in style 5
# 1961 saving: src/models/buildingMLModel/images2/1SolomonHutcherson.jpg in style 1
# 1961 saving: src/models/buildingMLModel/images2/2SolomonHutcherson.jpg in style 2
# 1961 saving: src/models/buildingMLModel/images2/3SolomonHutcherson.jpg in style 0
# 1961 saving: src/models/buildingMLModel/images2/4SolomonHutcherson.jpg in style 5
# 1960 saving: src/models/buildingMLModel/images2/1JustinLevens.jpg in style 1
# 1960 saving: src/models/buildingMLModel/images2/2JustinLevens.jpg in style 0
# 1960 saving: src/models/buildingMLModel/images2/3JustinLevens.jpg in style 0
# 1960 saving: src/models/buildingMLModel/images2/4JustinLevens.jpg in style 1
# 1959 saving: src/models/buildingMLModel/images2/1KristianRothaermel.jpg in style 0
# 1959 saving: src/models/buildingMLModel/images2/2KristianRothaermel.jpg in style 6
# 1959 saving: src/models/buildingMLModel/images2/3KristianRothaermel.jpg in style 4
# 1959 saving: src/models/buildingMLModel/images2/4KristianRothaermel.jpg in style 5
# 1958 saving: src/models/buildingMLModel/images2/1BrandenLeeHinkle.jpg in style 1
# 1958 saving: src/models/buildingMLModel/images2/2BrandenLeeHinkle.jpg in style 1
# 1958 saving: src/models/buildingMLModel/images2/3BrandenLeeHinkle.jpg in style 1
# 1958 saving: src/models/buildingMLModel/images2/4BrandenLeeHinkle.jpg in style 4
# 1957 saving: src/models/buildingMLModel/images2/1GilbertAldana.jpg in style 5
# 1957 saving: src/models/buildingMLModel/images2/2GilbertAldana.jpg in style 7
# 1957 saving: src/models/buildingMLModel/images2/3GilbertAldana.jpg in style 1
# 1957 saving: src/models/buildingMLModel/images2/4GilbertAldana.jpg in style 5
# 1956 saving: src/models/buildingMLModel/images2/1JoeJordan.jpg in style 4
# 1956 saving: src/models/buildingMLModel/images2/2JoeJordan.jpg in style 1
# 1956 saving: src/models/buildingMLModel/images2/3JoeJordan.jpg in style 5
# 1956 saving: src/models/buildingMLModel/images2/4JoeJordan.jpg in style 5
# 1955 saving: src/models/buildingMLModel/images2/1DanChristison.jpg in style 5
# 1955 saving: src/models/buildingMLModel/images2/2DanChristison.jpg in style 1
# 1955 saving: src/models/buildingMLModel/images2/3DanChristison.jpg in style 6
# 1955 saving: src/models/buildingMLModel/images2/4DanChristison.jpg in style 3
# 1954 saving: src/models/buildingMLModel/images2/1SammyMorgan.jpg in style 5
# 1954 saving: src/models/buildingMLModel/images2/2SammyMorgan.jpg in style 3
# 1954 saving: src/models/buildingMLModel/images2/3SammyMorgan.jpg in style 5
# 1954 saving: src/models/buildingMLModel/images2/4SammyMorgan.jpg in style 5
# 1953 saving: src/models/buildingMLModel/images2/1KristofMidoux.jpg in style 1
# 1953 saving: src/models/buildingMLModel/images2/2KristofMidoux.jpg in style 4
# 1953 saving: src/models/buildingMLModel/images2/3KristofMidoux.jpg in style 3
# 1953 saving: src/models/buildingMLModel/images2/4KristofMidoux.jpg in style 5
# 1952 saving: src/models/buildingMLModel/images2/1JasonVonFlue.jpg in style 1
# 1952 saving: src/models/buildingMLModel/images2/2JasonVonFlue.jpg in style 5
# 1952 saving: src/models/buildingMLModel/images2/3JasonVonFlue.jpg in style 0
# 1952 saving: src/models/buildingMLModel/images2/4JasonVonFlue.jpg in style 4
# 1951 saving: src/models/buildingMLModel/images2/1YukiSasaki.jpg in style 2
# 1951 saving: src/models/buildingMLModel/images2/2YukiSasaki.jpg in style 5
# 1951 saving: src/models/buildingMLModel/images2/3YukiSasaki.jpg in style 4
# 1951 saving: src/models/buildingMLModel/images2/4YukiSasaki.jpg in style 5
# 1950 saving: src/models/buildingMLModel/images2/1CoryWalmsley.jpg in style 3
# 1950 saving: src/models/buildingMLModel/images2/2CoryWalmsley.jpg in style 4
# 1950 saving: src/models/buildingMLModel/images2/3CoryWalmsley.jpg in style 4
# 1950 saving: src/models/buildingMLModel/images2/4CoryWalmsley.jpg in style 7
# 1949 saving: src/models/buildingMLModel/images2/1WesCombs.jpg in style 1
# 1949 saving: src/models/buildingMLModel/images2/2WesCombs.jpg in style 1
# 1949 saving: src/models/buildingMLModel/images2/3WesCombs.jpg in style 4
# 1949 saving: src/models/buildingMLModel/images2/4WesCombs.jpg in style 7
# 1948 saving: src/models/buildingMLModel/images2/1RobMacDonald.jpg in style 4
# 1948 saving: src/models/buildingMLModel/images2/2RobMacDonald.jpg in style 1
# 1948 saving: src/models/buildingMLModel/images2/3RobMacDonald.jpg in style 5
# 1948 saving: src/models/buildingMLModel/images2/4RobMacDonald.jpg in style 1
# 1947 saving: src/models/buildingMLModel/images2/1DannyAbbadi.jpg in style 6
# 1947 saving: src/models/buildingMLModel/images2/2DannyAbbadi.jpg in style 6
# 1947 saving: src/models/buildingMLModel/images2/3DannyAbbadi.jpg in style 3
# 1947 saving: src/models/buildingMLModel/images2/4DannyAbbadi.jpg in style 5
# 1946 saving: src/models/buildingMLModel/images2/1MarioNeto.jpg in style 7
# 1946 saving: src/models/buildingMLModel/images2/2MarioNeto.jpg in style 0
# 1946 saving: src/models/buildingMLModel/images2/3MarioNeto.jpg in style 6
# 1946 saving: src/models/buildingMLModel/images2/4MarioNeto.jpg in style 4
# 1945 saving: src/models/buildingMLModel/images2/1CraftonWallace.jpg in style 5
# 1945 saving: src/models/buildingMLModel/images2/2CraftonWallace.jpg in style 1
# 1945 saving: src/models/buildingMLModel/images2/3CraftonWallace.jpg in style 2
# 1945 saving: src/models/buildingMLModel/images2/4CraftonWallace.jpg in style 1
# 1944 saving: src/models/buildingMLModel/images2/1KenShamrock.jpg in style 2
# 1944 saving: src/models/buildingMLModel/images2/2KenShamrock.jpg in style 6
# 1944 saving: src/models/buildingMLModel/images2/3KenShamrock.jpg in style 7
# 1944 saving: src/models/buildingMLModel/images2/4KenShamrock.jpg in style 5
# 1943 saving: src/models/buildingMLModel/images2/1JustinJames.jpg in style 3
# 1943 saving: src/models/buildingMLModel/images2/2JustinJames.jpg in style 4
# 1943 saving: src/models/buildingMLModel/images2/3JustinJames.jpg in style 0
# 1943 saving: src/models/buildingMLModel/images2/4JustinJames.jpg in style 1
# 1942 saving: src/models/buildingMLModel/images2/1GideonRay.jpg in style 3
# 1942 saving: src/models/buildingMLModel/images2/2GideonRay.jpg in style 7
# 1942 saving: src/models/buildingMLModel/images2/3GideonRay.jpg in style 1
# 1942 saving: src/models/buildingMLModel/images2/4GideonRay.jpg in style 3
# 1941 saving: src/models/buildingMLModel/images2/1JeremyJackson.jpg in style 2
# 1941 saving: src/models/buildingMLModel/images2/2JeremyJackson.jpg in style 1
# 1941 saving: src/models/buildingMLModel/images2/3JeremyJackson.jpg in style 5
# 1941 saving: src/models/buildingMLModel/images2/4JeremyJackson.jpg in style 2
# 1940 saving: src/models/buildingMLModel/images2/1EdwinDeWees.jpg in style 1
# 1940 saving: src/models/buildingMLModel/images2/2EdwinDeWees.jpg in style 3
# 1940 saving: src/models/buildingMLModel/images2/3EdwinDeWees.jpg in style 5
# 1940 saving: src/models/buildingMLModel/images2/4EdwinDeWees.jpg in style 3
# 1939 saving: src/models/buildingMLModel/images2/1JoshShockman.jpg in style 7
# 1939 saving: src/models/buildingMLModel/images2/2JoshShockman.jpg in style 1
# 1939 saving: src/models/buildingMLModel/images2/3JoshShockman.jpg in style 1
# 1939 saving: src/models/buildingMLModel/images2/4JoshShockman.jpg in style 1
# 1938 saving: src/models/buildingMLModel/images2/1ShermanPendergarst.jpg in style 1
# 1938 saving: src/models/buildingMLModel/images2/2ShermanPendergarst.jpg in style 6
# 1938 saving: src/models/buildingMLModel/images2/3ShermanPendergarst.jpg in style 2
# 1938 saving: src/models/buildingMLModel/images2/4ShermanPendergarst.jpg in style 1
# 1937 saving: src/models/buildingMLModel/images2/1JeffMonson.jpg in style 0
# 1937 saving: src/models/buildingMLModel/images2/2JeffMonson.jpg in style 1
# 1937 saving: src/models/buildingMLModel/images2/3JeffMonson.jpg in style 6
# 1937 saving: src/models/buildingMLModel/images2/4JeffMonson.jpg in style 6
# 1936 saving: src/models/buildingMLModel/images2/1SteveByrnes.jpg in style 5
# 1936 saving: src/models/buildingMLModel/images2/2SteveByrnes.jpg in style 6
# 1936 saving: src/models/buildingMLModel/images2/3SteveByrnes.jpg in style 6
# 1936 saving: src/models/buildingMLModel/images2/4SteveByrnes.jpg in style 2
# 1935 saving: src/models/buildingMLModel/images2/1LoganClark.jpg in style 3
# 1935 saving: src/models/buildingMLModel/images2/2LoganClark.jpg in style 3
# 1935 saving: src/models/buildingMLModel/images2/3LoganClark.jpg in style 6
# 1935 saving: src/models/buildingMLModel/images2/4LoganClark.jpg in style 6
# 1934 saving: src/models/buildingMLModel/images2/1DaveMenne.jpg in style 2
# 1934 saving: src/models/buildingMLModel/images2/2DaveMenne.jpg in style 2
# 1934 saving: src/models/buildingMLModel/images2/3DaveMenne.jpg in style 6
# 1934 saving: src/models/buildingMLModel/images2/4DaveMenne.jpg in style 6

# %%
#1971(3) at 8:13pm
#1960(3) at 9:01pm
#1945(3) at 10:07pm
#that is 26 names per 114 minutes, or .23 names per minute
#still needed:
#1200-1960 (760 names on laptop at 13.75 per hour)= 55 hours
#314-800 (486 names on home desktop at 4.7 per hour) = 103 hours
#800-1200 (400 names on work desktop at 4.7 per hour? = 85 hours
#(haven't tested but started at 800 around 5pm Thursday))
#idea: use the computer lab...

# %%
#trying parallel 
#started at 2:23 am friday april 8
i=1936
for name in names[1935:880:-1]:
    i-=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
            fighterimage=fighterimage.resize((256,256))
            content_img = image_loader(fighterimage)
            styleindex=random.randint(1,len(style))-1
            output = 'empty'
            k=0
            while output =='empty':
                if k>len(style):
                    print(str(j)+' couldnt find a good style for '+str(j)+name)
                    break
                k+=1
                input_img = content_img.clone()
                styleindex=(styleindex+1)%len(style)
                output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                   content_img, styleindex, input_img, num_steps=300,
                                   style_weight=1000000, content_weight=1)
            img1 = output
            save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
        except:
            print('exception')
            continue
# Out:
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_1356/2228601904.py:129: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_1356/2228601904.py:130: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 1935 saving: src/models/buildingMLModel/images2/1LoganClark.jpg in style 6
# 1935 saving: src/models/buildingMLModel/images2/2LoganClark.jpg in style 6
# 1935 saving: src/models/buildingMLModel/images2/3LoganClark.jpg in style 9
# 1935 saving: src/models/buildingMLModel/images2/4LoganClark.jpg in style 3
# 1934 saving: src/models/buildingMLModel/images2/1DaveMenne.jpg in style 5
# 1934 saving: src/models/buildingMLModel/images2/2DaveMenne.jpg in style 5
# 1934 saving: src/models/buildingMLModel/images2/3DaveMenne.jpg in style 0
# 1934 saving: src/models/buildingMLModel/images2/4DaveMenne.jpg in style 6
# 1933 saving: src/models/buildingMLModel/images2/1ShonieCarter.jpg in style 6
# 1933 saving: src/models/buildingMLModel/images2/2ShonieCarter.jpg in style 6
# 1933 saving: src/models/buildingMLModel/images2/3ShonieCarter.jpg in style 7
# 1933 saving: src/models/buildingMLModel/images2/4ShonieCarter.jpg in style 5
# 1932 saving: src/models/buildingMLModel/images2/1JeffJoslin.jpg in style 4
# 1932 saving: src/models/buildingMLModel/images2/2JeffJoslin.jpg in style 5
# 1932 saving: src/models/buildingMLModel/images2/3JeffJoslin.jpg in style 6
# 1932 saving: src/models/buildingMLModel/images2/4JeffJoslin.jpg in style 4
# 1931 saving: src/models/buildingMLModel/images2/1MarcioCruz.jpg in style 8
# 1931 saving: src/models/buildingMLModel/images2/2MarcioCruz.jpg in style 6
# 1931 saving: src/models/buildingMLModel/images2/3MarcioCruz.jpg in style 3
# 1931 saving: src/models/buildingMLModel/images2/4MarcioCruz.jpg in style 5
# 1930 saving: src/models/buildingMLModel/images2/1RossPointon.jpg in style 3
# 1930 saving: src/models/buildingMLModel/images2/2RossPointon.jpg in style 9
# 1930 saving: src/models/buildingMLModel/images2/3RossPointon.jpg in style 7
# 1930 saving: src/models/buildingMLModel/images2/4RossPointon.jpg in style 5
# 1929 saving: src/models/buildingMLModel/images2/1ChrisPrice.jpg in style 10
# 1929 saving: src/models/buildingMLModel/images2/2ChrisPrice.jpg in style 4
# 1929 saving: src/models/buildingMLModel/images2/3ChrisPrice.jpg in style 5
# 1929 saving: src/models/buildingMLModel/images2/4ChrisPrice.jpg in style 7
# 1928 saving: src/models/buildingMLModel/images2/1SamHoger.jpg in style 5
# 1928 saving: src/models/buildingMLModel/images2/2SamHoger.jpg in style 7
# 1928 saving: src/models/buildingMLModel/images2/3SamHoger.jpg in style 6
# 1928 saving: src/models/buildingMLModel/images2/4SamHoger.jpg in style 8
# 1927 saving: src/models/buildingMLModel/images2/1RexHolman.jpg in style 4
# 1927 saving: src/models/buildingMLModel/images2/2RexHolman.jpg in style 5
# 1927 saving: src/models/buildingMLModel/images2/3RexHolman.jpg in style 6
# 1927 saving: src/models/buildingMLModel/images2/4RexHolman.jpg in style 5
# 1926 saving: src/models/buildingMLModel/images2/1DrewFickett.jpg in style 5
# 1926 saving: src/models/buildingMLModel/images2/2DrewFickett.jpg in style 5
# 1926 saving: src/models/buildingMLModel/images2/3DrewFickett.jpg in style 6
# 1926 saving: src/models/buildingMLModel/images2/4DrewFickett.jpg in style 8
# 1925 saving: src/models/buildingMLModel/images2/1DokonjonosukeMishima.jpg in style 5
# 1925 saving: src/models/buildingMLModel/images2/2DokonjonosukeMishima.jpg in style 5
# 1925 saving: src/models/buildingMLModel/images2/3DokonjonosukeMishima.jpg in style 6
# 1925 saving: src/models/buildingMLModel/images2/4DokonjonosukeMishima.jpg in style 5
# 1924 saving: src/models/buildingMLModel/images2/1JoshHaynes.jpg in style 5
# 1924 saving: src/models/buildingMLModel/images2/2JoshHaynes.jpg in style 5
# 1924 saving: src/models/buildingMLModel/images2/3JoshHaynes.jpg in style 8
# 1924 saving: src/models/buildingMLModel/images2/4JoshHaynes.jpg in style 5
# 1923 saving: src/models/buildingMLModel/images2/1BradImes.jpg in style 7
# 1923 saving: src/models/buildingMLModel/images2/2BradImes.jpg in style 7
# 1923 saving: src/models/buildingMLModel/images2/3BradImes.jpg in style 3
# 1923 saving: src/models/buildingMLModel/images2/4BradImes.jpg in style 3
# 1922 saving: src/models/buildingMLModel/images2/1VictorValimaki.jpg in style 7
# 1922 saving: src/models/buildingMLModel/images2/2VictorValimaki.jpg in style 7
# 1922 saving: src/models/buildingMLModel/images2/3VictorValimaki.jpg in style 5
# 1922 saving: src/models/buildingMLModel/images2/4VictorValimaki.jpg in style 5
# 1921 saving: src/models/buildingMLModel/images2/1DavidLee.jpg in style 9
# 1921 saving: src/models/buildingMLModel/images2/2DavidLee.jpg in style 3
# 1921 saving: src/models/buildingMLModel/images2/3DavidLee.jpg in style 5
# 1921 saving: src/models/buildingMLModel/images2/4DavidLee.jpg in style 5
# 1920 saving: src/models/buildingMLModel/images2/1AssuerioSilva.jpg in style 4
# 1920 saving: src/models/buildingMLModel/images2/2AssuerioSilva.jpg in style 5
# 1920 saving: src/models/buildingMLModel/images2/3AssuerioSilva.jpg in style 5
# 1920 saving: src/models/buildingMLModel/images2/4AssuerioSilva.jpg in style 9
# 1919 saving: src/models/buildingMLModel/images2/1ElvisSinosic.jpg in style 4
# 1919 saving: src/models/buildingMLModel/images2/2ElvisSinosic.jpg in style 8
# 1919 saving: src/models/buildingMLModel/images2/3ElvisSinosic.jpg in style 9
# 1919 saving: src/models/buildingMLModel/images2/4ElvisSinosic.jpg in style 5
# 1918 saving: src/models/buildingMLModel/images2/1SeanSalmon.jpg in style 9
# 1918 saving: src/models/buildingMLModel/images2/2SeanSalmon.jpg in style 5
# 1918 saving: src/models/buildingMLModel/images2/3SeanSalmon.jpg in style 2
# 1918 saving: src/models/buildingMLModel/images2/4SeanSalmon.jpg in style 5
# 1917 saving: src/models/buildingMLModel/images2/1ChadReiner.jpg in style 5
# 1917 saving: src/models/buildingMLModel/images2/2ChadReiner.jpg in style 5
# 3 couldnt find a good style for 3ChadReiner
# 1917 saving: src/models/buildingMLModel/images2/4ChadReiner.jpg in style 10
# 1916 saving: src/models/buildingMLModel/images2/1PeteSpratt.jpg in style 2
# 1916 saving: src/models/buildingMLModel/images2/2PeteSpratt.jpg in style 9
# 1916 saving: src/models/buildingMLModel/images2/3PeteSpratt.jpg in style 5
# 1916 saving: src/models/buildingMLModel/images2/4PeteSpratt.jpg in style 7
# 1915 saving: src/models/buildingMLModel/images2/1StevieLynch.jpg in style 5
# 1915 saving: src/models/buildingMLModel/images2/2StevieLynch.jpg in style 9
# 1915 saving: src/models/buildingMLModel/images2/3StevieLynch.jpg in style 3
# 1915 saving: src/models/buildingMLModel/images2/4StevieLynch.jpg in style 5
# 1914 saving: src/models/buildingMLModel/images2/1ScottSmith.jpg in style 2
# 1914 saving: src/models/buildingMLModel/images2/2ScottSmith.jpg in style 3
# 1914 saving: src/models/buildingMLModel/images2/3ScottSmith.jpg in style 7
# 1914 saving: src/models/buildingMLModel/images2/4ScottSmith.jpg in style 4
# 1913 saving: src/models/buildingMLModel/images2/1RorySinger.jpg in style 0
# 1913 saving: src/models/buildingMLModel/images2/2RorySinger.jpg in style 5
# 1913 saving: src/models/buildingMLModel/images2/3RorySinger.jpg in style 0
# 1913 saving: src/models/buildingMLModel/images2/4RorySinger.jpg in style 9
# 1912 saving: src/models/buildingMLModel/images2/1HectorRamirez.jpg in style 9
# 1912 saving: src/models/buildingMLModel/images2/2HectorRamirez.jpg in style 9
# 1912 saving: src/models/buildingMLModel/images2/3HectorRamirez.jpg in style 5
# 1912 saving: src/models/buildingMLModel/images2/4HectorRamirez.jpg in style 10
# 1911 saving: src/models/buildingMLModel/images2/1BrianGeraghty.jpg in style 3
# 1911 saving: src/models/buildingMLModel/images2/2BrianGeraghty.jpg in style 5
# 1911 saving: src/models/buildingMLModel/images2/3BrianGeraghty.jpg in style 6
# 1911 saving: src/models/buildingMLModel/images2/4BrianGeraghty.jpg in style 2
# 1910 saving: src/models/buildingMLModel/images2/1AllenBerube.jpg in style 5
# 1910 saving: src/models/buildingMLModel/images2/2AllenBerube.jpg in style 4
# 1910 saving: src/models/buildingMLModel/images2/3AllenBerube.jpg in style 7
# 1910 saving: src/models/buildingMLModel/images2/4AllenBerube.jpg in style 9
# 1909 saving: src/models/buildingMLModel/images2/1AndyWang.jpg in style 8
# 1909 saving: src/models/buildingMLModel/images2/2AndyWang.jpg in style 9
# 1909 saving: src/models/buildingMLModel/images2/3AndyWang.jpg in style 2
# 1909 saving: src/models/buildingMLModel/images2/4AndyWang.jpg in style 5
# 1908 saving: src/models/buildingMLModel/images2/1BrandonMelendez.jpg in style 9
# 1908 saving: src/models/buildingMLModel/images2/2BrandonMelendez.jpg in style 9
# 1908 saving: src/models/buildingMLModel/images2/3BrandonMelendez.jpg in style 5
# 1908 saving: src/models/buildingMLModel/images2/4BrandonMelendez.jpg in style 7
# 1907 saving: src/models/buildingMLModel/images2/1FloydSword.jpg in style 3
# 1907 saving: src/models/buildingMLModel/images2/2FloydSword.jpg in style 5
# 1907 saving: src/models/buildingMLModel/images2/3FloydSword.jpg in style 3
# 4 couldnt find a good style for 4FloydSword
# 1906 saving: src/models/buildingMLModel/images2/1JensPulver.jpg in style 9
# 1906 saving: src/models/buildingMLModel/images2/2JensPulver.jpg in style 6
# 1906 saving: src/models/buildingMLModel/images2/3JensPulver.jpg in style 9
# 1906 saving: src/models/buildingMLModel/images2/4JensPulver.jpg in style 3
# 1905 saving: src/models/buildingMLModel/images2/1JasonGilliam.jpg in style 2
# 1905 saving: src/models/buildingMLModel/images2/2JasonGilliam.jpg in style 4
# 1905 saving: src/models/buildingMLModel/images2/3JasonGilliam.jpg in style 5
# 1905 saving: src/models/buildingMLModel/images2/4JasonGilliam.jpg in style 4
# 1904 saving: src/models/buildingMLModel/images2/1MikeNickels.jpg in style 3
# 1904 saving: src/models/buildingMLModel/images2/2MikeNickels.jpg in style 5
# 1904 saving: src/models/buildingMLModel/images2/3MikeNickels.jpg in style 10
# 1904 saving: src/models/buildingMLModel/images2/4MikeNickels.jpg in style 5
# 1903 saving: src/models/buildingMLModel/images2/1RenatoSobral.jpg in style 5
# 1903 saving: src/models/buildingMLModel/images2/2RenatoSobral.jpg in style 3
# 1903 saving: src/models/buildingMLModel/images2/3RenatoSobral.jpg in style 5
# 1903 saving: src/models/buildingMLModel/images2/4RenatoSobral.jpg in style 3
# 1902 saving: src/models/buildingMLModel/images2/1AnthonyTorres.jpg in style 5
# 1902 saving: src/models/buildingMLModel/images2/2AnthonyTorres.jpg in style 3
# 1902 saving: src/models/buildingMLModel/images2/3AnthonyTorres.jpg in style 0
# 1902 saving: src/models/buildingMLModel/images2/4AnthonyTorres.jpg in style 6
# 1901 saving: src/models/buildingMLModel/images2/1EdilbertodeOliveira.jpg in style 7
# 1901 saving: src/models/buildingMLModel/images2/2EdilbertodeOliveira.jpg in style 5
# 1901 saving: src/models/buildingMLModel/images2/3EdilbertodeOliveira.jpg in style 5
# 1901 saving: src/models/buildingMLModel/images2/4EdilbertodeOliveira.jpg in style 7
# 1900 saving: src/models/buildingMLModel/images2/1ScottJunk.jpg in style 3
# 1900 saving: src/models/buildingMLModel/images2/2ScottJunk.jpg in style 7
# 1900 saving: src/models/buildingMLModel/images2/3ScottJunk.jpg in style 5
# 1900 saving: src/models/buildingMLModel/images2/4ScottJunk.jpg in style 10
# 1899 saving: src/models/buildingMLModel/images2/1DiegoSaraiva.jpg in style 8
# 1899 saving: src/models/buildingMLModel/images2/2DiegoSaraiva.jpg in style 5
# 1899 saving: src/models/buildingMLModel/images2/3DiegoSaraiva.jpg in style 3
# 1899 saving: src/models/buildingMLModel/images2/4DiegoSaraiva.jpg in style 7
# 1898 saving: src/models/buildingMLModel/images2/1JasonBlack.jpg in style 7
# 1898 saving: src/models/buildingMLModel/images2/2JasonBlack.jpg in style 4
# 1898 saving: src/models/buildingMLModel/images2/3JasonBlack.jpg in style 0
# 1898 saving: src/models/buildingMLModel/images2/4JasonBlack.jpg in style 5
# 1897 saving: src/models/buildingMLModel/images2/1LukeCaudillo.jpg in style 2
# 1897 saving: src/models/buildingMLModel/images2/2LukeCaudillo.jpg in style 5
# 1897 saving: src/models/buildingMLModel/images2/3LukeCaudillo.jpg in style 9
# 1897 saving: src/models/buildingMLModel/images2/4LukeCaudillo.jpg in style 5
# 1896 saving: src/models/buildingMLModel/images2/1PaulGeorgieff.jpg in style 10
# 1896 saving: src/models/buildingMLModel/images2/2PaulGeorgieff.jpg in style 5
# 1896 saving: src/models/buildingMLModel/images2/3PaulGeorgieff.jpg in style 5
# 1896 saving: src/models/buildingMLModel/images2/4PaulGeorgieff.jpg in style 10
# 1895 saving: src/models/buildingMLModel/images2/1DorianPrice.jpg in style 3
# 1895 saving: src/models/buildingMLModel/images2/2DorianPrice.jpg in style 3
# 1895 saving: src/models/buildingMLModel/images2/3DorianPrice.jpg in style 2
# 1895 saving: src/models/buildingMLModel/images2/4DorianPrice.jpg in style 5
# 1894 saving: src/models/buildingMLModel/images2/1JohnKolosci.jpg in style 10
# 1894 saving: src/models/buildingMLModel/images2/2JohnKolosci.jpg in style 7
# 1894 saving: src/models/buildingMLModel/images2/3JohnKolosci.jpg in style 5
# 1894 saving: src/models/buildingMLModel/images2/4JohnKolosci.jpg in style 10
# 1893 saving: src/models/buildingMLModel/images2/1RichieHightower.jpg in style 6
# 1893 saving: src/models/buildingMLModel/images2/2RichieHightower.jpg in style 3
# 1893 saving: src/models/buildingMLModel/images2/3RichieHightower.jpg in style 8
# 1893 saving: src/models/buildingMLModel/images2/4RichieHightower.jpg in style 4
# 1892 saving: src/models/buildingMLModel/images2/1DanBarrera.jpg in style 7
# 1892 saving: src/models/buildingMLModel/images2/2DanBarrera.jpg in style 8
# 1892 saving: src/models/buildingMLModel/images2/3DanBarrera.jpg in style 5
# 1892 saving: src/models/buildingMLModel/images2/4DanBarrera.jpg in style 8
# 1891 saving: src/models/buildingMLModel/images2/1BillyMiles.jpg in style 4
# 1891 saving: src/models/buildingMLModel/images2/2BillyMiles.jpg in style 5
# 1891 saving: src/models/buildingMLModel/images2/3BillyMiles.jpg in style 5
# 1891 saving: src/models/buildingMLModel/images2/4BillyMiles.jpg in style 5
# 1890 saving: src/models/buildingMLModel/images2/1JaredRollins.jpg in style 7
# 1890 saving: src/models/buildingMLModel/images2/2JaredRollins.jpg in style 5
# 1890 saving: src/models/buildingMLModel/images2/3JaredRollins.jpg in style 7
# 1890 saving: src/models/buildingMLModel/images2/4JaredRollins.jpg in style 7
# 1889 saving: src/models/buildingMLModel/images2/1DougEvans.jpg in style 5
# 1889 saving: src/models/buildingMLModel/images2/2DougEvans.jpg in style 2
# 1889 saving: src/models/buildingMLModel/images2/3DougEvans.jpg in style 3
# 1889 saving: src/models/buildingMLModel/images2/4DougEvans.jpg in style 5
# 1888 saving: src/models/buildingMLModel/images2/1TonyDeSouza.jpg in style 2
# 1888 saving: src/models/buildingMLModel/images2/2TonyDeSouza.jpg in style 9
# 1888 saving: src/models/buildingMLModel/images2/3TonyDeSouza.jpg in style 5
# 1888 saving: src/models/buildingMLModel/images2/4TonyDeSouza.jpg in style 7
# 1887 saving: src/models/buildingMLModel/images2/1JordanRadev.jpg in style 10
# 1887 saving: src/models/buildingMLModel/images2/2JordanRadev.jpg in style 3
# 1887 saving: src/models/buildingMLModel/images2/3JordanRadev.jpg in style 6
# 1887 saving: src/models/buildingMLModel/images2/4JordanRadev.jpg in style 10
# 1886 saving: src/models/buildingMLModel/images2/1JamesLee.jpg in style 10
# 1886 saving: src/models/buildingMLModel/images2/2JamesLee.jpg in style 8
# 1886 saving: src/models/buildingMLModel/images2/3JamesLee.jpg in style 8
# 1886 saving: src/models/buildingMLModel/images2/4JamesLee.jpg in style 2
# 1885 saving: src/models/buildingMLModel/images2/1ColinRobinson.jpg in style 5
# 1885 saving: src/models/buildingMLModel/images2/2ColinRobinson.jpg in style 3
# 1885 saving: src/models/buildingMLModel/images2/3ColinRobinson.jpg in style 9
# 1885 saving: src/models/buildingMLModel/images2/4ColinRobinson.jpg in style 3
# 1884 saving: src/models/buildingMLModel/images2/1JoeVeres.jpg in style 5
# 1884 saving: src/models/buildingMLModel/images2/2JoeVeres.jpg in style 7
# 1884 saving: src/models/buildingMLModel/images2/3JoeVeres.jpg in style 10
# 1884 saving: src/models/buildingMLModel/images2/4JoeVeres.jpg in style 4
# 1883 saving: src/models/buildingMLModel/images2/1AlbertoCrane.jpg in style 0
# 1883 saving: src/models/buildingMLModel/images2/2AlbertoCrane.jpg in style 4
# 1883 saving: src/models/buildingMLModel/images2/3AlbertoCrane.jpg in style 5
# 1883 saving: src/models/buildingMLModel/images2/4AlbertoCrane.jpg in style 7
# 1882 saving: src/models/buildingMLModel/images2/1TerryMartin.jpg in style 5
# 1882 saving: src/models/buildingMLModel/images2/2TerryMartin.jpg in style 5
# 1882 saving: src/models/buildingMLModel/images2/3TerryMartin.jpg in style 0
# 1882 saving: src/models/buildingMLModel/images2/4TerryMartin.jpg in style 5
# 1881 saving: src/models/buildingMLModel/images2/1DavidHeath.jpg in style 7
# 1881 saving: src/models/buildingMLModel/images2/2DavidHeath.jpg in style 6
# 1881 saving: src/models/buildingMLModel/images2/3DavidHeath.jpg in style 8
# 1881 saving: src/models/buildingMLModel/images2/4DavidHeath.jpg in style 5
# 1880 saving: src/models/buildingMLModel/images2/1TimSylvia.jpg in style 4
# 1880 saving: src/models/buildingMLModel/images2/2TimSylvia.jpg in style 3
# 1880 saving: src/models/buildingMLModel/images2/3TimSylvia.jpg in style 4
# 1880 saving: src/models/buildingMLModel/images2/4TimSylvia.jpg in style 4
# 1879 saving: src/models/buildingMLModel/images2/1JohnHalverson.jpg in style 5
# 1879 saving: src/models/buildingMLModel/images2/2JohnHalverson.jpg in style 3
# 1879 saving: src/models/buildingMLModel/images2/3JohnHalverson.jpg in style 4
# 1879 saving: src/models/buildingMLModel/images2/4JohnHalverson.jpg in style 3
# 1878 saving: src/models/buildingMLModel/images2/1TommySpeer.jpg in style 5
# 1878 saving: src/models/buildingMLModel/images2/2TommySpeer.jpg in style 10
# 1878 saving: src/models/buildingMLModel/images2/3TommySpeer.jpg in style 8
# 1878 saving: src/models/buildingMLModel/images2/4TommySpeer.jpg in style 3
# 1877 saving: src/models/buildingMLModel/images2/1RomanMitichyan.jpg in style 9
# 1877 saving: src/models/buildingMLModel/images2/2RomanMitichyan.jpg in style 5
# 1877 saving: src/models/buildingMLModel/images2/3RomanMitichyan.jpg in style 9
# 1877 saving: src/models/buildingMLModel/images2/4RomanMitichyan.jpg in style 9
# 1876 saving: src/models/buildingMLModel/images2/1JeffCox.jpg in style 3
# 1876 saving: src/models/buildingMLModel/images2/2JeffCox.jpg in style 3
# 1876 saving: src/models/buildingMLModel/images2/3JeffCox.jpg in style 5
# 1876 saving: src/models/buildingMLModel/images2/4JeffCox.jpg in style 3
# 1875 saving: src/models/buildingMLModel/images2/1RyanRoberts.jpg in style 5
# 1875 saving: src/models/buildingMLModel/images2/2RyanRoberts.jpg in style 3
# 1875 saving: src/models/buildingMLModel/images2/3RyanRoberts.jpg in style 7
# 1875 saving: src/models/buildingMLModel/images2/4RyanRoberts.jpg in style 7
# 1874 saving: src/models/buildingMLModel/images2/1DinThomas.jpg in style 7
# 1874 saving: src/models/buildingMLModel/images2/2DinThomas.jpg in style 5
# 1874 saving: src/models/buildingMLModel/images2/3DinThomas.jpg in style 4
# 1874 saving: src/models/buildingMLModel/images2/4DinThomas.jpg in style 6
# 1873 saving: src/models/buildingMLModel/images2/1KuniyoshiHironaka.jpg in style 5
# 1873 saving: src/models/buildingMLModel/images2/2KuniyoshiHironaka.jpg in style 3
# 1873 saving: src/models/buildingMLModel/images2/3KuniyoshiHironaka.jpg in style 6
# 1873 saving: src/models/buildingMLModel/images2/4KuniyoshiHironaka.jpg in style 4
# 1872 saving: src/models/buildingMLModel/images2/1CharlesMcCarthy.jpg in style 5
# 1872 saving: src/models/buildingMLModel/images2/2CharlesMcCarthy.jpg in style 5
# 1872 saving: src/models/buildingMLModel/images2/3CharlesMcCarthy.jpg in style 5
# 1872 saving: src/models/buildingMLModel/images2/4CharlesMcCarthy.jpg in style 8
# 1871 saving: src/models/buildingMLModel/images2/1KalibStarnes.jpg in style 5
# 1871 saving: src/models/buildingMLModel/images2/2KalibStarnes.jpg in style 10
# 1871 saving: src/models/buildingMLModel/images2/3KalibStarnes.jpg in style 5
# 1871 saving: src/models/buildingMLModel/images2/4KalibStarnes.jpg in style 5
# 1870 saving: src/models/buildingMLModel/images2/1TravisLutter.jpg in style 3
# 1870 saving: src/models/buildingMLModel/images2/2TravisLutter.jpg in style 3
# 1870 saving: src/models/buildingMLModel/images2/3TravisLutter.jpg in style 5
# 1870 saving: src/models/buildingMLModel/images2/4TravisLutter.jpg in style 3
# 1869 saving: src/models/buildingMLModel/images2/1JasonTan.jpg in style 6
# 1869 saving: src/models/buildingMLModel/images2/2JasonTan.jpg in style 7
# 1869 saving: src/models/buildingMLModel/images2/3JasonTan.jpg in style 2
# 1869 saving: src/models/buildingMLModel/images2/4JasonTan.jpg in style 10
# 1868 saving: src/models/buildingMLModel/images2/1WarMachine.jpg in style 5
# 1868 saving: src/models/buildingMLModel/images2/2WarMachine.jpg in style 10
# 1868 saving: src/models/buildingMLModel/images2/3WarMachine.jpg in style 9
# 1868 saving: src/models/buildingMLModel/images2/4WarMachine.jpg in style 0
# 1867 saving: src/models/buildingMLModel/images2/1KazuhiroNakamura.jpg in style 10
# 1867 saving: src/models/buildingMLModel/images2/2KazuhiroNakamura.jpg in style 7
# 1867 saving: src/models/buildingMLModel/images2/3KazuhiroNakamura.jpg in style 9
# 1867 saving: src/models/buildingMLModel/images2/4KazuhiroNakamura.jpg in style 5
# 1866 saving: src/models/buildingMLModel/images2/1IvanSalaverry.jpg in style 4
# 1866 saving: src/models/buildingMLModel/images2/2IvanSalaverry.jpg in style 7
# 1866 saving: src/models/buildingMLModel/images2/3IvanSalaverry.jpg in style 5
# 1866 saving: src/models/buildingMLModel/images2/4IvanSalaverry.jpg in style 5
# 1865 saving: src/models/buildingMLModel/images2/1RobYundt.jpg in style 3
# 1865 saving: src/models/buildingMLModel/images2/2RobYundt.jpg in style 9
# 1865 saving: src/models/buildingMLModel/images2/3RobYundt.jpg in style 3
# 1865 saving: src/models/buildingMLModel/images2/4RobYundt.jpg in style 5
# 1864 saving: src/models/buildingMLModel/images2/1MarvinEastman.jpg in style 4
# 1864 saving: src/models/buildingMLModel/images2/2MarvinEastman.jpg in style 3
# 1864 saving: src/models/buildingMLModel/images2/3MarvinEastman.jpg in style 10
# 1864 saving: src/models/buildingMLModel/images2/4MarvinEastman.jpg in style 7
# 1863 saving: src/models/buildingMLModel/images2/1DanteRivera.jpg in style 3
# 1863 saving: src/models/buildingMLModel/images2/2DanteRivera.jpg in style 10
# 1863 saving: src/models/buildingMLModel/images2/3DanteRivera.jpg in style 5
# 1863 saving: src/models/buildingMLModel/images2/4DanteRivera.jpg in style 5
# 1862 saving: src/models/buildingMLModel/images2/1EvanTanner.jpg in style 5
# 1862 saving: src/models/buildingMLModel/images2/2EvanTanner.jpg in style 9
# 1862 saving: src/models/buildingMLModel/images2/3EvanTanner.jpg in style 6
# 1862 saving: src/models/buildingMLModel/images2/4EvanTanner.jpg in style 3
# 1861 saving: src/models/buildingMLModel/images2/1JamesGiboo.jpg in style 3
# 1861 saving: src/models/buildingMLModel/images2/2JamesGiboo.jpg in style 7
# 1861 saving: src/models/buildingMLModel/images2/3JamesGiboo.jpg in style 3
# 1861 saving: src/models/buildingMLModel/images2/4JamesGiboo.jpg in style 5
# 1860 saving: src/models/buildingMLModel/images2/1CaleYarbrough.jpg in style 5
# 1860 saving: src/models/buildingMLModel/images2/2CaleYarbrough.jpg in style 5
# 1860 saving: src/models/buildingMLModel/images2/3CaleYarbrough.jpg in style 9
# 1860 saving: src/models/buildingMLModel/images2/4CaleYarbrough.jpg in style 5
# 1 couldnt find a good style for 1LukeCummo
# 1859 saving: src/models/buildingMLModel/images2/2LukeCummo.jpg in style 2
# 1859 saving: src/models/buildingMLModel/images2/3LukeCummo.jpg in style 6
# 1859 saving: src/models/buildingMLModel/images2/4LukeCummo.jpg in style 5
# 1858 saving: src/models/buildingMLModel/images2/1HeathHerring.jpg in style 6
# 1858 saving: src/models/buildingMLModel/images2/2HeathHerring.jpg in style 0
# 3 couldnt find a good style for 3HeathHerring
# 1858 saving: src/models/buildingMLModel/images2/4HeathHerring.jpg in style 5
# 1857 saving: src/models/buildingMLModel/images2/1JasonLambert.jpg in style 5
# 1857 saving: src/models/buildingMLModel/images2/2JasonLambert.jpg in style 5
# 1857 saving: src/models/buildingMLModel/images2/3JasonLambert.jpg in style 5
# 1857 saving: src/models/buildingMLModel/images2/4JasonLambert.jpg in style 4
# 1856 saving: src/models/buildingMLModel/images2/1BradMorris.jpg in style 5
# 1856 saving: src/models/buildingMLModel/images2/2BradMorris.jpg in style 9
# 1856 saving: src/models/buildingMLModel/images2/3BradMorris.jpg in style 5
# 1856 saving: src/models/buildingMLModel/images2/4BradMorris.jpg in style 4
# 1855 saving: src/models/buildingMLModel/images2/1SamySchiavo.jpg in style 5
# 1855 saving: src/models/buildingMLModel/images2/2SamySchiavo.jpg in style 6
# 1855 saving: src/models/buildingMLModel/images2/3SamySchiavo.jpg in style 5
# 1855 saving: src/models/buildingMLModel/images2/4SamySchiavo.jpg in style 3
# 1854 saving: src/models/buildingMLModel/images2/1DavidBaron.jpg in style 9
# 1854 saving: src/models/buildingMLModel/images2/2DavidBaron.jpg in style 5
# 1854 saving: src/models/buildingMLModel/images2/3DavidBaron.jpg in style 4
# 1854 saving: src/models/buildingMLModel/images2/4DavidBaron.jpg in style 6
# 1853 saving: src/models/buildingMLModel/images2/1JessLiaudin.jpg in style 5
# 1853 saving: src/models/buildingMLModel/images2/2JessLiaudin.jpg in style 8
# 1853 saving: src/models/buildingMLModel/images2/3JessLiaudin.jpg in style 3
# 1853 saving: src/models/buildingMLModel/images2/4JessLiaudin.jpg in style 9
# 1852 saving: src/models/buildingMLModel/images2/1NeilWain.jpg in style 3
# 1852 saving: src/models/buildingMLModel/images2/2NeilWain.jpg in style 5
# 1852 saving: src/models/buildingMLModel/images2/3NeilWain.jpg in style 9
# 1852 saving: src/models/buildingMLModel/images2/4NeilWain.jpg in style 5
# 1851 saving: src/models/buildingMLModel/images2/1RameauThierrySokoudjou.jpg in style 4
# 1851 saving: src/models/buildingMLModel/images2/2RameauThierrySokoudjou.jpg in style 7
# 1851 saving: src/models/buildingMLModel/images2/3RameauThierrySokoudjou.jpg in style 2
# 1851 saving: src/models/buildingMLModel/images2/4RameauThierrySokoudjou.jpg in style 5
# 1850 saving: src/models/buildingMLModel/images2/1RyanThomas.jpg in style 9
# 1850 saving: src/models/buildingMLModel/images2/2RyanThomas.jpg in style 9
# 1850 saving: src/models/buildingMLModel/images2/3RyanThomas.jpg in style 9
# 1850 saving: src/models/buildingMLModel/images2/4RyanThomas.jpg in style 10
# 1849 saving: src/models/buildingMLModel/images2/1AlvinRobinson.jpg in style 5
# 1849 saving: src/models/buildingMLModel/images2/2AlvinRobinson.jpg in style 5
# 1849 saving: src/models/buildingMLModel/images2/3AlvinRobinson.jpg in style 5
# 1849 saving: src/models/buildingMLModel/images2/4AlvinRobinson.jpg in style 2
# 1848 saving: src/models/buildingMLModel/images2/1JorgeGurgel.jpg in style 3
# 2 couldnt find a good style for 2JorgeGurgel
# 1848 saving: src/models/buildingMLModel/images2/3JorgeGurgel.jpg in style 5
# 1848 saving: src/models/buildingMLModel/images2/4JorgeGurgel.jpg in style 10
# 1847 saving: src/models/buildingMLModel/images2/1JoshHendricks.jpg in style 7
# 1847 saving: src/models/buildingMLModel/images2/2JoshHendricks.jpg in style 5
# 1847 saving: src/models/buildingMLModel/images2/3JoshHendricks.jpg in style 7
# 1847 saving: src/models/buildingMLModel/images2/4JoshHendricks.jpg in style 5
# 1846 saving: src/models/buildingMLModel/images2/1EddieSanchez.jpg in style 7
# 1846 saving: src/models/buildingMLModel/images2/2EddieSanchez.jpg in style 6
# 1846 saving: src/models/buildingMLModel/images2/3EddieSanchez.jpg in style 10
# 1846 saving: src/models/buildingMLModel/images2/4EddieSanchez.jpg in style 4
# 1845 saving: src/models/buildingMLModel/images2/1CoreyHill.jpg in style 5
# 1845 saving: src/models/buildingMLModel/images2/2CoreyHill.jpg in style 7
# 1845 saving: src/models/buildingMLModel/images2/3CoreyHill.jpg in style 3
# 1845 saving: src/models/buildingMLModel/images2/4CoreyHill.jpg in style 4
# 1844 saving: src/models/buildingMLModel/images2/1JohnnyRees.jpg in style 4
# 1844 saving: src/models/buildingMLModel/images2/2JohnnyRees.jpg in style 8
# 1844 saving: src/models/buildingMLModel/images2/3JohnnyRees.jpg in style 5
# 1844 saving: src/models/buildingMLModel/images2/4JohnnyRees.jpg in style 4
# 1843 saving: src/models/buildingMLModel/images2/1BrodieFarber.jpg in style 5
# 1843 saving: src/models/buildingMLModel/images2/2BrodieFarber.jpg in style 4
# 1843 saving: src/models/buildingMLModel/images2/3BrodieFarber.jpg in style 7
# 1843 saving: src/models/buildingMLModel/images2/4BrodieFarber.jpg in style 8
# 1842 saving: src/models/buildingMLModel/images2/1NateLoughran.jpg in style 8
# 1842 saving: src/models/buildingMLModel/images2/2NateLoughran.jpg in style 5
# 1842 saving: src/models/buildingMLModel/images2/3NateLoughran.jpg in style 9
# 1842 saving: src/models/buildingMLModel/images2/4NateLoughran.jpg in style 5
# 1841 saving: src/models/buildingMLModel/images2/1JohnPolakowski.jpg in style 2
# 1841 saving: src/models/buildingMLModel/images2/2JohnPolakowski.jpg in style 5
# 1841 saving: src/models/buildingMLModel/images2/3JohnPolakowski.jpg in style 5
# 1841 saving: src/models/buildingMLModel/images2/4JohnPolakowski.jpg in style 3
# 1840 saving: src/models/buildingMLModel/images2/1JulesBruchez.jpg in style 4
# 1840 saving: src/models/buildingMLModel/images2/2JulesBruchez.jpg in style 5
# 1840 saving: src/models/buildingMLModel/images2/3JulesBruchez.jpg in style 5
# 1840 saving: src/models/buildingMLModel/images2/4JulesBruchez.jpg in style 3
# 1839 saving: src/models/buildingMLModel/images2/1ShanePrimm.jpg in style 6
# 1839 saving: src/models/buildingMLModel/images2/2ShanePrimm.jpg in style 3
# 1839 saving: src/models/buildingMLModel/images2/3ShanePrimm.jpg in style 5
# 1839 saving: src/models/buildingMLModel/images2/4ShanePrimm.jpg in style 5
# 1838 saving: src/models/buildingMLModel/images2/1DanEvensen.jpg in style 8
# 1838 saving: src/models/buildingMLModel/images2/2DanEvensen.jpg in style 3
# 1838 saving: src/models/buildingMLModel/images2/3DanEvensen.jpg in style 6
# 1838 saving: src/models/buildingMLModel/images2/4DanEvensen.jpg in style 3
# 1837 saving: src/models/buildingMLModel/images2/1ReeseAndy.jpg in style 5
# 1837 saving: src/models/buildingMLModel/images2/2ReeseAndy.jpg in style 3
# 3 couldnt find a good style for 3ReeseAndy
# 1837 saving: src/models/buildingMLModel/images2/4ReeseAndy.jpg in style 4
# 1836 saving: src/models/buildingMLModel/images2/1MikeWessel.jpg in style 9
# 1836 saving: src/models/buildingMLModel/images2/2MikeWessel.jpg in style 5
# 1836 saving: src/models/buildingMLModel/images2/3MikeWessel.jpg in style 7
# 1836 saving: src/models/buildingMLModel/images2/4MikeWessel.jpg in style 4
# 1835 saving: src/models/buildingMLModel/images2/1DeanLister.jpg in style 9
# 1835 saving: src/models/buildingMLModel/images2/2DeanLister.jpg in style 5
# 1835 saving: src/models/buildingMLModel/images2/3DeanLister.jpg in style 5
# 1835 saving: src/models/buildingMLModel/images2/4DeanLister.jpg in style 3
# 1834 saving: src/models/buildingMLModel/images2/1NateMohr.jpg in style 9
# 1834 saving: src/models/buildingMLModel/images2/2NateMohr.jpg in style 7
# 1834 saving: src/models/buildingMLModel/images2/3NateMohr.jpg in style 5
# 1834 saving: src/models/buildingMLModel/images2/4NateMohr.jpg in style 5
# 1833 saving: src/models/buildingMLModel/images2/1IvanSerati.jpg in style 9
# 1833 saving: src/models/buildingMLModel/images2/2IvanSerati.jpg in style 4
# 1833 saving: src/models/buildingMLModel/images2/3IvanSerati.jpg in style 5
# 1833 saving: src/models/buildingMLModel/images2/4IvanSerati.jpg in style 5
# 1832 saving: src/models/buildingMLModel/images2/1AntonioMendes.jpg in style 5
# 1832 saving: src/models/buildingMLModel/images2/2AntonioMendes.jpg in style 3
# 1832 saving: src/models/buildingMLModel/images2/3AntonioMendes.jpg in style 5
# 1832 saving: src/models/buildingMLModel/images2/4AntonioMendes.jpg in style 5
# 1831 saving: src/models/buildingMLModel/images2/1AlexandreBarros.jpg in style 7
# 1831 saving: src/models/buildingMLModel/images2/2AlexandreBarros.jpg in style 9
# 1831 saving: src/models/buildingMLModel/images2/3AlexandreBarros.jpg in style 7
# 1831 saving: src/models/buildingMLModel/images2/4AlexandreBarros.jpg in style 7
# 1830 saving: src/models/buildingMLModel/images2/1TomEgan.jpg in style 6
# 1830 saving: src/models/buildingMLModel/images2/2TomEgan.jpg in style 0
# 1830 saving: src/models/buildingMLModel/images2/3TomEgan.jpg in style 3
# 1830 saving: src/models/buildingMLModel/images2/4TomEgan.jpg in style 8
# 1 couldnt find a good style for 1JeremyHorn
# 1829 saving: src/models/buildingMLModel/images2/2JeremyHorn.jpg in style 8
# 1829 saving: src/models/buildingMLModel/images2/3JeremyHorn.jpg in style 3
# 1829 saving: src/models/buildingMLModel/images2/4JeremyHorn.jpg in style 5
# 1828 saving: src/models/buildingMLModel/images2/1MattArroyo.jpg in style 9
# 1828 saving: src/models/buildingMLModel/images2/2MattArroyo.jpg in style 9
# 1828 saving: src/models/buildingMLModel/images2/3MattArroyo.jpg in style 8
# 1828 saving: src/models/buildingMLModel/images2/4MattArroyo.jpg in style 3
# 1827 saving: src/models/buildingMLModel/images2/1ChristianWellisch.jpg in style 8
# 1827 saving: src/models/buildingMLModel/images2/2ChristianWellisch.jpg in style 3
# 1827 saving: src/models/buildingMLModel/images2/3ChristianWellisch.jpg in style 7
# 1827 saving: src/models/buildingMLModel/images2/4ChristianWellisch.jpg in style 5
# 1826 saving: src/models/buildingMLModel/images2/1AkihiroGono.jpg in style 8
# 1826 saving: src/models/buildingMLModel/images2/2AkihiroGono.jpg in style 5
# 1826 saving: src/models/buildingMLModel/images2/3AkihiroGono.jpg in style 6
# 1826 saving: src/models/buildingMLModel/images2/4AkihiroGono.jpg in style 5
# 1825 saving: src/models/buildingMLModel/images2/1SteveBruno.jpg in style 7
# 1825 saving: src/models/buildingMLModel/images2/2SteveBruno.jpg in style 5
# 1825 saving: src/models/buildingMLModel/images2/3SteveBruno.jpg in style 7
# 1825 saving: src/models/buildingMLModel/images2/4SteveBruno.jpg in style 5
# 1 couldnt find a good style for 1DerekDowney
# 1824 saving: src/models/buildingMLModel/images2/2DerekDowney.jpg in style 0
# 1824 saving: src/models/buildingMLModel/images2/3DerekDowney.jpg in style 6
# 1824 saving: src/models/buildingMLModel/images2/4DerekDowney.jpg in style 3
# 1823 saving: src/models/buildingMLModel/images2/1RichClementi.jpg in style 3
# 1823 saving: src/models/buildingMLModel/images2/2RichClementi.jpg in style 4
# 1823 saving: src/models/buildingMLModel/images2/3RichClementi.jpg in style 7
# 1823 saving: src/models/buildingMLModel/images2/4RichClementi.jpg in style 5
# 1822 saving: src/models/buildingMLModel/images2/1LuigiFioravanti.jpg in style 3
# 1822 saving: src/models/buildingMLModel/images2/2LuigiFioravanti.jpg in style 6
# 1822 saving: src/models/buildingMLModel/images2/3LuigiFioravanti.jpg in style 9
# 1822 saving: src/models/buildingMLModel/images2/4LuigiFioravanti.jpg in style 9
# 1821 saving: src/models/buildingMLModel/images2/1TroyMandaloniz.jpg in style 9
# 1821 saving: src/models/buildingMLModel/images2/2TroyMandaloniz.jpg in style 9
# 1821 saving: src/models/buildingMLModel/images2/3TroyMandaloniz.jpg in style 3
# 1821 saving: src/models/buildingMLModel/images2/4TroyMandaloniz.jpg in style 4
# 1820 saving: src/models/buildingMLModel/images2/1NeilGrove.jpg in style 10
# 1820 saving: src/models/buildingMLModel/images2/2NeilGrove.jpg in style 5
# 1820 saving: src/models/buildingMLModel/images2/3NeilGrove.jpg in style 7
# 1820 saving: src/models/buildingMLModel/images2/4NeilGrove.jpg in style 9
# 1819 saving: src/models/buildingMLModel/images2/1PerEklund.jpg in style 4
# 1819 saving: src/models/buildingMLModel/images2/2PerEklund.jpg in style 5
# 1819 saving: src/models/buildingMLModel/images2/3PerEklund.jpg in style 5
# 1819 saving: src/models/buildingMLModel/images2/4PerEklund.jpg in style 5
# 1818 saving: src/models/buildingMLModel/images2/1BrianCobb.jpg in style 3
# 1818 saving: src/models/buildingMLModel/images2/2BrianCobb.jpg in style 7
# 1818 saving: src/models/buildingMLModel/images2/3BrianCobb.jpg in style 6
# 1818 saving: src/models/buildingMLModel/images2/4BrianCobb.jpg in style 5
# 1817 saving: src/models/buildingMLModel/images2/1MichaelPatt.jpg in style 3
# 1817 saving: src/models/buildingMLModel/images2/2MichaelPatt.jpg in style 10
# 1817 saving: src/models/buildingMLModel/images2/3MichaelPatt.jpg in style 5
# 1817 saving: src/models/buildingMLModel/images2/4MichaelPatt.jpg in style 8
# 1816 saving: src/models/buildingMLModel/images2/1JasonDay.jpg in style 7
# 1816 saving: src/models/buildingMLModel/images2/2JasonDay.jpg in style 9
# 1816 saving: src/models/buildingMLModel/images2/3JasonDay.jpg in style 4
# 1816 saving: src/models/buildingMLModel/images2/4JasonDay.jpg in style 0
# 1815 saving: src/models/buildingMLModel/images2/1RyanMadigan.jpg in style 2
# 1815 saving: src/models/buildingMLModel/images2/2RyanMadigan.jpg in style 8
# 1815 saving: src/models/buildingMLModel/images2/3RyanMadigan.jpg in style 9
# 1815 saving: src/models/buildingMLModel/images2/4RyanMadigan.jpg in style 5
# 1814 saving: src/models/buildingMLModel/images2/1PeteSell.jpg in style 9
# 1814 saving: src/models/buildingMLModel/images2/2PeteSell.jpg in style 10
# 1814 saving: src/models/buildingMLModel/images2/3PeteSell.jpg in style 4
# 1814 saving: src/models/buildingMLModel/images2/4PeteSell.jpg in style 9
# 1813 saving: src/models/buildingMLModel/images2/1TimMcKenzie.jpg in style 5
# 1813 saving: src/models/buildingMLModel/images2/2TimMcKenzie.jpg in style 5
# 1813 saving: src/models/buildingMLModel/images2/3TimMcKenzie.jpg in style 9
# 1813 saving: src/models/buildingMLModel/images2/4TimMcKenzie.jpg in style 9
# 1812 saving: src/models/buildingMLModel/images2/1JoeVedepo.jpg in style 6
# 1812 saving: src/models/buildingMLModel/images2/2JoeVedepo.jpg in style 5
# 1812 saving: src/models/buildingMLModel/images2/3JoeVedepo.jpg in style 3
# 1812 saving: src/models/buildingMLModel/images2/4JoeVedepo.jpg in style 5
# 1811 saving: src/models/buildingMLModel/images2/1NissenOsterneck.jpg in style 10
# 1811 saving: src/models/buildingMLModel/images2/2NissenOsterneck.jpg in style 4
# 1811 saving: src/models/buildingMLModel/images2/3NissenOsterneck.jpg in style 9
# 1811 saving: src/models/buildingMLModel/images2/4NissenOsterneck.jpg in style 10
# 1810 saving: src/models/buildingMLModel/images2/1JesseSanders.jpg in style 9
# 1810 saving: src/models/buildingMLModel/images2/2JesseSanders.jpg in style 9
# 1810 saving: src/models/buildingMLModel/images2/3JesseSanders.jpg in style 3
# 1810 saving: src/models/buildingMLModel/images2/4JesseSanders.jpg in style 6
# 1809 saving: src/models/buildingMLModel/images2/1MattHorwich.jpg in style 5
# 1809 saving: src/models/buildingMLModel/images2/2MattHorwich.jpg in style 3
# 1809 saving: src/models/buildingMLModel/images2/3MattHorwich.jpg in style 5
# 1809 saving: src/models/buildingMLModel/images2/4MattHorwich.jpg in style 8
# 1808 saving: src/models/buildingMLModel/images2/1JunieBrowning.jpg in style 5
# 1808 saving: src/models/buildingMLModel/images2/2JunieBrowning.jpg in style 3
# 1808 saving: src/models/buildingMLModel/images2/3JunieBrowning.jpg in style 5
# 4 couldnt find a good style for 4JunieBrowning
# 1807 saving: src/models/buildingMLModel/images2/1CarmeloMarrero.jpg in style 7
# 1807 saving: src/models/buildingMLModel/images2/2CarmeloMarrero.jpg in style 5
# 1807 saving: src/models/buildingMLModel/images2/3CarmeloMarrero.jpg in style 5
# 1807 saving: src/models/buildingMLModel/images2/4CarmeloMarrero.jpg in style 7
# 1806 saving: src/models/buildingMLModel/images2/1RyoChonan.jpg in style 6
# 1806 saving: src/models/buildingMLModel/images2/2RyoChonan.jpg in style 5
# 1806 saving: src/models/buildingMLModel/images2/3RyoChonan.jpg in style 4
# 1806 saving: src/models/buildingMLModel/images2/4RyoChonan.jpg in style 5
# 1805 saving: src/models/buildingMLModel/images2/1DavidBielkheden.jpg in style 3
# 1805 saving: src/models/buildingMLModel/images2/2DavidBielkheden.jpg in style 5

# %%
#Fighters we care about
from functions import *
favorites = []

for name in names:
    if fighter_score(name, "March 1, 2022",8)>15:
        favorites.append(name)
favorites
# Out:
# ['Stipe Miocic',
#  'Daniel Cormier',
#  'Junior Dos Santos',
#  'Derrick Lewis',
#  'Beneil Dariush',
#  'Derek Brunson',
#  'Vicente Luque',
#  'Robert Whittaker',
#  'Carla Esparza',
#  'Marina Rodriguez',
#  'Francisco Trinaldo',
#  'Deiveson Figueiredo',
#  'Joseph Benavidez',
#  'Grant Dawson',
#  'Arman Tsarukyan',
#  'Calvin Kattar',
#  'Jimmie Rivera',
#  'Kamaru Usman',
#  'Alexander Volkanovski',
#  'Max Holloway',
#  'Petr Yan',
#  'Jose Aldo',
#  'Rose Namajunas',
#  'Jessica Andrade',
#  'Muslim Salikhov',
#  'Elizeu Zaleski dos Santos',
#  'Leonardo Santos',
#  'Dustin Poirier',
#  'Dan Hooker',
#  'Curtis Blaydes',
#  'Josh Emmett',
#  'Belal Muhammad',
#  'Marvin Vettori',
#  'Amanda Nunes',
#  'Aljamain Sterling',
#  'Neil Magny',
#  'Anthony Rocco Martin',
#  'Gilbert Burns',
#  'Daniel Rodriguez',
#  'Edson Barboza',
#  'Song Yadong',
#  'Glover Teixeira',
#  'Alexander Hernandez',
#  'Ricky Simon',
#  'Justin Gaethje',
#  'Henry Cejudo',
#  'Dominick Cruz',
#  'Francis Ngannou',
#  'Anthony Pettis',
#  'Donald Cerrone',
#  'Niko Price',
#  'Charles Oliveira',
#  'Kevin Lee',
#  'Demian Maia',
#  'Brandon Moreno',
#  'Israel Adesanya',
#  'Joanna Jedrzejczyk',
#  'Paul Felder',
#  'Jan Blachowicz',
#  'Jon Jones',
#  'Valentina Shevchenko',
#  'Michael Chiesa',
#  'Rafael Dos Anjos',
#  'Conor McGregor',
#  'Diego Ferreira',
#  'Aleksandar Rakic',
#  'Ciryl Gane',
#  'Colby Covington',
#  'Germaine de Randamie',
#  'Geoff Neal',
#  'Rob Font',
#  'Warlley Alves',
#  'Stephen Thompson',
#  'Gregor Gillespie',
#  'James Vick',
#  'Tai Tuivasa',
#  'Jared Cannonier',
#  'Gunnar Nelson',
#  'Uriah Hall',
#  'Khabib Nurmagomedov',
#  'Islam Makhachev',
#  'Claudio Silva',
#  'Leon Edwards',
#  'Thiago Santos',
#  'John Lineker',
#  'Michel Prazeres',
#  'Santiago Ponzinibbio',
#  'Sean Strickland',
#  'Demetrious Johnson',
#  'Gegard Mousasi',
#  'Lorenz Larkin']

# %%
favorites=['Stipe Miocic',
 'Daniel Cormier',
 'Junior Dos Santos',
 'Derrick Lewis',
 'Beneil Dariush',
 'Derek Brunson',
 'Vicente Luque',
 'Robert Whittaker',
 'Carla Esparza',
 'Marina Rodriguez',
 'Francisco Trinaldo',
 'Deiveson Figueiredo',
 'Joseph Benavidez',
 'Grant Dawson',
 'Arman Tsarukyan',
 'Calvin Kattar',
 'Jimmie Rivera',
 'Kamaru Usman',
 'Alexander Volkanovski',
 'Max Holloway',
 'Petr Yan',
 'Jose Aldo',
 'Rose Namajunas',
 'Jessica Andrade',
 'Muslim Salikhov',
 'Elizeu Zaleski dos Santos',
 'Leonardo Santos',
 'Dustin Poirier',
 'Dan Hooker',
 'Curtis Blaydes',
 'Josh Emmett',
 'Belal Muhammad',
 'Marvin Vettori',
 'Amanda Nunes',
 'Aljamain Sterling',
 'Neil Magny',
 'Anthony Rocco Martin',
 'Gilbert Burns',
 'Daniel Rodriguez',
 'Edson Barboza',
 'Song Yadong',
 'Glover Teixeira',
 'Alexander Hernandez',
 'Ricky Simon',
 'Justin Gaethje',
 'Henry Cejudo',
 'Dominick Cruz',
 'Francis Ngannou',
 'Anthony Pettis',
 'Donald Cerrone',
 'Niko Price',
 'Charles Oliveira',
 'Kevin Lee',
 'Demian Maia',
 'Brandon Moreno',
 'Israel Adesanya',
 'Joanna Jedrzejczyk',
 'Paul Felder',
 'Jan Blachowicz',
 'Jon Jones',
 'Valentina Shevchenko',
 'Michael Chiesa',
 'Rafael Dos Anjos',
 'Conor McGregor',
 'Diego Ferreira',
 'Aleksandar Rakic',
 'Ciryl Gane',
 'Colby Covington',
 'Germaine de Randamie',
 'Geoff Neal',
 'Rob Font',
 'Warlley Alves',
 'Stephen Thompson',
 'Gregor Gillespie',
 'James Vick',
 'Tai Tuivasa',
 'Jared Cannonier',
 'Gunnar Nelson',
 'Uriah Hall',
 'Khabib Nurmagomedov',
 'Islam Makhachev',
 'Claudio Silva',
 'Leon Edwards',
 'Thiago Santos',
 'John Lineker',
 'Michel Prazeres',
 'Santiago Ponzinibbio',
 'Sean Strickland',
 'Demetrious Johnson',
 'Gegard Mousasi',
 'Lorenz Larkin']

this_week = [
    'Alexander Volkanovski', 'Chan Jung Sung',
    'Aljamain Sterling', 'Petr Yan',
    'Gilbert Burns', 'Khamzat Chimaev',
    'MackenzieDern', 'TeciaTorres', 
    'Vinc Pichel', 'Mark Madsen', 
    'Ian Garry', 'Darian Weeks', 
    'Anthony Hernandez', 'Josh Fremd', 
    'Aspen Ladd', 'Raquel Pennington', 
    'Mickey Gall', 'Mike Malott', 
    'Aleksei Oleinik', 'Jared Vanderaa', 
    'PieraRodriguez', 'Kay Hansen',
    'Julio Arce', 'Daniel Santos'
]

# %%
worthy_names=favorites+this_week
len(worthy_names)
# Out:
# 115

# %%
#making images for the list of fighters people will probably search
#only applying to big names from recent years
i=0
for name in worthy_names:
    i+=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print("src/models/buildingMLModel/images2/"+str(j)+name+".jpg is already stylized")
        except:
            try:
                name = name.replace(" ","")
                fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
                fighterimage=fighterimage.resize((256,256))
                content_img = image_loader(fighterimage)
                styleindex=random.randint(1,len(style))-1
                output = 'empty'
                k=0
                while output =='empty':
                    if k>len(style):
                        print(str(j)+' couldnt find a good style for '+str(j)+name)
                        break
                    k+=1
                    input_img = content_img.clone()
                    styleindex=(styleindex+1)%len(style)
                    output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                       content_img, styleindex, input_img, num_steps=300,
                                       style_weight=1000000, content_weight=1)
                img1 = output
                save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
                print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
            except:
                print('exception')
                pass
            pass
# Out:
# src/models/buildingMLModel/images2/1StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/2StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/3StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/4StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/1DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/2DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/3DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/4DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/1JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/2DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/3DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/4DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/1BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/2BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/3BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/4BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/1DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/2DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/3DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/4DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/1VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/2VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/3VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/4VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/1RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/2RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/3RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/4RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/1CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/2CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/3CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/4CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/1MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/2MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/3MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/4MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/1FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/2FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/3FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/4FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/1DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/2DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/3DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/4DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/1JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/2JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/3JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/4JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/1GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/2GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/3GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/4GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/1ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/2ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/3ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/4ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/1CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/2CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/3CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/4CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/1JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/2JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/3JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/4JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/1KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/2KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/3KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/4KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/1MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/2MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/3MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/4MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/1PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/2PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/3PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/4PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/1JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/2JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/3JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/4JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/1RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/2RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/3RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/4RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/1JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/2JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/3JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/4JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/1MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/2MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/3MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/4MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/1ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/2DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/3DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/4DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/1DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/2DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/3DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/4DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/1CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/2CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/3CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/4CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/1JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/2JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/3JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/4JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/1BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/2BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/3BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/4BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/1MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/2MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/3MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/4MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/1AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/2AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/3AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/4AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/1AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/2AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/3AljamainSterling.jpg is already stylized
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_3454/4107968898.py:148: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_3454/4107968898.py:149: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)

# %%
#trying some styles from stylealt 
#only applying to big names in recent years
alt = True
i=0
for name in worthy_names:
    i+=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print("src/models/buildingMLModel/images2/"+str(j)+name+".jpg is already stylized")
        except:
            try:
                name = name.replace(" ","")
                fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
                fighterimage=fighterimage.resize((256,256))
                content_img = image_loader(fighterimage)
                styleindex=random.randint(1,len(stylealt))-1
                output = 'empty'
                k=0
                while output =='empty':
                    if k>len(stylealt):
                        print(str(j)+' couldnt find a good style for '+str(j)+name)
                        break
                    k+=1
                    input_img = content_img.clone()
                    styleindex=(styleindex+1)%len(stylealt)
                    output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                       content_img, styleindex, input_img, num_steps=300,
                                       style_weight=1000000, content_weight=1)
                img1 = output
                save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
                print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
            except:
                print('exception')
                pass
            pass
# Out:
# src/models/buildingMLModel/images2/1StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/2StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/3StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/4StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/1DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/2DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/3DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/4DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/1JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/2DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/3DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/4DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/1BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/2BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/3BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/4BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/1DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/2DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/3DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/4DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/1VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/2VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/3VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/4VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/1RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/2RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/3RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/4RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/1CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/2CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/3CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/4CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/1MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/2MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/3MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/4MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/1FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/2FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/3FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/4FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/1DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/2DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/3DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/4DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/1JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/2JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/3JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/4JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/1GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/2GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/3GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/4GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/1ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/2ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/3ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/4ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/1CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/2CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/3CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/4CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/1JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/2JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/3JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/4JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/1KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/2KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/3KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/4KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/1MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/2MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/3MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/4MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/1PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/2PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/3PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/4PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/1JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/2JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/3JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/4JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/1RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/2RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/3RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/4RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/1JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/2JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/3JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/4JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/1MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/2MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/3MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/4MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/1ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/2DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/3DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/4DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/1DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/2DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/3DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/4DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/1CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/2CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/3CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/4CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/1JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/2JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/3JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/4JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/1BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/2BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/3BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/4BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/1MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/2MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/3MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/4MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/1AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/2AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/3AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/4AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/1AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/2AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/3AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/4AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/1NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/2NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/3NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/4NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/1GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/2GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/3GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/4GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/1DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/2DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/3DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/4DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/1EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/2EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/3EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/4EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/1SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/2SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/3SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/4SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/1GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/2GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/3GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/4GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/1RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/2RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/3RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/4RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/1JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/2JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/3JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/4JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/1HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/2HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/3HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/4HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/1DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/2DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/3DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/4DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/1FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/2FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/3FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/4FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/1DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/2DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/3DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/4DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/1NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/2NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/3NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/4NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/1CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/2CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/3CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/4CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/1KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/2KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/3KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/4KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/1DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/2DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/3DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/4DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/1BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/2BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/3BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/4BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/1IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/2IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/3IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/4IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/1JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/2JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/3JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/4JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/1PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/2PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/3PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/4PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/1JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/2JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/3JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/4JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/1JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/2JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/3JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/4JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/1ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/2ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/3ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/4ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/1MichaelChiesa.jpg is already stylized
# src/models/buildingMLModel/images2/2MichaelChiesa.jpg is already stylized
# src/models/buildingMLModel/images2/3MichaelChiesa.jpg is already stylized
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11862/335258156.py:164: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11862/335258156.py:165: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 4 couldnt find a good style for 4MichaelChiesa
# exception
# src/models/buildingMLModel/images2/1RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/2RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/3RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/4RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/1ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/2ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/3ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/4ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/1DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/2DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/3DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/4DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/1AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/2AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/3AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/4AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/1CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/2CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/3CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/4CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/1ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/2ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/3ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/4ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/1GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/2GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/3GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/4GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/1GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/2GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/3GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/4GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/1RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/2RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/3RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/4RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/1WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/2WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/3WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/4WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/1StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/2StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/3StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/4StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/1GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/2GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/3GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/4GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/1JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/2JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/3JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/4JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/1TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/2TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/3TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/4TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/1JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/2JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/3JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/4JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/1GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/2GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/3GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/4GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/1UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/2UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/3UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/4UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/1KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/2KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/3KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/4KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/1IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/2IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/3IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/4IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/1ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/2ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/3ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/4ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/1LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/2LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/3LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/4LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/1ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/2JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/3JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/4JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/1MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/2MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/3MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/4MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/1SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/2SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/3SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/4SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/1SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/2SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/3SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/4SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/1DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/2DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/3DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/4DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/1GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/2GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/3GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/4GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/1LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/2LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/3LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/4LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderVolkanovski.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/2AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/3AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/4AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/1PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/2PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/3PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/4PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/1GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/2GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/3GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/4GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/1KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/2KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/3KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/4KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/1MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/2MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/3MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/4MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/1TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/2TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/3TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/4TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/1VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/2VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/3VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/4VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/1MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/2MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/3MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/4MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/1IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/2IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/3IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/4IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/1DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/2DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/3DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/4DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyHernandez.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/2AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/3AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/4AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/1RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/2RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/3RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/4RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/1MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/2MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/3MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/4MickeyGall.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/2AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/3AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/4AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/1JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/2JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/3JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/4JaredVanderaa.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/2KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/3KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/4KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/1JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/2JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/3JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/4JulioArce.jpg is already stylized
# exception
# exception
# exception
# exception

# %%
#trying some styles from style
#only applying to big names in recent years
alt = False
i=0
for name in worthy_names:
    i+=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            print("src/models/buildingMLModel/images2/"+str(j)+name+".jpg is already stylized")
        except:
            try:
                name = name.replace(" ","")
                fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
                fighterimage=fighterimage.resize((256,256))
                content_img = image_loader(fighterimage)
                styleindex=random.randint(1,len(stylealt))-1
                output = 'empty'
                k=0
                while output =='empty':
                    if k>len(stylealt):
                        print(str(j)+' couldnt find a good style for '+str(j)+name)
                        break
                    k+=1
                    input_img = content_img.clone()
                    styleindex=(styleindex+1)%len(stylealt)
                    output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                       content_img, styleindex, input_img, num_steps=300,
                                       style_weight=1000000, content_weight=1)
                img1 = output
                save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
                print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
            except:
                print('exception')
                pass
            pass
# Out:
# src/models/buildingMLModel/images2/1StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/2StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/3StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/4StipeMiocic.jpg is already stylized
# src/models/buildingMLModel/images2/1DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/2DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/3DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/4DanielCormier.jpg is already stylized
# src/models/buildingMLModel/images2/1JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4JuniorDosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/2DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/3DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/4DerrickLewis.jpg is already stylized
# src/models/buildingMLModel/images2/1BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/2BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/3BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/4BeneilDariush.jpg is already stylized
# src/models/buildingMLModel/images2/1DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/2DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/3DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/4DerekBrunson.jpg is already stylized
# src/models/buildingMLModel/images2/1VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/2VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/3VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/4VicenteLuque.jpg is already stylized
# src/models/buildingMLModel/images2/1RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/2RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/3RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/4RobertWhittaker.jpg is already stylized
# src/models/buildingMLModel/images2/1CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/2CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/3CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/4CarlaEsparza.jpg is already stylized
# src/models/buildingMLModel/images2/1MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/2MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/3MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/4MarinaRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/1FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/2FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/3FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/4FranciscoTrinaldo.jpg is already stylized
# src/models/buildingMLModel/images2/1DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/2DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/3DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/4DeivesonFigueiredo.jpg is already stylized
# src/models/buildingMLModel/images2/1JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/2JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/3JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/4JosephBenavidez.jpg is already stylized
# src/models/buildingMLModel/images2/1GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/2GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/3GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/4GrantDawson.jpg is already stylized
# src/models/buildingMLModel/images2/1ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/2ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/3ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/4ArmanTsarukyan.jpg is already stylized
# src/models/buildingMLModel/images2/1CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/2CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/3CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/4CalvinKattar.jpg is already stylized
# src/models/buildingMLModel/images2/1JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/2JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/3JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/4JimmieRivera.jpg is already stylized
# src/models/buildingMLModel/images2/1KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/2KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/3KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/4KamaruUsman.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/1MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/2MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/3MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/4MaxHolloway.jpg is already stylized
# src/models/buildingMLModel/images2/1PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/2PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/3PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/4PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/1JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/2JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/3JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/4JoseAldo.jpg is already stylized
# src/models/buildingMLModel/images2/1RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/2RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/3RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/4RoseNamajunas.jpg is already stylized
# src/models/buildingMLModel/images2/1JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/2JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/3JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/4JessicaAndrade.jpg is already stylized
# src/models/buildingMLModel/images2/1MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/2MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/3MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/4MuslimSalikhov.jpg is already stylized
# src/models/buildingMLModel/images2/1ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4ElizeuZaleskidosSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4LeonardoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/2DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/3DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/4DustinPoirier.jpg is already stylized
# src/models/buildingMLModel/images2/1DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/2DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/3DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/4DanHooker.jpg is already stylized
# src/models/buildingMLModel/images2/1CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/2CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/3CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/4CurtisBlaydes.jpg is already stylized
# src/models/buildingMLModel/images2/1JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/2JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/3JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/4JoshEmmett.jpg is already stylized
# src/models/buildingMLModel/images2/1BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/2BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/3BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/4BelalMuhammad.jpg is already stylized
# src/models/buildingMLModel/images2/1MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/2MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/3MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/4MarvinVettori.jpg is already stylized
# src/models/buildingMLModel/images2/1AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/2AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/3AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/4AmandaNunes.jpg is already stylized
# src/models/buildingMLModel/images2/1AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/2AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/3AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/4AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/1NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/2NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/3NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/4NeilMagny.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyRoccoMartin.jpg is already stylized
# src/models/buildingMLModel/images2/1GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/2GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/3GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/4GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/1DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/2DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/3DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/4DanielRodriguez.jpg is already stylized
# src/models/buildingMLModel/images2/1EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/2EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/3EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/4EdsonBarboza.jpg is already stylized
# src/models/buildingMLModel/images2/1SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/2SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/3SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/4SongYadong.jpg is already stylized
# src/models/buildingMLModel/images2/1GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/2GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/3GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/4GloverTeixeira.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/1RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/2RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/3RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/4RickySimon.jpg is already stylized
# src/models/buildingMLModel/images2/1JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/2JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/3JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/4JustinGaethje.jpg is already stylized
# src/models/buildingMLModel/images2/1HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/2HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/3HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/4HenryCejudo.jpg is already stylized
# src/models/buildingMLModel/images2/1DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/2DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/3DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/4DominickCruz.jpg is already stylized
# src/models/buildingMLModel/images2/1FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/2FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/3FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/4FrancisNgannou.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyPettis.jpg is already stylized
# src/models/buildingMLModel/images2/1DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/2DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/3DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/4DonaldCerrone.jpg is already stylized
# src/models/buildingMLModel/images2/1NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/2NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/3NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/4NikoPrice.jpg is already stylized
# src/models/buildingMLModel/images2/1CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/2CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/3CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/4CharlesOliveira.jpg is already stylized
# src/models/buildingMLModel/images2/1KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/2KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/3KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/4KevinLee.jpg is already stylized
# src/models/buildingMLModel/images2/1DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/2DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/3DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/4DemianMaia.jpg is already stylized
# src/models/buildingMLModel/images2/1BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/2BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/3BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/4BrandonMoreno.jpg is already stylized
# src/models/buildingMLModel/images2/1IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/2IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/3IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/4IsraelAdesanya.jpg is already stylized
# src/models/buildingMLModel/images2/1JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/2JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/3JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/4JoannaJedrzejczyk.jpg is already stylized
# src/models/buildingMLModel/images2/1PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/2PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/3PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/4PaulFelder.jpg is already stylized
# src/models/buildingMLModel/images2/1JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/2JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/3JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/4JanBlachowicz.jpg is already stylized
# src/models/buildingMLModel/images2/1JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/2JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/3JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/4JonJones.jpg is already stylized
# src/models/buildingMLModel/images2/1ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/2ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/3ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/4ValentinaShevchenko.jpg is already stylized
# src/models/buildingMLModel/images2/1MichaelChiesa.jpg is already stylized
# src/models/buildingMLModel/images2/2MichaelChiesa.jpg is already stylized
# src/models/buildingMLModel/images2/3MichaelChiesa.jpg is already stylized
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11862/335258156.py:164: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11862/335258156.py:165: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 4 couldnt find a good style for 4MichaelChiesa
# exception
# src/models/buildingMLModel/images2/1RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/2RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/3RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/4RafaelDosAnjos.jpg is already stylized
# src/models/buildingMLModel/images2/1ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/2ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/3ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/4ConorMcGregor.jpg is already stylized
# src/models/buildingMLModel/images2/1DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/2DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/3DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/4DiegoFerreira.jpg is already stylized
# src/models/buildingMLModel/images2/1AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/2AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/3AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/4AleksandarRakic.jpg is already stylized
# src/models/buildingMLModel/images2/1CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/2CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/3CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/4CirylGane.jpg is already stylized
# src/models/buildingMLModel/images2/1ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/2ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/3ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/4ColbyCovington.jpg is already stylized
# src/models/buildingMLModel/images2/1GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/2GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/3GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/4GermainedeRandamie.jpg is already stylized
# src/models/buildingMLModel/images2/1GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/2GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/3GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/4GeoffNeal.jpg is already stylized
# src/models/buildingMLModel/images2/1RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/2RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/3RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/4RobFont.jpg is already stylized
# src/models/buildingMLModel/images2/1WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/2WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/3WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/4WarlleyAlves.jpg is already stylized
# src/models/buildingMLModel/images2/1StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/2StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/3StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/4StephenThompson.jpg is already stylized
# src/models/buildingMLModel/images2/1GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/2GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/3GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/4GregorGillespie.jpg is already stylized
# src/models/buildingMLModel/images2/1JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/2JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/3JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/4JamesVick.jpg is already stylized
# src/models/buildingMLModel/images2/1TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/2TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/3TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/4TaiTuivasa.jpg is already stylized
# src/models/buildingMLModel/images2/1JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/2JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/3JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/4JaredCannonier.jpg is already stylized
# src/models/buildingMLModel/images2/1GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/2GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/3GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/4GunnarNelson.jpg is already stylized
# src/models/buildingMLModel/images2/1UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/2UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/3UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/4UriahHall.jpg is already stylized
# src/models/buildingMLModel/images2/1KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/2KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/3KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/4KhabibNurmagomedov.jpg is already stylized
# src/models/buildingMLModel/images2/1IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/2IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/3IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/4IslamMakhachev.jpg is already stylized
# src/models/buildingMLModel/images2/1ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/2ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/3ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/4ClaudioSilva.jpg is already stylized
# src/models/buildingMLModel/images2/1LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/2LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/3LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/4LeonEdwards.jpg is already stylized
# src/models/buildingMLModel/images2/1ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/2ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/3ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/4ThiagoSantos.jpg is already stylized
# src/models/buildingMLModel/images2/1JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/2JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/3JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/4JohnLineker.jpg is already stylized
# src/models/buildingMLModel/images2/1MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/2MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/3MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/4MichelPrazeres.jpg is already stylized
# src/models/buildingMLModel/images2/1SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/2SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/3SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/4SantiagoPonzinibbio.jpg is already stylized
# src/models/buildingMLModel/images2/1SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/2SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/3SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/4SeanStrickland.jpg is already stylized
# src/models/buildingMLModel/images2/1DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/2DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/3DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/4DemetriousJohnson.jpg is already stylized
# src/models/buildingMLModel/images2/1GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/2GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/3GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/4GegardMousasi.jpg is already stylized
# src/models/buildingMLModel/images2/1LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/2LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/3LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/4LorenzLarkin.jpg is already stylized
# src/models/buildingMLModel/images2/1AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/2AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/3AlexanderVolkanovski.jpg is already stylized
# src/models/buildingMLModel/images2/4AlexanderVolkanovski.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/2AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/3AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/4AljamainSterling.jpg is already stylized
# src/models/buildingMLModel/images2/1PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/2PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/3PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/4PetrYan.jpg is already stylized
# src/models/buildingMLModel/images2/1GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/2GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/3GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/4GilbertBurns.jpg is already stylized
# src/models/buildingMLModel/images2/1KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/2KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/3KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/4KhamzatChimaev.jpg is already stylized
# src/models/buildingMLModel/images2/1MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/2MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/3MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/4MackenzieDern.jpg is already stylized
# src/models/buildingMLModel/images2/1TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/2TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/3TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/4TeciaTorres.jpg is already stylized
# src/models/buildingMLModel/images2/1VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/2VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/3VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/4VincPichel.jpg is already stylized
# src/models/buildingMLModel/images2/1MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/2MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/3MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/4MarkMadsen.jpg is already stylized
# src/models/buildingMLModel/images2/1IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/2IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/3IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/4IanGarry.jpg is already stylized
# src/models/buildingMLModel/images2/1DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/2DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/3DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/4DarianWeeks.jpg is already stylized
# src/models/buildingMLModel/images2/1AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/2AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/3AnthonyHernandez.jpg is already stylized
# src/models/buildingMLModel/images2/4AnthonyHernandez.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/2AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/3AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/4AspenLadd.jpg is already stylized
# src/models/buildingMLModel/images2/1RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/2RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/3RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/4RaquelPennington.jpg is already stylized
# src/models/buildingMLModel/images2/1MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/2MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/3MickeyGall.jpg is already stylized
# src/models/buildingMLModel/images2/4MickeyGall.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/2AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/3AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/4AlekseiOleinik.jpg is already stylized
# src/models/buildingMLModel/images2/1JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/2JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/3JaredVanderaa.jpg is already stylized
# src/models/buildingMLModel/images2/4JaredVanderaa.jpg is already stylized
# exception
# exception
# exception
# exception
# src/models/buildingMLModel/images2/1KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/2KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/3KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/4KayHansen.jpg is already stylized
# src/models/buildingMLModel/images2/1JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/2JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/3JulioArce.jpg is already stylized
# src/models/buildingMLModel/images2/4JulioArce.jpg is already stylized
# exception
# exception
# exception
# exception

# %%
#computes the number of remaining names
i=0
for name in names:
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
        except:
            i+=1
            pass
print('there are '+str(i)+' images left to stylize. '+str(i//60)+' hours remaining...')
# Out:
# there are 4942 images left to stylize. 82 hours remaining...

# %%
#trying some styles from style on the full list of names (skipping those that already exist)
alt = True
i=0
for name in names:
    i+=1
    for j in range(1,5):
        try:
            name = name.replace(" ","")
            fighterimage=Image.open("src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
            #print("src/models/buildingMLModel/images2/"+str(j)+name+".jpg is already stylized")
        except:
            try:
                name = name.replace(" ","")
                fighterimage=Image.open("src/models/buildingMLModel/images/"+str(j)+name+".jpg")
                fighterimage=fighterimage.resize((256,256))
                content_img = image_loader(fighterimage)
                styleindex=random.randint(1,len(stylealt))-1
                output = 'empty'
                k=0
                while output =='empty':
                    if k>len(stylealt):
                        print(str(j)+' couldnt find a good style for '+str(j)+name)
                        break
                    k+=1
                    input_img = content_img.clone()
                    styleindex=(styleindex+1)%len(stylealt)
                    output = run_style_transfer_adaptive(cnn, cnn_normalization_mean, cnn_normalization_std,
                                       content_img, styleindex, input_img, num_steps=300,
                                       style_weight=1000000, content_weight=1)
                img1 = output
                save_image(img1, "src/models/buildingMLModel/images2/"+str(j)+name+".jpg")
                print(str(i)+' saving: '+"src/models/buildingMLModel/images2/"+str(j)+name+".jpg"+' in style '+str(styleindex))
            except:
                print('something is going wrong with '+name+"... perhaps they had their debut recently and you never scraped their images")
                pass
            pass
# Out:
# something is going wrong with DanielSantos
# something is going wrong with DanielSantos
# something is going wrong with DanielSantos
# something is going wrong with DanielSantos
# something is going wrong with MikeMalott
# something is going wrong with MikeMalott
# something is going wrong with MikeMalott
# something is going wrong with MikeMalott
# something is going wrong with PieraRodriguez
# something is going wrong with PieraRodriguez
# something is going wrong with PieraRodriguez
# something is going wrong with PieraRodriguez
# something is going wrong with JoshFremd
# something is going wrong with JoshFremd
# something is going wrong with JoshFremd
# something is going wrong with JoshFremd
# something is going wrong with DenisTiuliulin
# something is going wrong with DenisTiuliulin
# something is going wrong with DenisTiuliulin
# something is going wrong with DenisTiuliulin
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11972/4161736381.py:164: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.mean = torch.tensor(mean).view(-1, 1, 1)
# /var/folders/zr/jttn57m976g1m1_y2p2t8zwm0000gn/T/ipykernel_11972/4161736381.py:165: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.std = torch.tensor(std).view(-1, 1, 1)
# 2 couldnt find a good style for 2BradyHiestand
# something is going wrong with BradyHiestand

# %%
#1882(3) at 9:27am friday
#424 minutes
#1935-1882 = 53 names
#53/424 = .125 names/minute

#together with the other notebook running in parallel:
# we are at .125+.117 = .242... only slightly faster than it runs at on a single notebook

#not worth doing this unless we can allocate to specific cores


#  list of missing or corrupted entries from images2
# [
#1MichaelChandler,
# 4BloodDiamond,
# 2JPBuys,
# 3JPBuys,
# 1WilliamKnight,
# 3WilliamKnight,
# 2BobbyGreen,
# 2DanielCormier,
# 1DanielCormier
# 4ChanSungJung
# 2AleksandarRakic
# 3JaredGooden
# 1VolkanOezdemir
# 3MikePerry
# 1KhamaWorthy
# 2PhilipeLins
# 4KayHansen
# 3JordanGriffin
# 3MarionReneau
# 3OskarPiechota
#]

# %%
# good starting page fighters (good style transfer photos)
# Kevin Holland 3/4
# Shavkat Rakhmonov 3/4
# Robert Whittaker 3/4
# Sean O'Malley 4/4
# Paddy Pimblett 4/4
# Max Holloway 4/4
