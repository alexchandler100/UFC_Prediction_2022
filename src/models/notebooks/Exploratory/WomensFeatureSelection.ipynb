# %%
# standard library imports
import git, os, sys

git_repo = git.Repo(os.getcwd(), search_parent_directories=True)
git_root = git_repo.git.rev_parse("--show-toplevel")
os.chdir(f'{git_root}/src')
sys.path.append(os.path.abspath(os.path.join(f'{git_root}/src')))
print(f'Changed working directory to {os.getcwd()}')

# local imports
from fight_stat_helpers import *
from data_handler import DataHandler
# Out:
# Changed working directory to C:\Users\Alex\OneDrive\Documents\GitHub\UFC_Prediction_2022\src

# %%
dh = DataHandler()
# get reported derived doubled data
ufc_fights_reported_derived_doubled = dh.get('ufc_fights_reported_derived_doubled')

# %%
ufc_fights_predictive_flattened_diffs = dh.make_ufc_fights_predictive_flattened_diffs(ufc_fights_reported_derived_doubled)
ufc_fights_predictive_flattened_diffs = dh.clean_ufc_fights_for_winner_prediction(ufc_fights_predictive_flattened_diffs)

# %%
# show division counts
print(ufc_fights_predictive_flattened_diffs['division'].value_counts())
# Out:
# division
# Lightweight              1059
# Welterweight             1016
# Middleweight              820
# Featherweight             669
# Bantamweight              593
# Light Heavyweight         578
# Heavyweight               525
# Flyweight                 305
# Women's Strawweight       274
# Women's Flyweight         222
# Women's Bantamweight      178
# Catch Weight               62
# Women's Featherweight      26
# Name: count, dtype: int64

# %%
# filter by division. start with just lightweight and featherweight
division_mask = ufc_fights_predictive_flattened_diffs['division'].isin(["Women's Strawweight", "Women's Flyweight", "Women's Bantamweight", "Women's Featherweight"])
ufc_fights_predictive_flattened_diffs_womens = ufc_fights_predictive_flattened_diffs[division_mask]
ufc_fights_predictive_flattened_diffs_womens.shape
# Out:
# (700, 321)

# %%
# drop the 'fighter_result' column and opponent_result column as it is not needed for the model and also fighter and opponent columns
X = ufc_fights_predictive_flattened_diffs_womens.drop(columns=['fighter', 'opponent', 'method', 'division'])
# KEEP result in X as this is what model_score is expecting for better or for worse
y = X['result']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=72)

# %% [markdown]
# # Use the entire data set with all features as a baseline

# %%
all_features = X_train.columns.tolist()
# remove result from all_features
if 'result' in all_features:
    all_features.remove('result')
model_test_score(X_train, X_test, all_features, _max_iter = 20000, scaled=True)
# Out:
# Training set size: (560, 317) accuracy: 0.7571428571428571
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.8985363879349987. Probability to observe data given model: 0.40716515568107653

# %%
best_features = additive_greedy(X_train, X_test, search_doubles=True, _max_iter=30000)
# Out:
# Starting with an empty feature set.
# Added single feature: age_diff
# Negative log loss on training set: -0.6779215480179095
# Training set size: (560, 317) accuracy: 0.5821428571428572
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.6885549184471669. Probability to observe data given model: 0.50230141135396
# Added single feature: l1y_inf_takedowns_attempts_per_min_diff
# Negative log loss on training set: -0.6661938730829038
# Training set size: (560, 317) accuracy: 0.6
# Test set size: (140, 317) accuracy: 0.6
# Test set neg log loss: -0.673673842383155. Probability to observe data given model: 0.5098320901960643
# Added single feature: l3y_abs_head_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6578137710753098
# Training set size: (560, 317) accuracy: 0.6375
# Test set size: (140, 317) accuracy: 0.5571428571428572
# Test set neg log loss: -0.69952126489462. Probability to observe data given model: 0.49682309352375503
# Added single feature: l1y_abs_takedowns_landed_per_min_diff
# Negative log loss on training set: -0.6488266656613011
# Training set size: (560, 317) accuracy: 0.6339285714285714
# Test set size: (140, 317) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7028557006815772. Probability to observe data given model: 0.49516922770797417
# Added single feature: l3y_losses_dec_diff
# Negative log loss on training set: -0.6445701935602256
# Training set size: (560, 317) accuracy: 0.6375
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7073941387214668. Probability to observe data given model: 0.4929270247469988
# Added single feature: all_wins_ko_diff
# Negative log loss on training set: -0.640097278033538
# Training set size: (560, 317) accuracy: 0.6410714285714286
# Test set size: (140, 317) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7018744851422969. Probability to observe data given model: 0.4956553338972467
# Added single feature: l3y_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.6361588039300107
# Training set size: (560, 317) accuracy: 0.6482142857142857
# Test set size: (140, 317) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7111019122832379. Probability to observe data given model: 0.4911027470510152
# Added single feature: l5y_inf_sig_strikes_accuracy_diff
# Negative log loss on training set: -0.630169505520904
# Training set size: (560, 317) accuracy: 0.6535714285714286
# Test set size: (140, 317) accuracy: 0.5857142857142857
# Test set neg log loss: -0.6955060613107583. Probability to observe data given model: 0.4988219496110404
# Added single feature: l1y_inf_clinch_strikes_landed_per_min_diff
# Negative log loss on training set: -0.626620421372091
# Training set size: (560, 317) accuracy: 0.6553571428571429
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7113914906174738. Probability to observe data given model: 0.4909605549244587
# Added single feature: l1y_inf_head_strikes_accuracy_diff
# Negative log loss on training set: -0.6233123765286286
# Training set size: (560, 317) accuracy: 0.6607142857142857
# Test set size: (140, 317) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7236085515090762. Probability to observe data given model: 0.4849989507208902
# Added single feature: l3y_losses_losses_diff
# Negative log loss on training set: -0.6203181363559417
# Training set size: (560, 317) accuracy: 0.6642857142857143
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7359493289649647. Probability to observe data given model: 0.47905046655674216
# Added single feature: l3y_abs_takedowns_landed_per_min_diff
# Negative log loss on training set: -0.6177034497424981
# Training set size: (560, 317) accuracy: 0.6696428571428571
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7535128263664642. Probability to observe data given model: 0.4707101221398107
# Added single feature: all_abs_leg_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6152294286713282
# Training set size: (560, 317) accuracy: 0.6660714285714285
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.7766368601810996. Probability to observe data given model: 0.4599502901723684
# Added single feature: l1y_abs_head_strikes_accuracy_diff
# Negative log loss on training set: -0.6134956411957581
# Training set size: (560, 317) accuracy: 0.6785714285714286
# Test set size: (140, 317) accuracy: 0.4928571428571429
# Test set neg log loss: -0.7777547505086714. Probability to observe data given model: 0.4594364034798185
# Added single feature: all_overall_fighter_score_diff
# Negative log loss on training set: -0.6124719765443027
# Training set size: (560, 317) accuracy: 0.6803571428571429
# Test set size: (140, 317) accuracy: 0.4714285714285714
# Test set neg log loss: -0.7862579714101. Probability to observe data given model: 0.4555462769928272
# Added single feature: l3y_inf_total_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6069014797052307
# Training set size: (560, 317) accuracy: 0.7
# Test set size: (140, 317) accuracy: 0.4714285714285714
# Test set neg log loss: -0.7935689807111483. Probability to observe data given model: 0.45222791897857134
# Added single feature: l5y_abs_clinch_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6046686570952924
# Training set size: (560, 317) accuracy: 0.7035714285714286
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.7823388364380763. Probability to observe data given model: 0.4573351274218318
# Added single feature: all_inf_takedowns_attempts_per_min_diff
# Negative log loss on training set: -0.6033534851804538
# Training set size: (560, 317) accuracy: 0.7107142857142857
# Test set size: (140, 317) accuracy: 0.5
# Test set neg log loss: -0.7881182204436616. Probability to observe data given model: 0.45469963519775136
# Added single feature: l5y_inf_sub_attempts_per_min_diff
# Negative log loss on training set: -0.6020982658886317
# Training set size: (560, 317) accuracy: 0.7017857142857142
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7832567733820208. Probability to observe data given model: 0.4569155152308379
# Added single feature: l1y_losses_losses_diff
# Negative log loss on training set: -0.6010808986941246
# Training set size: (560, 317) accuracy: 0.7053571428571429
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7809848673121618. Probability to observe data given model: 0.4579547644546014
# Added single feature: l1y_abs_ground_strikes_accuracy_diff
# Negative log loss on training set: -0.6003161132299841
# Training set size: (560, 317) accuracy: 0.7017857142857142
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.7842220641957517. Probability to observe data given model: 0.4564746716866772
# Added single feature: l1y_abs_control_per_min_diff
# Negative log loss on training set: -0.5995059209340478
# Training set size: (560, 317) accuracy: 0.7
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7811089085869186. Probability to observe data given model: 0.4578979626847923
# Added single feature: l3y_abs_leg_strikes_accuracy_diff
# Negative log loss on training set: -0.5988397282644431
# Training set size: (560, 317) accuracy: 0.6982142857142857
# Test set size: (140, 317) accuracy: 0.5
# Test set neg log loss: -0.7885807845633112. Probability to observe data given model: 0.4544893560988237
# Added single feature: all_abs_total_strikes_accuracy_diff
# Negative log loss on training set: -0.5981574961153855
# Training set size: (560, 317) accuracy: 0.6928571428571428
# Test set size: (140, 317) accuracy: 0.5
# Test set neg log loss: -0.7893527894072031. Probability to observe data given model: 0.4541386235154642
# Added single feature: all_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.597319262819087
# Training set size: (560, 317) accuracy: 0.6964285714285714
# Test set size: (140, 317) accuracy: 0.5142857142857142
# Test set neg log loss: -0.7899770030722456. Probability to observe data given model: 0.4538552324383354
# Added single feature: l5y_overall_fighter_score_diff
# Negative log loss on training set: -0.5966847371936927
# Training set size: (560, 317) accuracy: 0.6964285714285714
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7934961994632023. Probability to observe data given model: 0.4522608338886503
# Added single feature: l1y_losses_dec_diff
# Negative log loss on training set: -0.5961910082908809
# Training set size: (560, 317) accuracy: 0.7053571428571429
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7940175580736687. Probability to observe data given model: 0.4520251052636394
# Added single feature: l1y_wins_sub_diff
# Negative log loss on training set: -0.5957806369739493
# Training set size: (560, 317) accuracy: 0.7160714285714286
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.792163337401482. Probability to observe data given model: 0.4528640371001802
# Added single feature: l5y_inf_takedowns_accuracy_diff
# Negative log loss on training set: -0.5953547175351849
# Training set size: (560, 317) accuracy: 0.7071428571428572
# Test set size: (140, 317) accuracy: 0.5
# Test set neg log loss: -0.7938791284230277. Probability to observe data given model: 0.45208768327226806
# Added single feature: l5y_wins_wins_diff
# Negative log loss on training set: -0.5948611506119529
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7962920122560703. Probability to observe data given model: 0.45099816318148866
# Added single feature: l5y_inf_leg_strikes_accuracy_diff
# Negative log loss on training set: -0.594331050766667
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5142857142857142
# Test set neg log loss: -0.7897379396627051. Probability to observe data given model: 0.4539637455878849
# Added single feature: l1y_inf_clinch_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.5939775798997459
# Training set size: (560, 317) accuracy: 0.7142857142857143
# Test set size: (140, 317) accuracy: 0.5142857142857142
# Test set neg log loss: -0.794005476384245. Probability to observe data given model: 0.4520305665235635
# Added single feature: all_abs_takedowns_accuracy_diff
# Negative log loss on training set: -0.5937045978570774
# Training set size: (560, 317) accuracy: 0.7107142857142857
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7881863873392699. Probability to observe data given model: 0.45466864079159397
# Added single feature: l5y_abs_total_strikes_accuracy_diff
# Negative log loss on training set: -0.593426635750486
# Training set size: (560, 317) accuracy: 0.7125
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7881717203233886. Probability to observe data given model: 0.4546753094726739
# Added single feature: l5y_inf_total_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5931507744468477
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7882225013089593. Probability to observe data given model: 0.4546522211985718
# Added single feature: l1y_overall_fighter_score_diff
# Negative log loss on training set: -0.5929802665070294
# Training set size: (560, 317) accuracy: 0.7142857142857143
# Test set size: (140, 317) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7851805206613617. Probability to observe data given model: 0.4560373701869137
# Added single feature: age_sum
# Negative log loss on training set: -0.5926956825159547
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7826468610327566. Probability to observe data given model: 0.4571942786481315
# Added single feature: all_abs_reversals_per_min_diff
# Negative log loss on training set: -0.5922717598102355
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5571428571428572
# Test set neg log loss: -0.7838416900292834. Probability to observe data given model: 0.4566483358860276
# Added single feature: l3y_abs_reversals_per_min_diff
# Negative log loss on training set: -0.5909890795685067
# Training set size: (560, 317) accuracy: 0.7196428571428571
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7842849576397809. Probability to observe data given model: 0.45644596332525605
# Added single feature: l5y_abs_leg_strikes_accuracy_diff
# Negative log loss on training set: -0.5906013049079698
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7826773384956546. Probability to observe data given model: 0.45718034473880304
# Added single feature: l5y_abs_reversals_per_min_diff
# Negative log loss on training set: -0.5903335544040715
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7825935144142822. Probability to observe data given model: 0.4572186690674507
# Added single feature: l3y_wins_ko_diff
# Negative log loss on training set: -0.5901048945376682
# Training set size: (560, 317) accuracy: 0.7125
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7863999227685182. Probability to observe data given model: 0.4554816161694401
# Added single feature: l5y_wins_ko_diff
# Negative log loss on training set: -0.589329024312938
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.7911848177983348. Probability to observe data given model: 0.4533073903175744
# Added single feature: l3y_overall_fighter_score_diff
# Negative log loss on training set: -0.5889301514675203
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5071428571428571
# Test set neg log loss: -0.792269444393394. Probability to observe data given model: 0.452815987608697
# Added single feature: l3y_abs_leg_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5886758111436706
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7973699342931624. Probability to observe data given model: 0.4505122842395626
# Added single feature: l5y_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.5884904324713313
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7980884320539474. Probability to observe data given model: 0.4501887084302977
# Added single feature: l1y_inf_knockdowns_per_min_diff
# Negative log loss on training set: -0.5884322551384655
# Training set size: (560, 317) accuracy: 0.725
# Test set size: (140, 317) accuracy: 0.5142857142857142
# Test set neg log loss: -0.7937079127715849. Probability to observe data given model: 0.4521650943862768
# Added single feature: l5y_abs_body_strikes_accuracy_diff
# Negative log loss on training set: -0.5883860293716623
# Training set size: (560, 317) accuracy: 0.725
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7971302726281335. Probability to observe data given model: 0.4506202677029508
# Added single feature: all_abs_sig_strikes_accuracy_diff
# Negative log loss on training set: -0.5883017338884537
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7968636579131388. Probability to observe data given model: 0.4507404257144305
# Added single feature: l5y_abs_head_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5882023067171641
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7961552788657064. Probability to observe data given model: 0.45105983390551585
# Added single feature: all_abs_body_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5881835979409212
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7952551662601165. Probability to observe data given model: 0.45146602132767444
# Added single feature: all_abs_head_strikes_accuracy_diff
# Negative log loss on training set: -0.5881363768468277
# Training set size: (560, 317) accuracy: 0.7196428571428571
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.795236765371852. Probability to observe data given model: 0.45147432877992016
# Added single feature: all_abs_clinch_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5880874394505531
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7938880574466619. Probability to observe data given model: 0.4520836465886812
# Added single feature: l5y_abs_sig_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5880576185973431
# Training set size: (560, 317) accuracy: 0.7214285714285714
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7940901148314421. Probability to observe data given model: 0.4519923089773798
# No improvement found with single addition, trying pairs.
# Added double feature: all_inf_ground_strikes_attempts_per_min_diff, l3y_inf_ground_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5871409028938817
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.8020396201656638. Probability to observe data given model: 0.4484134376814679
# Added single feature: l5y_inf_ground_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.587131492161815
# Training set size: (560, 317) accuracy: 0.7196428571428571
# Test set size: (140, 317) accuracy: 0.5142857142857142
# Test set neg log loss: -0.8041381354715464. Probability to observe data given model: 0.4474734218828679
# Added single feature: l3y_inf_ground_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.587123233508457
# Training set size: (560, 317) accuracy: 0.7178571428571429
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.8031683090454065. Probability to observe data given model: 0.44790760393898976
# Added single feature: l5y_abs_takedowns_accuracy_diff
# Negative log loss on training set: -0.5871195927900142
# Training set size: (560, 317) accuracy: 0.7232142857142857
# Test set size: (140, 317) accuracy: 0.5214285714285715
# Test set neg log loss: -0.8032660071899749. Probability to observe data given model: 0.44786384633470006
# No improvement found with single addition, trying pairs.
# No improvement found with double addition, stopping.
# Final best feature set: ['age_diff', 'l1y_inf_takedowns_attempts_per_min_diff', 'l3y_abs_head_strikes_landed_per_min_diff', 'l1y_abs_takedowns_landed_per_min_diff', 'l3y_losses_dec_diff', 'all_wins_ko_diff', 'l3y_abs_distance_strikes_accuracy_diff', 'l5y_inf_sig_strikes_accuracy_diff', 'l1y_inf_clinch_strikes_landed_per_min_diff', 'l1y_inf_head_strikes_accuracy_diff', 'l3y_losses_losses_diff', 'l3y_abs_takedowns_landed_per_min_diff', 'all_abs_leg_strikes_landed_per_min_diff', 'l1y_abs_head_strikes_accuracy_diff', 'all_overall_fighter_score_diff', 'l3y_inf_total_strikes_landed_per_min_diff', 'l5y_abs_clinch_strikes_landed_per_min_diff', 'all_inf_takedowns_attempts_per_min_diff', 'l5y_inf_sub_attempts_per_min_diff', 'l1y_losses_losses_diff', 'l1y_abs_ground_strikes_accuracy_diff', 'l1y_abs_control_per_min_diff', 'l3y_abs_leg_strikes_accuracy_diff', 'all_abs_total_strikes_accuracy_diff', 'all_abs_distance_strikes_accuracy_diff', 'l5y_overall_fighter_score_diff', 'l1y_losses_dec_diff', 'l1y_wins_sub_diff', 'l5y_inf_takedowns_accuracy_diff', 'l5y_wins_wins_diff', 'l5y_inf_leg_strikes_accuracy_diff', 'l1y_inf_clinch_strikes_attempts_per_min_diff', 'all_abs_takedowns_accuracy_diff', 'l5y_abs_total_strikes_accuracy_diff', 'l5y_inf_total_strikes_landed_per_min_diff', 'l1y_overall_fighter_score_diff', 'age_sum', 'all_abs_reversals_per_min_diff', 'l3y_abs_reversals_per_min_diff', 'l5y_abs_leg_strikes_accuracy_diff', 'l5y_abs_reversals_per_min_diff', 'l3y_wins_ko_diff', 'l5y_wins_ko_diff', 'l3y_overall_fighter_score_diff', 'l3y_abs_leg_strikes_landed_per_min_diff', 'l5y_abs_distance_strikes_accuracy_diff', 'l1y_inf_knockdowns_per_min_diff', 'l5y_abs_body_strikes_accuracy_diff', 'all_abs_sig_strikes_accuracy_diff', 'l5y_abs_head_strikes_landed_per_min_diff', 'all_abs_body_strikes_landed_per_min_diff', 'all_abs_head_strikes_accuracy_diff', 'all_abs_clinch_strikes_landed_per_min_diff', 'l5y_abs_sig_strikes_landed_per_min_diff', 'all_inf_ground_strikes_attempts_per_min_diff', 'l3y_inf_ground_strikes_landed_per_min_diff', 'l5y_inf_ground_strikes_attempts_per_min_diff', 'l3y_inf_ground_strikes_attempts_per_min_diff', 'l5y_abs_takedowns_accuracy_diff']

# %%
model_test_score(X_train, X_test, best_features, _max_iter = 30000, scaled=True)
# Out:
# Training set size: (560, 317) accuracy: 0.725
# Test set size: (140, 317) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7290313426064227. Probability to observe data given model: 0.4823760209564177

# %%
best_features = ['l1y_inf_total_strikes_accuracy_diff',
 'age_diff',
 'all_wins_wins_diff',
 'l3y_abs_distance_strikes_landed_per_min_diff',
 'l1y_inf_takedowns_attempts_per_min_diff',
 'l1y_losses_losses_diff',
 'l5y_inf_leg_strikes_accuracy_diff',
 'l1y_inf_knockdowns_per_min_diff',
 'l3y_abs_distance_strikes_accuracy_diff',
 'l1y_abs_takedowns_landed_per_min_diff',
 'l3y_losses_sub_diff',
 'l3y_losses_ko_diff',
 'l3y_inf_sub_attempts_per_min_diff',
 'l5y_inf_sig_strikes_accuracy_diff',
 'l1y_losses_diff',
 'l1y_inf_takedowns_landed_per_min_diff',
 'l5y_abs_sub_attempts_per_min_diff',
 'l3y_inf_total_strikes_accuracy_diff',
 'all_wins_sub_diff',
 'l1y_abs_control_per_min_diff',
 'l3y_abs_total_strikes_accuracy_diff',
 'l3y_abs_head_strikes_accuracy_diff',
 'l1y_abs_body_strikes_landed_per_min_diff',
 'l1y_abs_sig_strikes_attempts_per_min_diff',
 'l5y_inf_clinch_strikes_landed_per_min_diff',
 'all_abs_distance_strikes_attempts_per_min_diff',
 'all_inf_sig_strikes_accuracy_diff',
 'l1y_abs_total_strikes_accuracy_diff',
 'l1y_abs_sig_strikes_accuracy_diff',
 'l3y_inf_control_per_min_diff',
 'l5y_wins_ko_diff',
 'all_inf_leg_strikes_landed_per_min_diff',
 'l3y_inf_leg_strikes_attempts_per_min_diff',
 'l3y_inf_total_strikes_landed_per_min_diff',
 'l5y_inf_ground_strikes_landed_per_min_diff',
 'all_abs_reversals_per_min_diff',
 'height_diff',
 'l3y_defensive_grappling_loss_diff',
 'l3y_abs_takedowns_attempts_per_min_diff',
 'l3y_inf_body_strikes_attempts_per_min_diff',
 'l5y_losses_sub_diff',
 'all_inf_clinch_strikes_accuracy_diff',
 'l1y_abs_knockdowns_per_min_diff',
 'all_abs_distance_strikes_accuracy_diff',
 'all_abs_total_strikes_accuracy_diff',
 'l3y_abs_sig_strikes_accuracy_diff',
 'l5y_abs_takedowns_attempts_per_min_diff',
 'l5y_abs_total_strikes_accuracy_diff',
 'l3y_abs_takedowns_landed_per_min_diff',
 'all_abs_control_per_min_diff',
 'l3y_wins_wins_diff',
 'l1y_abs_body_strikes_accuracy_diff',
 'all_inf_leg_strikes_attempts_per_min_diff',
 'l5y_inf_leg_strikes_attempts_per_min_diff',
 'all_inf_total_strikes_accuracy_diff',
 'l3y_inf_leg_strikes_accuracy_diff',
 'l3y_inf_sig_strikes_accuracy_diff',
 'l5y_inf_leg_strikes_landed_per_min_diff',
 'l3y_abs_leg_strikes_accuracy_diff',
 'l5y_abs_leg_strikes_accuracy_diff',
 'l3y_inf_distance_strikes_accuracy_diff',
 'l3y_inf_knockdowns_per_min_diff',
 'l5y_inf_head_strikes_accuracy_diff',
 'l3y_abs_distance_strikes_attempts_per_min_diff']

model_test_score(X_train, X_test, best_features, _max_iter = 30000, scaled=True)
# Out:
# Training set size: (560, 317) accuracy: 0.725
# Test set size: (140, 317) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7290313426064227. Probability to observe data given model: 0.4823760209564177
