# %%
# standard library imports
import git, os, sys

git_repo = git.Repo(os.getcwd(), search_parent_directories=True)
git_root = git_repo.git.rev_parse("--show-toplevel")
os.chdir(f'{git_root}/src')
sys.path.append(os.path.abspath(os.path.join(f'{git_root}/src')))
print(f'Changed working directory to {os.getcwd()}')

# local imports
from fight_stat_helpers import *
from data_handler import DataHandler
# Out:
# Changed working directory to C:\Users\Alex\OneDrive\Documents\GitHub\UFC_Prediction_2022\src

# %%
dh = DataHandler()
# get reported derived doubled data
ufc_fights_reported_derived_doubled = dh.get('ufc_fights_reported_derived_doubled')

# %%
ufc_fights_predictive_flattened_diffs = dh.make_ufc_fights_predictive_flattened_diffs(ufc_fights_reported_derived_doubled)
ufc_fights_predictive_flattened_diffs = dh.clean_ufc_fights_for_winner_prediction(ufc_fights_predictive_flattened_diffs)

# %%
# show division counts
print(ufc_fights_predictive_flattened_diffs['division'].value_counts())
# Out:
# division
# Lightweight              1059
# Welterweight             1015
# Middleweight              819
# Featherweight             668
# Bantamweight              590
# Light Heavyweight         576
# Heavyweight               524
# Flyweight                 304
# Women's Strawweight       273
# Women's Flyweight         222
# Women's Bantamweight      178
# Catch Weight               62
# Women's Featherweight      26
# Name: count, dtype: int64

# %%
# filter by division. start with just lightweight and featherweight
division_mask = ufc_fights_predictive_flattened_diffs['division'].isin(["Women's Strawweight", "Women's Flyweight", "Women's Bantamweight", "Women's Featherweight"])
ufc_fights_predictive_flattened_diffs_womens = ufc_fights_predictive_flattened_diffs[division_mask]
ufc_fights_predictive_flattened_diffs_womens.shape
# Out:
# (699, 325)

# %%
# drop the 'fighter_result' column and opponent_result column as it is not needed for the model and also fighter and opponent columns
X = ufc_fights_predictive_flattened_diffs_womens.drop(columns=['fighter', 'opponent', 'method', 'division'])
# KEEP result in X as this is what model_score is expecting for better or for worse
y = X['result']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=72)

# %% [markdown]
# # Use the entire data set with all features as a baseline

# %%
all_features = X_train.columns.tolist()
# remove result from all_features
if 'result' in all_features:
    all_features.remove('result')
model_test_score(X_train, X_test, all_features, _max_iter = 20000, scaled=True)
# Out:
# Training set size: (559, 321) accuracy: 0.7567084078711985
# Test set size: (140, 321) accuracy: 0.5571428571428572
# Test set neg log loss: -0.8609906854495246. Probability to observe data given model: 0.4227430693892821

# %%
best_features = additive_greedy(X_train, X_test, search_doubles=True, _max_iter=30000)
# Out:
# Starting with an empty feature set.
# Added single feature: age_diff
# Negative log loss on training set: -0.6772813100457699
# Training set size: (559, 321) accuracy: 0.5885509838998211
# Test set size: (140, 321) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7028449628886934. Probability to observe data given model: 0.49517454476113043
# Added single feature: l1y_inf_takedowns_attempts_per_min_diff
# Negative log loss on training set: -0.662882963747438
# Training set size: (559, 321) accuracy: 0.6046511627906976
# Test set size: (140, 321) accuracy: 0.55
# Test set neg log loss: -0.6948110976598459. Probability to observe data given model: 0.499168733221342
# Added single feature: l1y_abs_takedowns_landed_per_min_diff
# Negative log loss on training set: -0.6557130307624255
# Training set size: (559, 321) accuracy: 0.6189624329159212
# Test set size: (140, 321) accuracy: 0.5571428571428572
# Test set neg log loss: -0.6966019421918705. Probability to observe data given model: 0.4982755995953293
# Added single feature: l3y_abs_head_strikes_accuracy_diff
# Negative log loss on training set: -0.6475311612384578
# Training set size: (559, 321) accuracy: 0.629695885509839
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7113184485083585. Probability to observe data given model: 0.49099641702858876
# Added single feature: all_abs_total_strikes_accuracy_diff
# Negative log loss on training set: -0.6411742448618997
# Training set size: (559, 321) accuracy: 0.629695885509839
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.7093531134441419. Probability to observe data given model: 0.4919623383720132
# Added single feature: l3y_losses_dec_diff
# Negative log loss on training set: -0.6358224832915473
# Training set size: (559, 321) accuracy: 0.6350626118067979
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7378294740647334. Probability to observe data given model: 0.4781506283477764
# Added single feature: l3y_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.6316477071156612
# Training set size: (559, 321) accuracy: 0.6332737030411449
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7361903873545175. Probability to observe data given model: 0.47893500134024813
# Added single feature: all_overall_fighter_score_diff
# Negative log loss on training set: -0.6264586188679708
# Training set size: (559, 321) accuracy: 0.6440071556350626
# Test set size: (140, 321) accuracy: 0.55
# Test set neg log loss: -0.7337051262276137. Probability to observe data given model: 0.4801267601839457
# Added single feature: l1y_fight_math_diff
# Negative log loss on training set: -0.623020594009735
# Training set size: (559, 321) accuracy: 0.6511627906976745
# Test set size: (140, 321) accuracy: 0.55
# Test set neg log loss: -0.7454254664191465. Probability to observe data given model: 0.4745323593997765
# Added single feature: l1y_inf_clinch_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6195705240306274
# Training set size: (559, 321) accuracy: 0.6618962432915921
# Test set size: (140, 321) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7591414279440692. Probability to observe data given model: 0.4680681247541902
# Added single feature: l1y_abs_total_strikes_accuracy_diff
# Negative log loss on training set: -0.6158021710359438
# Training set size: (559, 321) accuracy: 0.6601073345259392
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7657745711844023. Probability to observe data given model: 0.4649736362752155
# Added single feature: l3y_abs_takedowns_landed_per_min_diff
# Negative log loss on training set: -0.6137080577980094
# Training set size: (559, 321) accuracy: 0.6601073345259392
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7822294299483283. Probability to observe data given model: 0.45738516558996173
# Added single feature: l5y_abs_ground_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.6121332871002498
# Training set size: (559, 321) accuracy: 0.6654740608228981
# Test set size: (140, 321) accuracy: 0.5
# Test set neg log loss: -0.7990147466759598. Probability to observe data given model: 0.44977188513157695
# Added single feature: l3y_inf_total_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6106529651646623
# Training set size: (559, 321) accuracy: 0.6636851520572451
# Test set size: (140, 321) accuracy: 0.5214285714285715
# Test set neg log loss: -0.7989244442030737. Probability to observe data given model: 0.44981250247893484
# Added single feature: all_inf_leg_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.6085903223968545
# Training set size: (559, 321) accuracy: 0.6708407871198568
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.801239013306932. Probability to observe data given model: 0.4487725843036641
# Added single feature: l1y_inf_head_strikes_accuracy_diff
# Negative log loss on training set: -0.6067814717970396
# Training set size: (559, 321) accuracy: 0.6833631484794276
# Test set size: (140, 321) accuracy: 0.5214285714285715
# Test set neg log loss: -0.8037108657764337. Probability to observe data given model: 0.4476646545664628
# Added single feature: all_abs_clinch_strikes_landed_per_min_diff
# Negative log loss on training set: -0.605210276817469
# Training set size: (559, 321) accuracy: 0.6726296958855098
# Test set size: (140, 321) accuracy: 0.5285714285714286
# Test set neg log loss: -0.7892883603251689. Probability to observe data given model: 0.4541678841927027
# Added single feature: l1y_abs_ground_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6039867804582295
# Training set size: (559, 321) accuracy: 0.6815742397137746
# Test set size: (140, 321) accuracy: 0.5428571428571428
# Test set neg log loss: -0.7844267715054956. Probability to observe data given model: 0.4563812375483219
# Added single feature: l1y_abs_control_per_min_diff
# Negative log loss on training set: -0.6025648196961237
# Training set size: (559, 321) accuracy: 0.6851520572450805
# Test set size: (140, 321) accuracy: 0.55
# Test set neg log loss: -0.778951481252439. Probability to observe data given model: 0.4588869106740156
# Added single feature: l3y_inf_knockdowns_per_min_diff
# Negative log loss on training set: -0.6014306501242966
# Training set size: (559, 321) accuracy: 0.6833631484794276
# Test set size: (140, 321) accuracy: 0.5357142857142857
# Test set neg log loss: -0.7779398494638671. Probability to observe data given model: 0.4593513701515884
# Added single feature: l1y_abs_body_strikes_landed_per_min_diff
# Negative log loss on training set: -0.6004567533719174
# Training set size: (559, 321) accuracy: 0.6797853309481217
# Test set size: (140, 321) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7810682066809768. Probability to observe data given model: 0.45791660038389287
# Added single feature: l1y_inf_reversals_per_min_diff
# Negative log loss on training set: -0.5989154318958034
# Training set size: (559, 321) accuracy: 0.6887298747763864
# Test set size: (140, 321) accuracy: 0.5571428571428572
# Test set neg log loss: -0.7811958031841941. Probability to observe data given model: 0.4578581755543999
# Added single feature: all_abs_takedowns_accuracy_diff
# Negative log loss on training set: -0.5977634531324816
# Training set size: (559, 321) accuracy: 0.6958855098389982
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7767219710619901. Probability to observe data given model: 0.45991114506386693
# Added single feature: l1y_abs_total_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5967650722038089
# Training set size: (559, 321) accuracy: 0.6851520572450805
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.7829815277907093. Probability to observe data given model: 0.4570412965215858
# Added single feature: l5y_losses_losses_diff
# Negative log loss on training set: -0.5962450298898567
# Training set size: (559, 321) accuracy: 0.6797853309481217
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.7847107467783925. Probability to observe data given model: 0.45625165496184006
# Added single feature: l1y_abs_clinch_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.5956959580143142
# Training set size: (559, 321) accuracy: 0.6779964221824687
# Test set size: (140, 321) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7852730834746414. Probability to observe data given model: 0.4559951600385437
# Added single feature: l5y_overall_fighter_score_diff
# Negative log loss on training set: -0.5952296030470706
# Training set size: (559, 321) accuracy: 0.6923076923076923
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7881827844011251. Probability to observe data given model: 0.4546702789375342
# Added single feature: l3y_abs_takedowns_accuracy_diff
# Negative log loss on training set: -0.5947470620599276
# Training set size: (559, 321) accuracy: 0.6905187835420393
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7878866999505529. Probability to observe data given model: 0.45480491966879477
# Added single feature: l5y_abs_total_strikes_accuracy_diff
# Negative log loss on training set: -0.5942223578323661
# Training set size: (559, 321) accuracy: 0.6923076923076923
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.78718216582583. Probability to observe data given model: 0.45512545815668604
# Added single feature: l3y_inf_sub_attempts_per_min_diff
# Negative log loss on training set: -0.5936613150872563
# Training set size: (559, 321) accuracy: 0.6905187835420393
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.7847771878559765. Probability to observe data given model: 0.45622134211725507
# Added single feature: l1y_inf_body_strikes_accuracy_diff
# Negative log loss on training set: -0.5932588167925718
# Training set size: (559, 321) accuracy: 0.6851520572450805
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.7905619148569665. Probability to observe data given model: 0.45358984478607395
# Added single feature: all_losses_losses_diff
# Negative log loss on training set: -0.5929420992567762
# Training set size: (559, 321) accuracy: 0.6797853309481217
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.7913896696197781. Probability to observe data given model: 0.4532145389837013
# Added single feature: l1y_inf_leg_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.592755196667947
# Training set size: (559, 321) accuracy: 0.6851520572450805
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.7909259584041262. Probability to observe data given model: 0.4534247483829858
# Added single feature: l1y_inf_clinch_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.5925622302998464
# Training set size: (559, 321) accuracy: 0.6833631484794276
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.7934456909109281. Probability to observe data given model: 0.45228367750551446
# Added single feature: l3y_inf_takedowns_attempts_per_min_diff
# Negative log loss on training set: -0.5924180752435934
# Training set size: (559, 321) accuracy: 0.6815742397137746
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.7958668422850005. Probability to observe data given model: 0.451189954826616
# Added single feature: l3y_inf_ground_strikes_accuracy_diff
# Negative log loss on training set: -0.5921324818375571
# Training set size: (559, 321) accuracy: 0.6923076923076923
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8030812257997513. Probability to observe data given model: 0.4479466108852955
# Added single feature: all_abs_takedowns_landed_per_min_diff
# Negative log loss on training set: -0.5918842488176685
# Training set size: (559, 321) accuracy: 0.6940966010733453
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.806797461588981. Probability to observe data given model: 0.4462850249930039
# Added single feature: l5y_inf_total_strikes_landed_per_min_diff
# Negative log loss on training set: -0.5916267428966697
# Training set size: (559, 321) accuracy: 0.6923076923076923
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8061853177579963. Probability to observe data given model: 0.44655829925095636
# Added single feature: all_inf_sig_strikes_accuracy_diff
# Negative log loss on training set: -0.5913913441052207
# Training set size: (559, 321) accuracy: 0.6994633273703041
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.8025460112004773. Probability to observe data given model: 0.448186422620783
# Added single feature: l1y_abs_leg_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.5911876511591547
# Training set size: (559, 321) accuracy: 0.6994633273703041
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8119151278469855. Probability to observe data given model: 0.4440069214380475
# Added single feature: l1y_abs_ground_strikes_accuracy_diff
# Negative log loss on training set: -0.5910254253505869
# Training set size: (559, 321) accuracy: 0.6940966010733453
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.8178235778566513. Probability to observe data given model: 0.44139126358993674
# Added single feature: l1y_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.5908370894431015
# Training set size: (559, 321) accuracy: 0.6940966010733453
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.8174153201766677. Probability to observe data given model: 0.44157150175247856
# Added single feature: l3y_inf_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.5907244513492401
# Training set size: (559, 321) accuracy: 0.7084078711985689
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.8184991709120161. Probability to observe data given model: 0.4410931634260953
# Added single feature: all_abs_distance_strikes_accuracy_diff
# Negative log loss on training set: -0.5905664091215878
# Training set size: (559, 321) accuracy: 0.7048300536672629
# Test set size: (140, 321) accuracy: 0.5928571428571429
# Test set neg log loss: -0.817925626893554. Probability to observe data given model: 0.44134622233483756
# Added single feature: l5y_abs_head_strikes_accuracy_diff
# Negative log loss on training set: -0.5902614373769548
# Training set size: (559, 321) accuracy: 0.7137745974955277
# Test set size: (140, 321) accuracy: 0.5928571428571429
# Test set neg log loss: -0.8182965752483193. Probability to observe data given model: 0.44118253604123814
# Added single feature: l1y_abs_body_strikes_accuracy_diff
# Negative log loss on training set: -0.5901628271050416
# Training set size: (559, 321) accuracy: 0.7066189624329159
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.8204532792557261. Probability to observe data given model: 0.4402320612126137
# Added single feature: l5y_inf_sig_strikes_accuracy_diff
# Negative log loss on training set: -0.5900845970964126
# Training set size: (559, 321) accuracy: 0.7048300536672629
# Test set size: (140, 321) accuracy: 0.5857142857142857
# Test set neg log loss: -0.8189208796936944. Probability to observe data given model: 0.44090718978165583
# Added single feature: l1y_abs_ground_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.590022587586225
# Training set size: (559, 321) accuracy: 0.7048300536672629
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8180846533851422. Probability to observe data given model: 0.4412760421739242
# Added single feature: l3y_abs_ground_strikes_attempts_per_min_diff
# Negative log loss on training set: -0.589965889146975
# Training set size: (559, 321) accuracy: 0.7048300536672629
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8195394284577974. Probability to observe data given model: 0.440634551513057
# No improvement found with single addition, trying pairs.
# No improvement found with double addition, stopping.
# Final best feature set: ['age_diff', 'l1y_inf_takedowns_attempts_per_min_diff', 'l1y_abs_takedowns_landed_per_min_diff', 'l3y_abs_head_strikes_accuracy_diff', 'all_abs_total_strikes_accuracy_diff', 'l3y_losses_dec_diff', 'l3y_abs_distance_strikes_accuracy_diff', 'all_overall_fighter_score_diff', 'l1y_fight_math_diff', 'l1y_inf_clinch_strikes_landed_per_min_diff', 'l1y_abs_total_strikes_accuracy_diff', 'l3y_abs_takedowns_landed_per_min_diff', 'l5y_abs_ground_strikes_attempts_per_min_diff', 'l3y_inf_total_strikes_landed_per_min_diff', 'all_inf_leg_strikes_attempts_per_min_diff', 'l1y_inf_head_strikes_accuracy_diff', 'all_abs_clinch_strikes_landed_per_min_diff', 'l1y_abs_ground_strikes_landed_per_min_diff', 'l1y_abs_control_per_min_diff', 'l3y_inf_knockdowns_per_min_diff', 'l1y_abs_body_strikes_landed_per_min_diff', 'l1y_inf_reversals_per_min_diff', 'all_abs_takedowns_accuracy_diff', 'l1y_abs_total_strikes_landed_per_min_diff', 'l5y_losses_losses_diff', 'l1y_abs_clinch_strikes_attempts_per_min_diff', 'l5y_overall_fighter_score_diff', 'l3y_abs_takedowns_accuracy_diff', 'l5y_abs_total_strikes_accuracy_diff', 'l3y_inf_sub_attempts_per_min_diff', 'l1y_inf_body_strikes_accuracy_diff', 'all_losses_losses_diff', 'l1y_inf_leg_strikes_attempts_per_min_diff', 'l1y_inf_clinch_strikes_attempts_per_min_diff', 'l3y_inf_takedowns_attempts_per_min_diff', 'l3y_inf_ground_strikes_accuracy_diff', 'all_abs_takedowns_landed_per_min_diff', 'l5y_inf_total_strikes_landed_per_min_diff', 'all_inf_sig_strikes_accuracy_diff', 'l1y_abs_leg_strikes_attempts_per_min_diff', 'l1y_abs_ground_strikes_accuracy_diff', 'l1y_abs_distance_strikes_accuracy_diff', 'l3y_inf_distance_strikes_accuracy_diff', 'all_abs_distance_strikes_accuracy_diff', 'l5y_abs_head_strikes_accuracy_diff', 'l1y_abs_body_strikes_accuracy_diff', 'l5y_inf_sig_strikes_accuracy_diff', 'l1y_abs_ground_strikes_attempts_per_min_diff', 'l3y_abs_ground_strikes_attempts_per_min_diff']

# %%
model_test_score(X_train, X_test, best_features, _max_iter = 30000, scaled=True)
# Out:
# Training set size: (559, 321) accuracy: 0.7048300536672629
# Test set size: (140, 321) accuracy: 0.5785714285714286
# Test set neg log loss: -0.8195394284577974. Probability to observe data given model: 0.440634551513057

# %%
best_features = ['l1y_inf_total_strikes_accuracy_diff',
 'age_diff',
 'all_wins_wins_diff',
 'l3y_abs_distance_strikes_landed_per_min_diff',
 'l1y_inf_takedowns_attempts_per_min_diff',
 'l1y_losses_losses_diff',
 'l5y_inf_leg_strikes_accuracy_diff',
 'l1y_inf_knockdowns_per_min_diff',
 'l3y_abs_distance_strikes_accuracy_diff',
 'l1y_abs_takedowns_landed_per_min_diff',
 'l3y_losses_sub_diff',
 'l3y_losses_ko_diff',
 'l3y_inf_sub_attempts_per_min_diff',
 'l5y_inf_sig_strikes_accuracy_diff',
 'l1y_losses_diff',
 'l1y_inf_takedowns_landed_per_min_diff',
 'l5y_abs_sub_attempts_per_min_diff',
 'l3y_inf_total_strikes_accuracy_diff',
 'all_wins_sub_diff',
 'l1y_abs_control_per_min_diff',
 'l3y_abs_total_strikes_accuracy_diff',
 'l3y_abs_head_strikes_accuracy_diff',
 'l1y_abs_body_strikes_landed_per_min_diff',
 'l1y_abs_sig_strikes_attempts_per_min_diff',
 'l5y_inf_clinch_strikes_landed_per_min_diff',
 'all_abs_distance_strikes_attempts_per_min_diff',
 'all_inf_sig_strikes_accuracy_diff',
 'l1y_abs_total_strikes_accuracy_diff',
 'l1y_abs_sig_strikes_accuracy_diff',
 'l3y_inf_control_per_min_diff',
 'l5y_wins_ko_diff',
 'all_inf_leg_strikes_landed_per_min_diff',
 'l3y_inf_leg_strikes_attempts_per_min_diff',
 'l3y_inf_total_strikes_landed_per_min_diff',
 'l5y_inf_ground_strikes_landed_per_min_diff',
 'all_abs_reversals_per_min_diff',
 'height_diff',
 'l3y_defensive_grappling_loss_diff',
 'l3y_abs_takedowns_attempts_per_min_diff',
 'l3y_inf_body_strikes_attempts_per_min_diff',
 'l5y_losses_sub_diff',
 'all_inf_clinch_strikes_accuracy_diff',
 'l1y_abs_knockdowns_per_min_diff',
 'all_abs_distance_strikes_accuracy_diff',
 'all_abs_total_strikes_accuracy_diff',
 'l3y_abs_sig_strikes_accuracy_diff',
 'l5y_abs_takedowns_attempts_per_min_diff',
 'l5y_abs_total_strikes_accuracy_diff',
 'l3y_abs_takedowns_landed_per_min_diff',
 'all_abs_control_per_min_diff',
 'l3y_wins_wins_diff',
 'l1y_abs_body_strikes_accuracy_diff',
 'all_inf_leg_strikes_attempts_per_min_diff',
 'l5y_inf_leg_strikes_attempts_per_min_diff',
 'all_inf_total_strikes_accuracy_diff',
 'l3y_inf_leg_strikes_accuracy_diff',
 'l3y_inf_sig_strikes_accuracy_diff',
 'l5y_inf_leg_strikes_landed_per_min_diff',
 'l3y_abs_leg_strikes_accuracy_diff',
 'l5y_abs_leg_strikes_accuracy_diff',
 'l3y_inf_distance_strikes_accuracy_diff',
 'l3y_inf_knockdowns_per_min_diff',
 'l5y_inf_head_strikes_accuracy_diff',
 'l3y_abs_distance_strikes_attempts_per_min_diff']

model_test_score(X_train, X_test, best_features, _max_iter = 30000, scaled=True)
# Out:
# Training set size: (559, 321) accuracy: 0.7227191413237924
# Test set size: (140, 321) accuracy: 0.5714285714285714
# Test set neg log loss: -0.696068156654517. Probability to observe data given model: 0.49854164290272746

# %%
# without fight math
# Training set size: (560, 317) accuracy: 0.725
# Test set size: (140, 317) accuracy: 0.5642857142857143
# Test set neg log loss: -0.7290313426064227. Probability to observe data given model: 0.4823760209564177
